# %% [markdown]
# Before we start, I personally set goals.
#
# 1. Get fomatted answer (with retry)
# 2. tag with multiple document(uuid maybe)
# 3. test guardrails

# %%
import os
import dspy
from dspy.retrieve.weaviate_rm import WeaviateRM
import weaviate


weaviate_client = weaviate.Client("http://localhost:8080",
    additional_headers={
        "X-Openai-Api-Key": os.getenv("OPENAI_API_KEY"),
    }
)

llm = dspy.OpenAI(model="gpt-3.5-turbo", max_tokens=4000, model_type="chat")
weaviate_rm = WeaviateRM("WeaviateBlogChunk", weaviate_client=weaviate_client)
dspy.settings.configure(lm=llm, rm=weaviate_rm)

# %%
schema = {
  "classes": [
    {
      "class": "WeaviateBlogChunk",
      "vectorizer": "text2vec-openai",
      "properties": [
        {
          "name": "content",
          "dataType": ["text"],
        },
        {
          "name": "author",
          "dataType": ["text"],
        }
      ],
      "moduleConfig": {
        "text2vec-openai": {
          "model": "text-embedding-3-large"
        }
      }
    }
  ]
}

# 스키마 생성
weaviate_client.schema.create(schema)
# Out:
# c:\anaconda\envs\dspy\Lib\site-packages\pygments\regexopt.py:78: ResourceWarning: unclosed <socket.socket fd=580, family=23, type=1, proto=0, laddr=('::', 64179, 0, 0)>
#   for group in groupby(strings, lambda s: s[0] == first[0])) \
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeException             Traceback (most recent call last)
# Cell In[14], line 26
#       1 schema = {
#       2   "classes": [
#       3     {
#    (...)
#      22   ]
#      23 }
#      25 # 스키마 생성
# ---> 26 weaviate_client.schema.create(schema)
#
# File c:\anaconda\envs\dspy\Lib\site-packages\weaviate\schema\crud_schema.py:200, in Schema.create(self, schema)
#     136 """
#     137 Create the schema of the Weaviate instance, with all classes at once.
#     138
#    (...)
#     196     If the 'schema' could not be validated against the standard format.
#     197 """
#     199 loaded_schema = _get_dict_from_object(schema)
# --> 200 self._create_classes_with_primitives(loaded_schema["classes"])
#     201 self._create_complex_properties_from_classes(loaded_schema["classes"])
#
# File c:\anaconda\envs\dspy\Lib\site-packages\weaviate\schema\crud_schema.py:831, in Schema._create_classes_with_primitives(self, schema_classes_list)
#     819 """
#     820 Create all the classes in the list and primitive properties.
#     821 This function does not create references,
#    (...)
#     827     A list of classes as they are found in a schema JSON description.
#     828 """
#     830 for weaviate_class in schema_classes_list:
# --> 831     self._create_class_with_primitives(weaviate_class)
#
# File c:\anaconda\envs\dspy\Lib\site-packages\weaviate\schema\crud_schema.py:816, in Schema._create_class_with_primitives(self, weaviate_class)
#     814     raise RequestsConnectionError("Class may not have been created properly.") from conn_err
#     815 if response.status_code != 200:
# --> 816     raise UnexpectedStatusCodeException("Create class", response)
#
# UnexpectedStatusCodeException: Create class! Unexpected status code: 422, with response body: {'error': [{'message': 'class name "WeaviateBlogChunk" already exists'}]}.

# %%
# Chunk Blogs

import os
import re

def chunk_list(lst, chunk_size):
    """Break a list into chunks of the specified size."""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def split_into_sentences(text):
    """Split text into sentences using regular expressions."""
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    return [sentence.strip() for sentence in sentences if sentence.strip()]

def read_and_chunk_index_files(main_folder_path):
    """Read index.md files from subfolders, split into sentences, and chunk every 5 sentences."""
    blog_chunks = []
    for folder_name in os.listdir(main_folder_path):
        subfolder_path = os.path.join(main_folder_path, folder_name)
        if os.path.isdir(subfolder_path):
            index_file_path = os.path.join(subfolder_path, 'index.mdx')
            if os.path.isfile(index_file_path):
                with open(index_file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                    sentences = split_into_sentences(content)
                    sentence_chunks = chunk_list(sentences, 5)
                    sentence_chunks = [' '.join(chunk) for chunk in sentence_chunks]
                    blog_chunks.extend(sentence_chunks)
    return blog_chunks

# Example usage
main_folder_path = './blog'
blog_chunks = read_and_chunk_index_files(main_folder_path)


print(f"There are {len(blog_chunks)} chunks in the main folder path.")
# Out:
# There are 1182 chunks in the main folder path.

# %%
import weaviate
for blog_chunk in blog_chunks:
    blog_object = {
        "content": blog_chunk,
    }

    try:
        response = weaviate_client.data_object.create(
            data_object=blog_object,
            class_name="WeaviateBlogChunk"
        )
        print(f"삽입 성공, UUID: {response}")
    except Exception as e:
        print(f"데이터 삽입 중 오류 발생: {e}")
# Out:
# 삽입 성공, UUID: 4fab49c7-e0b6-42c5-abab-0c7c0c214b2a
# 삽입 성공, UUID: a8e69d56-d099-41ec-93d7-ed915987b8a2
# 삽입 성공, UUID: 4e060d15-c36f-4ad3-8e98-870d6d0a9ad6
# 삽입 성공, UUID: 9ca4d0c3-6b05-4ef7-b656-4f3eb51a9417
# 삽입 성공, UUID: 78505c23-8884-45cb-a2af-2c5296becf43
# 삽입 성공, UUID: 0577f378-0964-479e-927d-8c2973fb1e92
# 삽입 성공, UUID: 535624c4-c2d8-4035-abad-fa29fb10d1ac
# 삽입 성공, UUID: 41e02cfc-662e-4100-bc75-1a3b3410bebc
# 삽입 성공, UUID: 60605a9e-8f6e-4e83-854f-9760838807a3
# 삽입 성공, UUID: 7a82b920-41dc-4582-85e1-5580954e0902
# 삽입 성공, UUID: 0c3921eb-d810-41e7-bd1a-2b6adc2d22ef
# 삽입 성공, UUID: 05ad6775-afde-48b0-b823-778026bedd40
# 삽입 성공, UUID: 35c1d2dd-777e-48ce-9c1b-d27a0f06abff
# 삽입 성공, UUID: 4fbdc7a9-f26a-4e7c-96a1-5128675a0ff7
# 삽입 성공, UUID: 5dec7d1f-3c0a-4fa6-bcfa-597741e4e24e
# 삽입 성공, UUID: 59262854-7fcd-4337-aa35-9ed9257ab9e3
# 삽입 성공, UUID: 3b0e17d2-ca7b-4677-bf49-764dfc9ac338
# 삽입 성공, UUID: 4a4f793c-2c3b-4b6a-9c77-d254fe46ecda
# 삽입 성공, UUID: fcd5592e-07dc-4e88-8ad0-1906e1c6abb2
# 삽입 성공, UUID: dbe570cb-c38b-480e-8f87-2594f556fdd3
# 삽입 성공, UUID: 63ab40c2-7e74-4639-9e49-2b05701e885b
# 삽입 성공, UUID: 3ef10ca2-6e20-4aca-8f43-dc8356d7c3e9
# 삽입 성공, UUID: b5dc2541-0c6e-4380-a153-734f22938c4d
# 삽입 성공, UUID: 46c65566-02e9-4e1c-a579-252ad12a1692
# 삽입 성공, UUID: 14f0d976-d89f-42ac-a5be-34af19a53637
# 삽입 성공, UUID: 6b9a503a-2060-4a16-a7d4-60504450cb4c
# 삽입 성공, UUID: e3b972a3-4965-46f3-97e3-01b389b2ca3d
# 삽입 성공, UUID: e6836dc8-051f-47dc-9250-51897897b9d2
# 삽입 성공, UUID: 77c92dcd-344b-4517-ab26-a76e6d576490
# 삽입 성공, UUID: 4cee3fe4-9b7d-4352-a3c8-e6fe9187cc8a
# 삽입 성공, UUID: 67a466bd-c866-4c87-aecf-e9caa0cb79fe
# 삽입 성공, UUID: fbf01c21-9ff2-417f-b953-c60f14afd607
# 삽입 성공, UUID: 315a1908-957b-435c-8353-ad6bda300958
# 삽입 성공, UUID: 8e3549ce-c3d5-47f6-9633-184d60f9042f
# 삽입 성공, UUID: c34e163a-69ac-42cc-b3b3-c1cdf030126d
# 삽입 성공, UUID: d7162e5e-5503-436f-9019-c8aa6e0f3f5d
# 삽입 성공, UUID: 15c1fe49-0aaf-4e4d-8e7d-c09e212c065c
# 삽입 성공, UUID: 51b937a9-5dbd-4202-9f60-2cc30ab72d8b
# 삽입 성공, UUID: 3ff0716e-7580-4c4c-8193-fb7e77f066ac
# 삽입 성공, UUID: 4e587e96-3cec-4fa1-a71b-e99f65c79514
# 삽입 성공, UUID: b7950cc1-8443-442c-ae25-4109a8f6b132
# 삽입 성공, UUID: 0bcaf642-93aa-4467-b9d5-dc27a71f642f
# 삽입 성공, UUID: 7817d577-c7d0-4785-ad14-1865eda9d7a9
# 삽입 성공, UUID: 8caf46ab-7d7f-46f2-8e73-878007b90f78
# 삽입 성공, UUID: 422377ac-4071-40d7-a5cf-29fa65a6d28d
# 삽입 성공, UUID: 8a0d93fd-e344-45d2-9e53-acbb3b7b9412
# 삽입 성공, UUID: d0441925-7a73-426d-8290-50b34cf1cd5e
# 삽입 성공, UUID: 74413280-05de-4c65-9c92-23a5962cfcf3
# 삽입 성공, UUID: 4b9991ae-7c95-4c64-ab26-0eda372968d5
# 삽입 성공, UUID: 905c61cc-69c7-48fe-a592-995c914e7aa6
# 삽입 성공, UUID: 8a59ab1f-086c-4cf2-a9e6-e5c863d4989b
# 삽입 성공, UUID: 2d6c9dc7-bd35-4e81-838d-4edbf7d1894e
# 삽입 성공, UUID: f7ea97ce-9e65-413b-b65a-ad16d5e7327e
# 삽입 성공, UUID: b48fc570-e2de-41ee-aaa9-0ef04a8ff5f9
# 삽입 성공, UUID: 94a25f0c-a4d1-49ac-b29d-eba1227881e7
# 삽입 성공, UUID: 62cbe1b4-b771-4aed-9f38-82ed926def05
# 삽입 성공, UUID: 25820f0e-507e-4684-9dfa-ab5fc076303b
# 삽입 성공, UUID: 4fe829a5-7818-4b68-b13a-05fc9d420072
# 삽입 성공, UUID: 1b6cf93b-9a55-4da9-93de-9170027baf06
# 삽입 성공, UUID: 852931ad-a7e4-4ca2-abf2-74df305dcd1a
# 삽입 성공, UUID: 0c9aa07c-77b9-4937-9809-5a73642ca9e7
# 삽입 성공, UUID: 8a4f7a17-0426-47e4-a0fb-c7a104e90175
# 삽입 성공, UUID: 9c2f4097-6ada-4979-b0c6-49111854e309
# 삽입 성공, UUID: cf860ace-e3b9-4c6b-8fb3-529229a19548
# 삽입 성공, UUID: 89252ea3-7873-4533-8918-62c556a00686
# 삽입 성공, UUID: 5c86d5cf-f2aa-45df-b396-58925f1b5f1a
# 삽입 성공, UUID: 4b22cf21-0727-4d56-b508-82bd395a3a21
# 삽입 성공, UUID: e30f2e76-b792-4301-b754-ef565e00620d
# 삽입 성공, UUID: 8eb6e5e3-83f0-4784-84e4-628d37d5bd2a
# 삽입 성공, UUID: 6ce40a04-eece-488f-b7ac-cf8322830705
# 삽입 성공, UUID: 86836467-a818-44e8-8d90-3930995980a0
# 삽입 성공, UUID: 97aae844-5def-4b13-afb1-c6815d526447
# 삽입 성공, UUID: 59e73394-e5cb-4928-a612-ac79963f15e8
# 삽입 성공, UUID: d61b426e-e65e-46f3-89d5-88f0ce842302
# 삽입 성공, UUID: c244c7d4-4407-4615-85eb-3073bf831862
# 삽입 성공, UUID: 465baf3b-c4c9-4767-924a-7e36b402e29e
# 삽입 성공, UUID: 1ef4e3be-44db-4e19-a7a1-21852ce99181
# 삽입 성공, UUID: 8eb015c2-0fad-4667-9edc-2f1edd28df44
# 삽입 성공, UUID: 41b7c314-9941-4a35-b52f-9c6ca6c2ecf0
# 삽입 성공, UUID: ba15cd68-4262-4ff4-9608-56a60c9431b9
# 삽입 성공, UUID: 6e9c96c1-92e7-43e3-a64a-62e415d03159
# 삽입 성공, UUID: 25d906e2-23be-49f6-bf54-4c689021b3a2
# 삽입 성공, UUID: ffea6d7f-4179-4fd1-b372-bcbdfb21c967
# 삽입 성공, UUID: bcfe760d-13a3-466c-a9ea-712fd632d26a
# 삽입 성공, UUID: fa154cbb-8eb9-49d5-9791-fbd1b937f70b
# 삽입 성공, UUID: 6611ce9b-cfbd-4fa0-9c37-2125ffce192b
# 삽입 성공, UUID: e33b75f0-0f85-407a-9307-4de8d2bbf7a2
# 삽입 성공, UUID: a81756ab-0069-4051-9e51-04772e0a4ea6
# 삽입 성공, UUID: a658b18d-5930-41f1-b13d-642c6f737fe8
# 삽입 성공, UUID: 6aa8f5a1-9f73-4476-8d3a-46c2bcdace40
# 삽입 성공, UUID: 5a7c9b8e-025b-449c-934a-73f347620554
# 삽입 성공, UUID: f62d5374-1e19-47b5-976f-1cd5b97f9c02
# 삽입 성공, UUID: 78f4d71a-201d-465a-8713-e8b72cb6b4fc
# 삽입 성공, UUID: b3d02a78-e19d-4fc3-9a09-4ab582ce2a27
# 삽입 성공, UUID: f6d9a5fb-c7ef-47bc-902b-8e5f740b78fa
# 삽입 성공, UUID: 6f55e690-165d-4cc8-93c3-0209c4f15f2f
# 삽입 성공, UUID: 29d6f82d-e8a3-4aa1-bc55-b5a72102ced7
# 삽입 성공, UUID: 69b8b548-52ec-4768-9e7c-e1e5d1c260d5
# 삽입 성공, UUID: aab9c098-fcb5-437a-9eda-ec59570ef27e
# 삽입 성공, UUID: 73e25873-3847-4de9-a626-92ed14c8678f
# 삽입 성공, UUID: ad582d4f-a0fa-4be0-9513-0ed78228b890
# 삽입 성공, UUID: 7d1a1b44-5f61-4bfb-aa1f-ce3ecf3321eb
# 삽입 성공, UUID: ca77a0b2-be92-4de7-a504-1c66035d95ad
# 삽입 성공, UUID: f04e2d1e-da7c-4738-a530-79f9d76c25eb
# 삽입 성공, UUID: 2407bc70-a823-4c57-a37f-c3a30546b20b
# 삽입 성공, UUID: b470bc34-320a-4ac8-ad83-7d585df0385a
# 삽입 성공, UUID: 41a3a027-cede-4116-b728-f2981a384fde
# 삽입 성공, UUID: 8efb482c-6f1c-49e7-bfc5-0f372386211f
# 삽입 성공, UUID: d6534a88-b108-4b3e-a7c4-65982efca6d3
# 삽입 성공, UUID: f587ffbf-9aff-447b-b1dc-001553bd6360
# 삽입 성공, UUID: 96aeffe3-e45d-4947-9511-5d6ae0a9f5e6
# 삽입 성공, UUID: 4c8d1514-a108-4de3-b978-9cacde8fcbae
# 삽입 성공, UUID: 870166f5-168c-492d-86f7-52a4978141a4
# 삽입 성공, UUID: 48978b95-ceca-44fc-85fa-748035535b17
# 삽입 성공, UUID: 538859cf-9c5f-47f8-91eb-6192177aaf0a
# 삽입 성공, UUID: 77dab8be-358c-4588-a66a-7dba81bff6da
# 삽입 성공, UUID: 9b9a9bdb-ba9d-4efd-9d35-e8f103201bda
# 삽입 성공, UUID: 3b34e9ed-b941-474a-b18e-4b0ecfe7f3b5
# 삽입 성공, UUID: 07b1a2c8-25d9-4e7b-b918-e2495849c232
# 삽입 성공, UUID: e14d4a92-9d55-448c-87ce-78086ad2dd29
# 삽입 성공, UUID: 048e80c1-f430-4d09-82f3-b5639f435cb3
# 삽입 성공, UUID: 476e90aa-d4ba-44ef-bfc0-65fd87b8b5fc
# 삽입 성공, UUID: 6b6940d6-6a54-400e-8fca-395115df7fc5
# 삽입 성공, UUID: f56d06f9-046d-4c6c-9fa4-7c91588c2d2d
# 삽입 성공, UUID: 0b5864a5-2b99-44c3-a383-8e950f48f456
# 삽입 성공, UUID: bc9c884f-d0b5-4e70-bad5-141e346352a5
# 삽입 성공, UUID: 52325aa3-7a35-4645-8b60-58cb7ab42a4e
# 삽입 성공, UUID: 2dee2cf0-4915-4746-8588-5712f74a5605
# 삽입 성공, UUID: 68925362-4d62-4499-95c9-9b0439bbccdb
# 삽입 성공, UUID: 4215bd65-a271-4a1c-a06d-be5624ca8e89
# 삽입 성공, UUID: 912a8215-2973-4de9-b5f7-4d724a0dc0ac
# 삽입 성공, UUID: e7028b6d-e059-434c-a5e8-b94d6dd411ad
# 삽입 성공, UUID: 276bd171-6c97-4968-b231-ed39a0ad6c82
# 삽입 성공, UUID: d16047a7-4bf1-425a-85cc-045c04837bc3
# 삽입 성공, UUID: 503fd16d-748c-495b-bcaa-08d9a34ee2a7
# 삽입 성공, UUID: c15495a4-100d-4128-ba75-eb30d8b2cc67
# 삽입 성공, UUID: 24c72497-de1c-4a15-b75c-e32d36683dcd
# 삽입 성공, UUID: d89ff593-a828-4f84-8b17-3ca9e08b0059
# 삽입 성공, UUID: 6fdc45e3-0cdb-4e79-aa66-1b17e4cf3302
# 삽입 성공, UUID: fcf1e529-bc21-4ea3-a4f4-2f2136b4796f
# 삽입 성공, UUID: 4e052eb9-0f48-4ccf-b1bf-a80e0b4254a4
# 삽입 성공, UUID: b2124901-dac5-4193-a348-cade073bd031
# 삽입 성공, UUID: 3d629494-9ea7-4d00-a3c5-2f7064a05648
# 삽입 성공, UUID: 536727db-9d5b-4978-aab1-e4b91d6cf17a
# 삽입 성공, UUID: 036f10c0-4c1e-4b30-801b-84728ad31210
# 삽입 성공, UUID: ef2a35b0-86d6-4982-a977-f847fd5b380a
# 삽입 성공, UUID: a2b7fc02-1a7c-4392-92bb-797be4f91c35
# 삽입 성공, UUID: 1bba4968-6c21-490d-9848-74f5d35afd11
# 삽입 성공, UUID: b7d822d5-b9bf-4421-bf1b-39e8bfa92d2b
# 삽입 성공, UUID: 35d137dc-43fd-4f9e-822e-40691a97b621
# 삽입 성공, UUID: 02f75b21-1e1f-4cc3-bbc2-9deb0dbd807e
# 삽입 성공, UUID: c370dfe9-383c-4f23-aecb-c2d17eefbbcf
# 삽입 성공, UUID: c00fda65-69f3-4ac9-8639-5c0f8c1be3f2
# 삽입 성공, UUID: e24f7fc7-7e3d-44f8-8012-e1840b18d581
# 삽입 성공, UUID: b359c69f-4fc8-45db-a492-40605a578abb
# 삽입 성공, UUID: 189e88a1-871e-4a06-9dde-6e77a07f1723
# 삽입 성공, UUID: 0443fd8d-b40c-4dca-9a3b-e3f343e839fb
# 삽입 성공, UUID: a071a785-54f7-4b8e-8a74-5e06b893b95b
# 삽입 성공, UUID: e24bc5d7-1096-4d16-852e-9e7468827089
# 삽입 성공, UUID: 68862353-952e-4711-b42d-fa50185c100f
# 삽입 성공, UUID: f4d68ec0-e832-48ff-9f1d-c5d5d9c190ea
# 삽입 성공, UUID: d8a4b7d9-76de-43a0-8667-cbd85aa65a67
# 삽입 성공, UUID: 8f8cd582-07f4-427a-8ea0-98dfa6e4fed3
# 삽입 성공, UUID: 7185de57-4df2-4029-a4d1-4778a206d737
# 삽입 성공, UUID: 3ed582ee-63aa-4ea8-a3c8-4b2061412e4b
# 삽입 성공, UUID: e64593bb-f3dc-4896-8f46-5b61e2a8d1a7
# 삽입 성공, UUID: 9df17dce-97df-48b6-9a19-8aadff3090fa
# 삽입 성공, UUID: c0e083f5-04b1-43c3-894e-d55376c29b54
# 삽입 성공, UUID: 3f4cc0a4-1487-4bfe-b7bc-d81eaed1fc07
# 삽입 성공, UUID: 56d25ff5-832c-42f5-b070-c3c65b4d77db
# 삽입 성공, UUID: 9a011f91-e6f4-4134-8e17-00ece2f90bf3
# 삽입 성공, UUID: f2569992-c283-44d9-9dc6-0ae0dcb69736
# 삽입 성공, UUID: 6eb1f6fc-4dd1-4118-9349-cc8e78ccc257
# 삽입 성공, UUID: b639de80-6e0f-4cd5-9601-6eb0b78be61b
# 삽입 성공, UUID: d13d0f23-ed13-491f-8d5a-cd87e8a0b2b9
# 삽입 성공, UUID: bb910aa7-d61c-4e4f-835d-c46286fcee1a
# 삽입 성공, UUID: 07cfb695-4382-4277-8ce9-adb0e7ed2695
# 삽입 성공, UUID: 0822ac0e-6bab-439a-a0f0-2faea5d9c32b
# 삽입 성공, UUID: ae15b059-f185-4e29-936a-4705b9720e5a
# 삽입 성공, UUID: ff6f7c29-5859-48c3-ac86-3bf2f69ad1e0
# 삽입 성공, UUID: a69178a5-3a35-4eb1-a8d1-505f56cf8293
# 삽입 성공, UUID: b0964bca-9f0e-4d06-b4f5-f3f9c0c17e6f
# 삽입 성공, UUID: 3aee01d1-e381-4335-a453-0728cdf701b6
# 삽입 성공, UUID: 2f431410-4df3-4920-8a52-389d047c5fc3
# 삽입 성공, UUID: a39bfa7a-d781-4cc0-820a-1aaf9ffa0b2b
# 삽입 성공, UUID: b9100aa5-2e96-4161-8f5a-cdaa50cceb54
# 삽입 성공, UUID: 8c799979-4a57-45bd-9638-c40cc7ac263d
# 삽입 성공, UUID: 05a356de-7555-43c5-9a9d-1c7e7b711e48
# 삽입 성공, UUID: 6b83551d-ec1b-484d-b2b0-7f95c854e7bb
# 삽입 성공, UUID: 91287006-881f-42da-83a0-e5e5b02dab55
# 삽입 성공, UUID: 3ccab78b-c216-4a7e-906d-08393c3c8f8b
# 삽입 성공, UUID: 7175ac59-c21c-4e9f-8c23-30bfd1416172
# 삽입 성공, UUID: 57273903-bd4b-4f25-a4ae-ed391479b920
# 삽입 성공, UUID: caeb7edc-d80e-4883-978d-dc16a70ce3e0
# 삽입 성공, UUID: 09dcaf77-5801-46db-a083-abdbc6ed5883
# 삽입 성공, UUID: b376ce37-c28a-45f0-96ba-c17012e4cbc8
# 삽입 성공, UUID: d9b6f0d3-d58e-48c3-abfc-8b4f8bdcd468
# 삽입 성공, UUID: aae712e8-662d-4544-83d9-24430d33ac2b
# 삽입 성공, UUID: 5383d4ec-3ce0-4a67-ac8b-fe380015447f
# 삽입 성공, UUID: 7472ce25-a065-4afb-bfd6-0da46cf1ca32
# 삽입 성공, UUID: 9924e748-c875-49d4-8fe2-108ce5bfd6b0
# 삽입 성공, UUID: 7af1cf54-aed5-42a1-8e06-b7efc089ce9a
# 삽입 성공, UUID: bca57dc6-16ff-4d4e-9593-011c78b51d70
# 삽입 성공, UUID: ff9b990d-749c-4bf1-acb4-0f6938ab506c
# 삽입 성공, UUID: 03b7f98b-69b7-4e79-a7ff-ff84caac5e37
# 삽입 성공, UUID: 091efa76-507b-46a0-9f39-9d655a41273b
# 삽입 성공, UUID: c7444a05-600d-40f4-b99b-e5cfea2b39d2
# 삽입 성공, UUID: 2b01c912-9ef9-4dd8-b434-05edf3a89171
# 삽입 성공, UUID: 010da4d3-ca08-4457-ab80-8f67d673f34b
# 삽입 성공, UUID: 433d0efd-03f0-4287-8072-0518c236d31d
# 삽입 성공, UUID: 37265178-eba3-4503-b085-3ba33660d7cb
# 삽입 성공, UUID: fbc742d7-0e90-4425-9591-625c95220aa9
# 삽입 성공, UUID: 4414ffa9-807f-4cf4-97a8-20e1e8eac7d7
# 삽입 성공, UUID: 318dd23d-9c7f-46ed-8eab-389bcb8300da
# 삽입 성공, UUID: 8ec800e9-e477-4cbb-a1cb-6508ccb91b31
# 삽입 성공, UUID: 5993e859-efa0-49a3-a757-b5c399ef6798
# 삽입 성공, UUID: bda6bccf-6d26-4ed4-912d-53211408aec2
# 삽입 성공, UUID: af8ae996-da01-4401-af4f-f7384abbac41
# 삽입 성공, UUID: ecf34cb8-0a68-4f3d-93e4-c33cd277276e
# 삽입 성공, UUID: 13a05c85-e95a-458d-8317-b06545b65930
# 삽입 성공, UUID: 57b052d1-f536-465e-a75e-dab376e297b3
# 삽입 성공, UUID: df3705f0-8303-427b-89a0-4479a7643519
# 삽입 성공, UUID: 39eb483d-c734-47b1-b03b-b21939887e45
# 삽입 성공, UUID: 268e8e42-6f7f-44cf-90b7-8e18fe2dbc55
# 삽입 성공, UUID: 999521c9-1403-4762-b716-912bf5fcf755
# 삽입 성공, UUID: 6b30d8e7-6ae6-4e82-9e93-df8ea42b0abb
# 삽입 성공, UUID: ac4e7cc3-db47-4a6c-8764-384507ce06e7
# 삽입 성공, UUID: 561a2a13-5418-48d4-bf11-7a757184c9d2
# 삽입 성공, UUID: 7448be83-1815-42df-8b2f-6064e2f7f2b5
# 삽입 성공, UUID: ba0e5cc8-8df4-4fb1-bf69-47aed85330f9
# 삽입 성공, UUID: 99c2d5ee-4ef2-4ee9-bd68-3ad387151565
# 삽입 성공, UUID: 08548f66-1b79-4237-9b78-df068f415d74
# 삽입 성공, UUID: 55e71c01-a7dc-4bb4-9cb1-f1ae00cede7b
# 삽입 성공, UUID: 967c5192-5a0f-4055-80dd-9a544a83221d
# 삽입 성공, UUID: daad68f6-e6c2-4449-9080-09d7befd6e7f
# 삽입 성공, UUID: c3ccd02e-e988-4c3b-9803-bbadc36f52b3
# 삽입 성공, UUID: cbe64edd-af00-4bbe-a0f0-05a6d2af36c2
# 삽입 성공, UUID: 4fdde308-7cc7-4169-9d8b-00580c41d01f
# 삽입 성공, UUID: ed987a81-17ca-4d26-9ca0-71bb1d08a50a
# 삽입 성공, UUID: e35d64b7-6092-4251-97f9-34c70eaeaeef
# 삽입 성공, UUID: 79561195-8184-4ac1-ace3-b04a78af30a9
# 삽입 성공, UUID: eb4c76a1-f89c-4846-8368-7d2e972e12ef
# 삽입 성공, UUID: 091d1554-1f72-4329-96d0-50564e3efbe4
# 삽입 성공, UUID: 4b6f0c16-eb8f-4916-b68b-840a88fc1133
# 삽입 성공, UUID: bb59b4e9-bd1d-424e-9a55-f74e037e5d85
# 삽입 성공, UUID: 6dbae517-8296-47ab-82d2-2dcecf1375ff
# 삽입 성공, UUID: 2e43d85c-8af8-4cd1-aa8c-e56f93792655
# 삽입 성공, UUID: 061f76a9-3037-4d99-8ac9-20fd906d38a8
# 삽입 성공, UUID: d506379c-dabb-4ec4-8cc9-780cd030f56c
# 삽입 성공, UUID: 2bf1bbdd-c6dd-4517-bd0e-9db99de10336
# 삽입 성공, UUID: 42cdbd5c-4b7b-4ef0-aa84-e5565ce58037
# 삽입 성공, UUID: cd7d9055-0bc6-4197-af6a-03eb6514552e
# 삽입 성공, UUID: d4284c91-880c-4f00-8d42-3c5a9ce5074e
# 삽입 성공, UUID: 4d377352-8379-4f9a-9908-46bc44833311
# 삽입 성공, UUID: ca314f24-f534-4c65-861e-59436177a9ed
# 삽입 성공, UUID: a4b742d8-c5f2-49ee-a83b-f099d423d4f3
# 삽입 성공, UUID: 76d9d448-72d7-41d7-be02-c462495d6a6f
# 삽입 성공, UUID: d8c66e6e-a444-4594-98f7-4a2dc720a296
# 삽입 성공, UUID: 3ba00511-b8f5-4764-9a68-b577e0681ea6
# 삽입 성공, UUID: 6109e16f-cd97-45bb-a5e6-36c655af3f37
# 삽입 성공, UUID: 79ad9a89-0874-4438-b676-fb9fe9953f3e
# 삽입 성공, UUID: 6136250f-ccbd-4624-bfe3-054e1d832e03
# 삽입 성공, UUID: 094ab8d2-2ef7-4543-b53d-14ee823d5b7c
# 삽입 성공, UUID: f490b125-532d-4df4-8a7e-f86cb7a2a977
# 삽입 성공, UUID: d7d1d846-ec97-459d-8782-cae0e4c12b77
# 삽입 성공, UUID: 082f427c-01bb-4f5d-920e-56097f90fee2
# 삽입 성공, UUID: 059d2e2b-f240-4394-a4f1-31fd596c8a0c
# 삽입 성공, UUID: fe97cbdb-529c-411d-9a1c-1ea3c4bfc834
# 삽입 성공, UUID: 7189731e-7b40-4b67-8ca6-c3828fd43c83
# 삽입 성공, UUID: 933f2eac-7a52-4120-a853-5d1a4172c806
# 삽입 성공, UUID: ac12452f-8167-407a-9a08-481a13081d0b
# 삽입 성공, UUID: 94679e9d-2633-4c0b-b958-f4174230f080
# 삽입 성공, UUID: b5cf754a-bc16-4416-98c5-b9fd609a585f
# 삽입 성공, UUID: ce069ab1-c855-4a84-b8e0-17b089dd7e72
# 삽입 성공, UUID: 6b3f2457-15d3-43db-8b2f-7709b2c560a0
# 삽입 성공, UUID: 21edf567-cb5e-464d-8b1a-9e80e7014232
# 삽입 성공, UUID: f2eb70c9-6734-41db-bab0-89a05ff30d58
# 삽입 성공, UUID: f2cbfcb5-0261-4565-babd-617fb4fd77fd
# 삽입 성공, UUID: 7240f11b-07ff-4ceb-b0e9-e7491805f6dc
# 삽입 성공, UUID: 64ae6db5-e88e-4fc0-ad21-038edfbb591b
# 삽입 성공, UUID: 34682fe3-e95e-494c-93fa-f50f401c0039
# 삽입 성공, UUID: 5126283a-52f4-40d1-8360-eee7105a0558
# 삽입 성공, UUID: 621f1b60-f428-435f-a240-4562b86de4e3
# 삽입 성공, UUID: 5d408abf-2375-41a2-9847-4f35d05986f4
# 삽입 성공, UUID: 73376a2a-d700-4f30-aa3d-e36304a4f11b
# 삽입 성공, UUID: 2c54c673-9330-4df2-9aea-a42deaa4f348
# 삽입 성공, UUID: 85d39a3a-5976-4aa3-bf7c-f793f2cb3150
# 삽입 성공, UUID: b714f8e3-7505-428d-bbed-a2cb0508c929
# 삽입 성공, UUID: 7b983c25-6740-4f0f-a8c4-45a80af60675
# 삽입 성공, UUID: d7074033-bd66-4a6c-a1bd-d483365e497c
# 삽입 성공, UUID: 375e912d-31ee-4f9f-ac76-cb7df6565357
# 삽입 성공, UUID: 4e8dbbde-d342-4b74-bdab-64ac1ff0964e
# 삽입 성공, UUID: 57623c6d-01ab-4a77-830d-7078412f0164
# 삽입 성공, UUID: 0d1974f7-d50b-4b2e-b930-b370e8ce44a0
# 삽입 성공, UUID: d2959da9-4fea-43dd-aada-2f2743a99e7a
# 삽입 성공, UUID: c9661d9f-e912-4cc2-881b-6d4c4b7cfce7
# 삽입 성공, UUID: 26bf36fe-2643-413a-a50f-78b7b82b622e
# 삽입 성공, UUID: 34b8b00c-221b-403c-8fcc-c6c731e7cde3
# 삽입 성공, UUID: afbafe79-6fa1-4ea1-93f0-cc9f5ad44c11
# 삽입 성공, UUID: c15d8cf8-016e-4994-be10-66a60b41fba9
# 삽입 성공, UUID: 1de9c004-8b0e-47a1-81c0-b56757a8ecca
# 삽입 성공, UUID: a6c899b6-ec8b-4583-9cf2-a2669ddf2b15
# 삽입 성공, UUID: 241799bc-06a7-4e10-8b27-6bc96a369f4b
# 삽입 성공, UUID: 91055bee-d6e7-4917-a930-ad807ddb8069
# 삽입 성공, UUID: 40547e81-890b-4747-bcce-65f212ab2c6d
# 삽입 성공, UUID: 92bfe657-83be-4c0a-b079-ebfe182bb3f1
# 삽입 성공, UUID: fe90d6c9-9983-46d2-894c-d0462213a608
# 삽입 성공, UUID: b18d3763-5eb5-458b-8668-10eaa7f81ddf
# 삽입 성공, UUID: c1850737-b2b0-49f0-a6dd-fe4d20ce86ec
# 삽입 성공, UUID: 6d88305b-7c16-409c-93c2-f01d28a8ebed
# 삽입 성공, UUID: dd5160e5-1652-45da-abfd-9884d2ccafd6
# 삽입 성공, UUID: 3a6efe58-b4b3-4312-b96f-5aa08d2972d5
# 삽입 성공, UUID: 59228eff-3152-4350-8cef-cf89d2df67e7
# 삽입 성공, UUID: 09dc2680-fd55-45ae-a1da-6735c10a390d
# 삽입 성공, UUID: 1b7a5729-42d2-433d-a8d5-d01662cd2cd6
# 삽입 성공, UUID: 82db8583-c02e-48e4-9347-4317edb2594e
# 삽입 성공, UUID: 67e06a9c-4376-4d2a-b659-5b7a55e7df36
# 삽입 성공, UUID: e22b51a6-86ac-46db-a700-ae0c539e5058
# 삽입 성공, UUID: c428dda0-cd6d-49f1-b181-3840df93d5cb
# 삽입 성공, UUID: 867b182d-5543-42c5-b1bf-8f3936faf7fb
# 삽입 성공, UUID: b324d425-69dd-4ea4-b95f-d581be9f12ea
# 삽입 성공, UUID: 0870351f-f8b3-45cc-9bd2-6a352c547ff3
# 삽입 성공, UUID: 40d23bba-bc88-44b7-8012-4301a854a2da
# 삽입 성공, UUID: 9eed9c39-39af-4bf0-8127-756f8e06c12f
# 삽입 성공, UUID: 8a85e080-e635-472d-812d-df063aa57e8c
# 삽입 성공, UUID: 010565c6-2fbd-4622-865c-079faf232a19
# 삽입 성공, UUID: 70d8ca63-5ecf-4de2-8434-c8a3a181fdb8
# 삽입 성공, UUID: a9e2a1e9-cd27-4387-9ca8-e1f1a3f66f11
# 삽입 성공, UUID: 2afc3075-07f2-4c2f-bba5-adb18b66fd7a
# 삽입 성공, UUID: defddff2-6659-446b-9dcd-8b97ecfa8683
# 삽입 성공, UUID: 28ec007e-2210-4a77-94f5-8a1f85787290
# 삽입 성공, UUID: 157fdfa0-b7bd-4a00-abd3-b7e4f768a879
# 삽입 성공, UUID: bfb13385-a415-405b-bd26-464c46c1410b
# 삽입 성공, UUID: d2863064-d536-4346-b0cc-a9aa84f9d436
# 삽입 성공, UUID: abbb7e95-8e87-4761-b285-f22ab8d18ae4
# 삽입 성공, UUID: 8b30d948-f08b-4863-9e99-5815417f4058
# 삽입 성공, UUID: 0b7dfdb5-e632-482f-95f2-40c06eac4485
# 삽입 성공, UUID: 4176863a-526c-4bee-8367-1d74c9586d6c
# 삽입 성공, UUID: e8a3d96a-6e70-4ef3-8eba-963edef120b2
# 삽입 성공, UUID: ef44b689-f2b5-4f84-a8ff-ce4be77919d4
# 삽입 성공, UUID: 15446b90-e012-46a6-b59f-641ecadbd145
# 삽입 성공, UUID: dc655db0-a6e0-4dfd-ad47-26fc517e252a
# 삽입 성공, UUID: 0c43b2a9-b855-4614-8351-63bc9bbad287
# 삽입 성공, UUID: 476d6136-00e2-454a-97f9-546c8f6cf8bb
# 삽입 성공, UUID: 9bdc49d5-32b6-4da9-a8c2-7d28ade73643
# 삽입 성공, UUID: 1c094399-aa4d-48e7-97c6-b0158ac41446
# 삽입 성공, UUID: ff77ad41-3502-404d-9ef6-e0e189978422
# 삽입 성공, UUID: 2bde55ec-784f-466a-9a2b-216ab938e11d
# 삽입 성공, UUID: 39c30c8c-a7f8-4ae1-90c7-3498d29ed667
# 삽입 성공, UUID: 38285f2e-3af8-44e0-a83d-268a0a86931d
# 삽입 성공, UUID: 4766a997-2c54-429c-98c0-62d6187de6b3
# 삽입 성공, UUID: 3c29c07c-ba86-4d19-9bea-6b88db412a34
# 삽입 성공, UUID: 7ee791ea-efbf-4b17-af92-ccb1b75f2792
# 삽입 성공, UUID: 23a5126a-e685-4002-be19-a13cca78b304
# 삽입 성공, UUID: c72ecdb9-209b-48b1-8832-96f964865194
# 삽입 성공, UUID: d36b2b01-08b5-4a75-bd6f-7884467728c7
# 삽입 성공, UUID: cb7ba210-3c57-4bad-9daa-02bb4be11005
# 삽입 성공, UUID: bbcbc094-ce9e-4eca-beef-510ba03f7389
# 삽입 성공, UUID: b8499ad2-541d-408b-bc66-c2448f9d9e8e
# 삽입 성공, UUID: bdc97594-61ae-448a-af41-b10dfbc3a8e2
# 삽입 성공, UUID: d3fcf887-cc0a-4fd6-abd1-6071be46ea38
# 삽입 성공, UUID: 4d849412-5ee0-4be3-8ced-58d149a1a269
# 삽입 성공, UUID: 74abed8b-23cb-4e0c-934b-0b72e8647017
# 삽입 성공, UUID: 47f34dca-f271-4921-9a48-883f04d19b5b
# 삽입 성공, UUID: a41dfdda-5927-49cf-bf0f-33bb98ae8b91
# 삽입 성공, UUID: 812430ed-c5d1-41dd-90d8-358da29c47ab
# 삽입 성공, UUID: 3008bbea-fc96-4228-9fa6-90da821f8327
# 삽입 성공, UUID: 840117a9-84dd-4311-af90-9f9295f52722
# 삽입 성공, UUID: 3d80d609-bce0-472a-8e27-b60f5d1ad68d
# 삽입 성공, UUID: 43ffbbe9-b161-4ad5-ace5-717157a942b7
# 삽입 성공, UUID: 32c340c4-f9aa-4813-9e23-80eb2a4d66d2
# 삽입 성공, UUID: 46b67d1e-9c92-455d-92b8-914a83a5b851
# 삽입 성공, UUID: a068f8e1-1f82-42b2-ad3b-481acca58e0f
# 삽입 성공, UUID: caa017b3-17f9-420e-98e6-5245eb7afe32
# 삽입 성공, UUID: 5c605d2e-190b-4a45-a9db-39d7f1e10e2c
# 삽입 성공, UUID: eadde259-9387-4877-b28a-e4266aeb991a
# 삽입 성공, UUID: 8d668a84-a997-47da-a752-a7990d54ce22
# 삽입 성공, UUID: fdf585ff-ab79-4709-9118-acd00ce3b985
# 삽입 성공, UUID: 95b72afb-c7df-4d27-88bf-8c038ab790f8
# 삽입 성공, UUID: 8f3ec0ac-e7b2-4b55-9f32-af386cf7aed9
# 삽입 성공, UUID: 7e8f97aa-086b-4f3e-959f-40cc7515107e
# 삽입 성공, UUID: 4115a674-7e24-4ac3-8f35-1e2c50bda477
# 삽입 성공, UUID: e20e3788-ef5f-4fd6-b4ca-c7a189c49455
# 삽입 성공, UUID: 62017b5a-9c9a-4d23-b575-58c186be0f0d
# 삽입 성공, UUID: 86e9bb39-578b-4a61-9999-437dd2d60a97
# 삽입 성공, UUID: 0ec12b7b-c4d7-4acb-a1fb-08e82c7aaa78
# 삽입 성공, UUID: d4e199c8-02ba-466f-bcc5-4f97175bba58
# 데이터 삽입 중 오류 발생: Creating object! Unexpected status code: 500, with response body: {'error': [{'message': 'update vector: connection to: OpenAI API failed with status: 503 error: Service Unavailable.'}]}.
# 삽입 성공, UUID: c3c48819-64ec-458d-973d-db1de17cc4fd
# 삽입 성공, UUID: 913cfb5d-fef6-4cfa-a0a3-8007709939c1
# 삽입 성공, UUID: 802cc4b7-d880-4dbd-8e07-2ce1d4888bcd
# 삽입 성공, UUID: 009e057b-6b32-4aa0-8798-f4e2eba9058b
# 삽입 성공, UUID: 85a5e5b9-3e8f-433d-b76d-c2987d7d58f7
# 삽입 성공, UUID: 9e8dcdb8-f77c-4326-a0e0-1e6cb3818f00
# 삽입 성공, UUID: 9fab3e50-11d9-4df9-bdd3-79c1cd5bad49
# 삽입 성공, UUID: 49aa5875-50a6-44ea-9364-aaaae634e5c7
# 삽입 성공, UUID: e5ebfe27-09b7-47be-8855-108302ad42d6
# 삽입 성공, UUID: a85d99f9-7c43-4117-9de2-b53feaed06df
# 삽입 성공, UUID: 927dbddd-c1ad-485c-82b5-b6c7b7900492
# 삽입 성공, UUID: 75e91392-8429-44b5-868c-3f9d4fb422b3
# 삽입 성공, UUID: 0260a0d1-3929-4b3f-84f4-6d581191fb04
# 삽입 성공, UUID: 21cc90b3-2609-4df3-b7e6-5b382885d0e1
# 삽입 성공, UUID: ac2da9e8-8c98-4b94-a4f8-d84073b269b1
# 삽입 성공, UUID: c999c529-342a-4b39-8b66-f9df55884a67
# 삽입 성공, UUID: fbf5edae-6c25-4cf4-89f0-1446dda0f9f4
# 삽입 성공, UUID: 106c8def-8552-48a8-b9c1-132282e56fff
# 삽입 성공, UUID: 3812fb20-09cc-4274-a07d-f3e1c1c09265
# 삽입 성공, UUID: 512854fd-d55c-4cf1-ad96-f4819aa59cdb
# 삽입 성공, UUID: d4f789fd-1195-4679-a5cf-e9145f865b66
# 삽입 성공, UUID: 62eac475-2190-49bd-8789-e6023892ef23
# 삽입 성공, UUID: 8da9b36e-9daa-4788-8db4-60681ba6211a
# 삽입 성공, UUID: f83fddb7-2dd1-4cb6-ae52-8f2d3bbeabd4
# 삽입 성공, UUID: cef8cb60-61c6-44ce-9763-b1d531d452f2
# 삽입 성공, UUID: 87e1e5ef-8372-4ce0-99df-da995f73165d
# 삽입 성공, UUID: 163b41e8-5164-4fb5-9f78-ca1b5b2deb40
# 삽입 성공, UUID: 5ebeba58-1fdc-40e7-9d45-da50bf2a217e
# 삽입 성공, UUID: d780797e-c8e5-44a6-a454-c51cb0138f6e
# 삽입 성공, UUID: 49c089ea-98bb-4247-b196-e7ef88f01be0
# 삽입 성공, UUID: 9e47af9a-0b18-4762-9962-6b6c37c9feeb
# 삽입 성공, UUID: bc6ae43a-dd66-462a-8234-a05b9185e276
# 삽입 성공, UUID: b5393fda-6a83-4fce-9e40-702504f1c075
# 삽입 성공, UUID: ee1bb7cd-aca1-4d09-95b1-dc8e9ebbf676
# 삽입 성공, UUID: ae686c81-0acc-40b5-8805-281967573121
# 삽입 성공, UUID: 3e0dcce1-b615-4d55-9ca9-4ff07d89ddf3
# 삽입 성공, UUID: 477018aa-a5b5-4ebd-a374-74dd5ce20bd5
# 삽입 성공, UUID: ce63eb47-616a-4822-804f-265b74fbb6ce
# 삽입 성공, UUID: 302636fc-e056-467a-9c40-800183a13e24
# 삽입 성공, UUID: d55fbce3-1736-4bab-952a-4907286336b6
# 삽입 성공, UUID: de80085f-1a5f-4259-aa5c-a64cf3764847
# 삽입 성공, UUID: fb84f4ae-048c-4c58-9287-131dbac6c64b
# 삽입 성공, UUID: 0fdef7b6-0e90-4ce4-b5ad-2aebcf3b142b
# 삽입 성공, UUID: 4a51d9c3-7a9a-44a9-98c8-ae3e52f22278
# 삽입 성공, UUID: e1fdc6f2-494f-417e-b8a5-7d9e477bd1f3
# 삽입 성공, UUID: f7059da9-462d-4b9f-a98a-0a9f335a08d0
# 삽입 성공, UUID: ab291a51-ea58-4b0c-b753-3cdf59b69392
# 삽입 성공, UUID: 26ce2620-ac41-4029-b0ef-61a3c12cbd82
# 삽입 성공, UUID: 8fe54b6f-777b-40e2-9029-0d77a655a3ab
# 삽입 성공, UUID: cd938138-1aff-43af-a582-ba9663d4f81c
# 삽입 성공, UUID: 7e8a2cfe-779f-4ebf-8faf-d46bc62fa9e9
# 삽입 성공, UUID: efe94509-bcf2-4cae-9135-369bf6906e8c
# 삽입 성공, UUID: 847d6038-21e9-434a-9739-85960a438907
# 삽입 성공, UUID: e22a8921-9581-436d-989d-5eadf5131f36
# 삽입 성공, UUID: ee720b57-2f6f-406f-a5d5-2f652cb7deba
# 삽입 성공, UUID: cd9bce82-613c-4147-a44a-0820d79d649b
# 삽입 성공, UUID: d563f238-4042-43f0-9610-70c0213be246
# 삽입 성공, UUID: 2d55ec38-ad4e-42a2-8900-9632b5cb5c56
# 삽입 성공, UUID: ef461b99-6128-43b1-b8c4-49c82f55c8a3
# 삽입 성공, UUID: b26c2342-3a8e-4f3e-a1da-508ddf4e0520
# 삽입 성공, UUID: dd29fcb4-5205-4ca3-b2f2-dbb2c3109762
# 삽입 성공, UUID: e0cfd035-3bc9-4336-8668-c9d5be33bbdc
# 삽입 성공, UUID: c20a536c-3b93-4e80-a836-69691445b029
# 삽입 성공, UUID: 4cbc4fad-6739-430f-85de-552b7b7966e5
# 삽입 성공, UUID: 340952f8-2f34-4328-b78f-f92cb972cfdb
# 삽입 성공, UUID: 881b595b-e065-480b-b273-b4b552585c82
# 삽입 성공, UUID: 96a7ee39-5673-45b6-9a0d-ff719ec27757
# 삽입 성공, UUID: f27a8687-cf4e-4570-8b3a-0139773000ee
# 삽입 성공, UUID: c7584c82-b4ea-45ce-92b3-710c5bd04e4a
# 삽입 성공, UUID: 128e3335-31b7-4add-b562-d030f31f2933
# 삽입 성공, UUID: d7b60062-b382-4c9a-8220-eec618a8287f
# 삽입 성공, UUID: a995157e-0805-42e8-abd6-f0429126bc45
# 삽입 성공, UUID: 9b8978d2-1b5a-4995-8044-3a9e00af66f6
# 삽입 성공, UUID: 0e95851e-a750-421f-9c58-a565ad67a4a2
# 삽입 성공, UUID: 147e55f3-651f-4d8d-946d-e41815fd6acd
# 삽입 성공, UUID: be57e2a5-cc92-4351-b54a-74264b3e0e6f
# 삽입 성공, UUID: 6d01cbf9-0350-4ca9-aa31-ece21d1cb420
# 삽입 성공, UUID: 839acee6-f754-4615-9192-4d4904cbe1c2
# 삽입 성공, UUID: 1f9dbc21-d6f6-4200-a4ff-ce417609c211
# 삽입 성공, UUID: 4e669890-2732-4718-b6bb-b3bd947ccbb7
# 삽입 성공, UUID: 73d684dc-3c8d-428d-8493-7ee82c58998d
# 삽입 성공, UUID: 10d70080-4e6f-4e84-b548-2335908e8e47
# 삽입 성공, UUID: 73901783-13e5-45cc-939a-c9ee6580af37
# 삽입 성공, UUID: 3e5f874e-e44e-45d7-9a6e-591654efc8f7
# 삽입 성공, UUID: 6da51833-3cdf-4d37-b8ef-24f5081b35a4
# 삽입 성공, UUID: 07717e30-b57a-4c99-9d74-f85e12821356
# 삽입 성공, UUID: 60424c01-5227-4ad8-a74c-4c1fb6024cc4
# 삽입 성공, UUID: d12b499c-55d7-4795-a90a-816893fe5a34
# 삽입 성공, UUID: 1061172f-07e8-49cf-9638-dc09e50f0899
# 삽입 성공, UUID: 7ebac2c6-33cc-4cd3-8843-51463a3e0e44
# 삽입 성공, UUID: 497a53db-7714-4efb-845f-92c008b003dc
# 삽입 성공, UUID: feca31e7-ef7b-4a0a-896a-ada491a52432
# 삽입 성공, UUID: f78a9685-9b0d-4362-a7de-97e89a064765
# 삽입 성공, UUID: 2a65fbd6-e771-4aac-845f-e0421a62dbd3
# 삽입 성공, UUID: b9a3195e-ad1a-41bf-bbb7-240b53fc008c
# 삽입 성공, UUID: 006ebf5a-68fe-4408-9b90-185c0425a4f1
# 삽입 성공, UUID: 4412150e-8dc0-471a-935e-aa3fb16bbc85
# 삽입 성공, UUID: 0d87a3f9-009b-4197-973b-837ff4e79241
# 삽입 성공, UUID: fccb101d-b4cb-4fce-b741-12e4b9e806cf
# 삽입 성공, UUID: b2052bff-66ef-4704-9838-81562a9721f7
# 삽입 성공, UUID: 4d882b05-d3f2-4134-8f39-c343a7e6af99
# 삽입 성공, UUID: 4c4d0c4d-8123-42bd-a334-8359cebffdda
# 삽입 성공, UUID: a9550418-db99-4e7e-a3a6-996a80bca85a
# 삽입 성공, UUID: 0db66e0e-c3f5-4798-9df8-a7da387874dd
# 삽입 성공, UUID: 1b4cebec-857f-4a8e-8ff2-a58f45d26580
# 삽입 성공, UUID: 1132506e-368e-472f-9ad0-32a7b77beeaf
# 삽입 성공, UUID: 2e8f6d2a-8dd0-4020-bb63-fcf28c2524f0
# 삽입 성공, UUID: 51082dca-c901-4ebd-b2b9-ae7158e9ebf0
# 삽입 성공, UUID: d65b9ce4-8423-489a-af25-e5a3eeb3a707
# 삽입 성공, UUID: 46a0f557-fb90-49b3-ae01-725ac46f1ace
# 삽입 성공, UUID: 38518992-13ef-479e-9d23-dd2ea44659b6
# 삽입 성공, UUID: e550b019-b95c-411b-8b4d-4ae348c68af7
# 삽입 성공, UUID: ba616f63-cc17-4757-9b10-c6351437d711
# 삽입 성공, UUID: 396a4928-c03b-4660-b66f-2e0ff3c356ff
# 삽입 성공, UUID: 6bf52fc5-60c6-4ffc-952c-f2a1e5e317dd
# 삽입 성공, UUID: 9aa63236-2521-418b-96e9-b34b41b724e3
# 삽입 성공, UUID: ac0f9115-be0e-46e5-b888-85f786352a4c
# 삽입 성공, UUID: 5257cfc8-3a8a-4c89-a9ec-e852f7680ba4
# 삽입 성공, UUID: 94022bbf-b3b8-450b-bb02-cdd30bcb98dd
# 삽입 성공, UUID: 3c3b83bd-7701-4e31-aae7-debb6f0261c7
# 삽입 성공, UUID: 37622a83-4522-4546-b1f2-f35604bd54c6
# 삽입 성공, UUID: 93e01521-8f5b-4745-949a-5bdcc20b97de
# 삽입 성공, UUID: 82bd2eef-54ac-4c70-89d1-dea8457a7cd5
# 삽입 성공, UUID: 5177165c-3abe-4516-9d30-777cd2cf4f1e
# 삽입 성공, UUID: 841ac8b6-00da-4926-a98b-37df46bd93db
# 삽입 성공, UUID: 3888638f-1e6b-4966-b8fd-3b5bf95231d5
# 삽입 성공, UUID: 86205821-d2f2-443b-b2f1-7731f6e47a3a
# 삽입 성공, UUID: f027eca4-9cb9-4ab4-949f-49164047f0bb
# 삽입 성공, UUID: 155c74c4-ef57-41bc-8cf9-ae43616a13b1
# 삽입 성공, UUID: 8beeb394-ce3d-4716-8e62-c8ae8e5eebf1
# 삽입 성공, UUID: e6fde92c-a645-42ab-a83c-1909ca785a72
# 삽입 성공, UUID: 79534721-ea9b-465d-bfce-223370072194
# 삽입 성공, UUID: 13831a69-f704-4133-9e6f-94078056ea0d
# 삽입 성공, UUID: 47129636-08c4-4ef3-885e-a917235eb8d0
# 삽입 성공, UUID: 881b64c9-faff-4e9d-a6ef-61b826ec2764
# 삽입 성공, UUID: 02c2788b-6f57-4eb8-8df3-81a5c9011df8
# 삽입 성공, UUID: 748e6cec-719b-4d15-921f-8da9473b43a9
# 삽입 성공, UUID: ad935abb-50be-4094-8dbd-f26ee2e68b2c
# 삽입 성공, UUID: 3f18dd9a-d790-459f-a02f-67e667868262
# 삽입 성공, UUID: a8eb6ab3-c36b-4b77-b6aa-333e39d6d059
# 삽입 성공, UUID: 8434af8f-7c53-4bc5-85df-7d2700c9106d
# 삽입 성공, UUID: 39aaafcc-9f00-4fc8-8c32-31e8ac59bb1b
# 삽입 성공, UUID: 8f5c068c-8f77-4825-b41d-b1860533df2b
# 삽입 성공, UUID: 4048dc1d-8cfc-4dd9-a561-f7d0a075dbed
# 삽입 성공, UUID: 20a8fd6b-6ab5-4647-a1f7-4c27f15f4920
# 삽입 성공, UUID: 36cf0599-5c6b-4339-a4de-6391c8d549c7
# 삽입 성공, UUID: 6326040e-78b9-4400-9cbc-04a9fde273e2
# 삽입 성공, UUID: c9c39df5-cb0b-4320-a6a3-89fbb3ad209c
# 삽입 성공, UUID: e362c842-9e75-415b-b560-4d447d4342c8
# 삽입 성공, UUID: 5cab7da7-5065-4a0c-8b9a-9090c2641040
# 삽입 성공, UUID: 11ec8330-3d5c-470f-ac6f-27909caba0f8
# 삽입 성공, UUID: 64e2dc97-180e-4e91-89fe-267d0bb76e58
# 삽입 성공, UUID: 58a38346-f20e-4c81-bd14-fd4c9d948ccf
# 삽입 성공, UUID: c62fb6c2-60f7-46c5-8377-95dc9c9f69a6
# 삽입 성공, UUID: e997ae85-6f6f-4fd1-a113-0e4b8d8bdf97
# 삽입 성공, UUID: 12922cf2-dcf2-4b99-a98c-52c3994b05a3
# 삽입 성공, UUID: 1fcee4b5-d1e5-4182-b829-2fe55e209854
# 삽입 성공, UUID: 7726fddb-e2f8-46c9-9d8e-393f0c2a5603
# 삽입 성공, UUID: eb40a6db-4c79-4ea9-802a-3808060e0799
# 삽입 성공, UUID: f61abfa3-86c9-4944-acad-39a9580e585d
# 삽입 성공, UUID: 21465f03-f865-4501-826f-36cc4fff592c
# 삽입 성공, UUID: 00926708-6091-400f-875e-3efe0d7d2acc
# 삽입 성공, UUID: f1748793-2ada-483c-be07-bfcd79f40f4e
# 삽입 성공, UUID: 2a483d3d-78dc-472f-a15c-90ab024b4d36
# 삽입 성공, UUID: c1633fc6-c121-4f3c-b9ef-9061168dff1f
# 삽입 성공, UUID: db0b3484-8909-4bc6-b495-df126fc97cb3
# 삽입 성공, UUID: 74134f8a-0aeb-4658-a45c-423ae34d8a3f
# 삽입 성공, UUID: 9806e253-c210-4249-8470-eb7b4a8ea72d
# 삽입 성공, UUID: 4c8e9015-8c79-429d-bf02-e05b622868ce
# 삽입 성공, UUID: 6c397bfc-e8bf-4c83-a3ee-7c776d154063
# 삽입 성공, UUID: f3a8186a-ab99-43cf-a190-e81d84355e81
# 삽입 성공, UUID: ff567157-39e7-4df6-832d-947c59637ea8
# 삽입 성공, UUID: e8ea9edf-f33d-4a0a-a0de-3c3be3610abd
# 삽입 성공, UUID: 49122a5a-1c3f-4c70-a2d7-cbe4c3c1e2e8
# 삽입 성공, UUID: 0f841325-2045-47a9-b2eb-f5280ccbc477
# 삽입 성공, UUID: 54a1c5ca-1231-4970-9b70-cf9f45534d15
# 삽입 성공, UUID: 263ade16-fa10-4b89-a674-fde37ace56e6
# 삽입 성공, UUID: e13199f1-9bc2-4f08-af6a-d30a68a105a1
# 삽입 성공, UUID: b1d982f4-0e2b-424e-b487-fa05d378ea17
# 삽입 성공, UUID: 2f369d14-93ea-4494-899b-634306567b4b
# 삽입 성공, UUID: bd5818ec-79c4-4e23-8ca6-77b8a37d283e
# 삽입 성공, UUID: f489bccb-546d-43b9-9464-1a0a0feb2a19
# 삽입 성공, UUID: 518c035d-93a6-4670-ae7b-04876f37fd9f
# 삽입 성공, UUID: 03e12a7c-84ca-48e8-9467-ad3c4bb99805
# 삽입 성공, UUID: bbd26ef8-61d8-4faf-874c-17fbf6f5587e
# 삽입 성공, UUID: 35f29c6a-5849-48d1-afe2-b1db220cd34a
# 삽입 성공, UUID: 4f2bb03a-6d01-4ace-b6b2-9a416ef0bb5b
# 삽입 성공, UUID: 3e24da3d-d946-46f8-bb48-a1a4cf98bd09
# 삽입 성공, UUID: 8010fb23-7526-44fa-91c6-767af2988a3c
# 삽입 성공, UUID: 8f9dc759-320a-449e-abdb-f3309cdc3f27
# 삽입 성공, UUID: c172f0a7-9f27-4fa9-90ef-831b5ea644c9
# 삽입 성공, UUID: d21f0969-49d1-4691-b226-d5304ee31a92
# 삽입 성공, UUID: b486da48-f822-43bd-8b59-eca430835462
# 삽입 성공, UUID: 8736f4af-3ed4-49fe-aef8-f53d98f5f7e5
# 삽입 성공, UUID: 24a8af51-7c3d-4c8a-b0ba-3953a7364fed
# 삽입 성공, UUID: daf9ebfe-7220-4266-a43d-560e21804607
# 삽입 성공, UUID: 5bf012df-dd97-40a9-86ed-4342327b2a86
# 삽입 성공, UUID: 6557cfb8-01fc-45a7-81a9-f04c6e91bec3
# 삽입 성공, UUID: 1a039cb7-e4c5-4a62-9920-13e594d4b15f
# 삽입 성공, UUID: 16a1035c-b258-469b-ac75-17ffab7a6b78
# 삽입 성공, UUID: 500551fd-4b2e-47a6-9715-36d3d8a26d4e
# 삽입 성공, UUID: fa124616-2711-4e90-9d6c-3c3ca5311e81
# 삽입 성공, UUID: d9aaf881-857d-4ce5-be53-df9a1b5f714f
# 삽입 성공, UUID: 6a9ae903-f4e6-4f83-8271-923fa7f1ea4f
# 삽입 성공, UUID: c6369ba1-d216-46cf-aa6e-761c1bf16c7d
# 삽입 성공, UUID: 158f7612-4678-4071-8d93-1d4d48dfa74f
# 삽입 성공, UUID: 5f9ad79b-4f79-4333-90ae-7939c41b00bb
# 삽입 성공, UUID: 519eb6e4-49ba-4654-a462-b5983eddff32
# 삽입 성공, UUID: 784c3a4d-b283-42e1-8f27-7da16da9edbf
# 삽입 성공, UUID: 6931e3e3-e52e-429a-819f-1175ee0e78ff
# 삽입 성공, UUID: db8e0489-242f-46bc-a1d8-dbe0eaeebf0e
# 삽입 성공, UUID: 2c7d5928-b70f-4b3b-ad9b-1260efb3c732
# 삽입 성공, UUID: 6e420db2-48ed-404a-8436-2763aab511ac
# 삽입 성공, UUID: e538b8c9-4a6c-456e-b7e9-22865f3f8858
# 삽입 성공, UUID: 4591efc3-8f68-496b-82d9-3aed44a9e8f7
# 삽입 성공, UUID: 670bf845-1ed4-40b4-b131-5df9c2f18cfd
# 삽입 성공, UUID: 26d7a402-0ebe-41aa-8e19-5793b57e6970
# 삽입 성공, UUID: 88585b4e-5404-485a-8feb-9769b158c67c
# 삽입 성공, UUID: 326a5fd4-c55e-4328-b67f-6c2de1f1ba49
# 삽입 성공, UUID: df324df0-2550-44ef-81aa-693c9f53d505
# 삽입 성공, UUID: 3042c854-f4a1-44da-ac2b-4a2058069475
# 삽입 성공, UUID: 63241aa2-0639-4aac-a51e-16ccd392cefc
# 삽입 성공, UUID: 958321fc-1d3f-4329-9aca-b9547a7c60fb
# 삽입 성공, UUID: 073515b7-ace6-4cf7-b7e1-524b7b3e19e6
# 삽입 성공, UUID: 7e9cdbe6-bbba-4880-aaa2-a93af143c7fb
# 삽입 성공, UUID: 736060fd-a77e-4e6a-b161-1120420c1da6
# 삽입 성공, UUID: 0f942e13-6ce2-44d2-aba8-2af5e103b232
# 삽입 성공, UUID: b44ce19f-a5b5-4a48-b7ab-7f511c144798
# 삽입 성공, UUID: 1726b49b-32e9-458b-a48f-d97f324ff17d
# 삽입 성공, UUID: a0963d73-f45c-4abc-99ea-7021cb7db1b6
# 삽입 성공, UUID: 902a91b9-5c3f-4351-9ce3-fef5167c9d89
# 삽입 성공, UUID: 6321f1ff-b0dd-4dbc-a57b-0205920a7a15
# 삽입 성공, UUID: a8e7f5b2-ace2-4ac8-a771-2e030c087a8c
# 삽입 성공, UUID: 08587702-2ace-40e7-bb4c-c6df1877d8ac
# 삽입 성공, UUID: 26c6f80c-3e44-40fe-96ae-a980f647148c
# 삽입 성공, UUID: 05ad063e-df79-4b11-b681-dca16d3a99fd
# 삽입 성공, UUID: beda6d59-c117-4e96-9972-41acd60ee190
# 삽입 성공, UUID: 5c9cbde4-9bf0-4bcd-99e8-3afe432963c3
# 삽입 성공, UUID: 001f4743-85d7-4689-8fd5-aa39f2a6ee43
# 삽입 성공, UUID: 3a94c981-c228-4484-bfe2-f90d5f5e69c4
# 삽입 성공, UUID: 5c19b4c9-1484-4b94-9614-78487cb83f84
# 삽입 성공, UUID: 06d70c9f-e0dd-46f4-9cba-b1a31506ce27
# 삽입 성공, UUID: 15edcd7f-6dde-41b8-a072-77609f9c9f62
# 삽입 성공, UUID: 46bc3661-bb39-4eb5-bfa2-85dee7428ace
# 삽입 성공, UUID: 87363823-5c1c-43d4-9c9b-597ba297e2f4
# 삽입 성공, UUID: 255da6d7-886a-4517-8cfb-6eaf4553f06f
# 삽입 성공, UUID: d1aec66e-6284-4347-9afa-c9b084dd6765
# 삽입 성공, UUID: ac8a0455-79c4-44b4-960f-8d1a3632613f
# 삽입 성공, UUID: 0f7cb042-e950-4599-aca4-aa92dc068bac
# 삽입 성공, UUID: 4ab8d541-976f-4e52-9cac-19f0565958eb
# 삽입 성공, UUID: d08b7192-19a4-44a1-89ef-e1434ce36651
# 삽입 성공, UUID: 241928c5-8d1a-4e5f-beec-d6736f7d6a0e
# 삽입 성공, UUID: 82152f44-5885-458c-99ac-1df185dd28c0
# 삽입 성공, UUID: 0a5cc0d2-67a6-4d0a-ae0d-d18a3f028e34
# 삽입 성공, UUID: fba98f71-479a-49c1-96aa-007f2acdde7d
# 삽입 성공, UUID: 24fafbb1-e3d4-4183-8327-5ba6cb3325c3
# 삽입 성공, UUID: 36832f25-d171-43b3-857b-a04f73cf2429
# 삽입 성공, UUID: 1cff0587-8918-4186-8104-5c37a95d5bad
# 삽입 성공, UUID: f6c46e80-5838-4d31-910c-0a576e7d0189
# 삽입 성공, UUID: 2f0ad5ce-0c68-4bc2-80a0-54cf7732b9b2
# 삽입 성공, UUID: aec1c985-b696-4217-8923-9e060d4da677
# 삽입 성공, UUID: dbaf6b18-7bfa-44e1-9d13-f4a9f9577521
# 삽입 성공, UUID: b6009065-dd47-447d-b7f6-3de83a6d909d
# 삽입 성공, UUID: 321085be-262d-400f-9e9e-e17d57db41d8
# 삽입 성공, UUID: 1682f538-7ef6-4b94-a570-822f1eeea37a
# 삽입 성공, UUID: 61cdc7cf-38e0-4d1e-9b5a-54b3d9deda28
# 삽입 성공, UUID: 86761c42-8760-45b2-b18d-1b6d34f139ef
# 삽입 성공, UUID: 316be920-ca1f-4177-bf57-7749ade48b05
# 삽입 성공, UUID: d231fca1-607f-403d-9f7e-e7a5bf2f71f0
# 삽입 성공, UUID: b016c276-8bee-4cf4-a946-96a9ff1620e8
# 삽입 성공, UUID: 9944588d-ee51-4276-be22-9352454f85f1
# 삽입 성공, UUID: d4278b67-5237-43e5-876c-31facc72c01a
# 삽입 성공, UUID: 3643f066-1b3b-4707-8dfa-f32d4a29dc1e
# 삽입 성공, UUID: b7206314-6f2b-43f1-b588-0e968e94fa35
# 삽입 성공, UUID: 6c28b916-0ac5-46f1-932b-017f8105701a
# 삽입 성공, UUID: ae0640f2-1c79-4fd0-b0ca-a1205cba1ab0
# 삽입 성공, UUID: 939d7a99-00fa-45df-9a8d-01be1582e12c
# 삽입 성공, UUID: 26d6e91b-acc7-4572-b6cd-b290dc92ca78
# 삽입 성공, UUID: 72d7c242-52ff-404f-9430-eba295b2918f
# 삽입 성공, UUID: 6d298528-6a58-494d-a853-35b12b4e4515
# 삽입 성공, UUID: ad870237-4d6f-4677-aea6-541ae24c8f68
# 삽입 성공, UUID: 7c6ed395-9fd9-4e7c-8263-e9dd1b79111c
# 삽입 성공, UUID: 34f8c2a9-c500-4576-8a3f-b24a2b98fc0e
# 삽입 성공, UUID: 53dbd2cd-4f83-4db7-a1de-a526dad5621f
# 삽입 성공, UUID: 379f7fa7-7229-45fa-b3f4-14c88323777b
# 삽입 성공, UUID: 783d0e66-679c-4713-a049-3a9094814033
# 삽입 성공, UUID: aa2041f1-cdaa-4057-aae6-23c438c3290e
# 삽입 성공, UUID: 1ae1a142-7bbd-49ba-9641-760a124aa8e0
# 삽입 성공, UUID: 275495cc-6b62-43d4-805b-1f151015b94b
# 삽입 성공, UUID: 7971d699-aaf3-4c79-8888-8dc99772b6c4
# 삽입 성공, UUID: 9af7142c-a449-4900-b8b8-8a0ce3d5ea8d
# 삽입 성공, UUID: ba0e6a50-4ec2-4c01-8ba0-c9cbd0e76c5b
# 삽입 성공, UUID: 3ae2570d-98cd-4f17-97af-92f4e9c73595
# 삽입 성공, UUID: 703535cd-4cea-479a-ba4b-8bd5da391dae
# 삽입 성공, UUID: 1a59c4c3-c3cf-468e-965a-af5f0cdb9abb
# 삽입 성공, UUID: 8d38b4ed-45b2-4eae-8852-66f98613e10e
# 삽입 성공, UUID: b9e9700a-7e58-4178-a69a-b08b08e51d29
# 삽입 성공, UUID: 176f2d0b-941a-4d96-8d3d-eb62f8637b94
# 삽입 성공, UUID: 06b2ec7b-eee3-4d35-bd87-d6da4243c6c6
# 삽입 성공, UUID: 10eb3c92-ddb1-4944-8784-a10af34f6b91
# 삽입 성공, UUID: 5032cc4b-8da4-4a1d-a16b-1172479f42ab
# 삽입 성공, UUID: 8fe489a6-8594-43e2-baf9-ee2d3ffc245f
# 삽입 성공, UUID: 414b143a-ca4f-4829-ade2-fe342e5d392f
# 삽입 성공, UUID: e2d35fa2-7858-472e-b6a5-73072b0165a8
# 삽입 성공, UUID: de54d530-a493-4a71-b9bf-f0ee749d2f30
# 삽입 성공, UUID: 5442d27e-9a51-4b6e-ad29-437c6444fe0e
# 삽입 성공, UUID: fa1fd030-8c6c-477e-9014-7d875724686f
# 삽입 성공, UUID: 81eea5d7-8cd8-42eb-b5e4-123435884823
# 삽입 성공, UUID: 34c47bbe-c6be-4ac0-bb32-d98dd1d84048
# 삽입 성공, UUID: 29a66532-4316-4d71-b4c8-2a20a9d5e2c3
# 삽입 성공, UUID: 0ae034d2-79f0-4a93-88d0-1439ed83e040
# 삽입 성공, UUID: 76407140-c5f6-4cb9-9c73-85b2476146cd
# 삽입 성공, UUID: 732f2012-4870-4883-925d-504ce4dd3c0c
# 삽입 성공, UUID: a6d5d09b-70c4-40ec-8d52-5ab0e04b5eae
# 삽입 성공, UUID: 0ebad0c5-ef7d-4c98-9b94-42041026845b
# 삽입 성공, UUID: 3fba9d15-c38a-4602-9216-b6f14a95c56b
# 삽입 성공, UUID: b5f3cf20-bf0e-45b3-8d3a-8fb693148697
# 삽입 성공, UUID: 56980148-5b9c-4c36-946d-3c8b51fd8d43
# 삽입 성공, UUID: 265be01f-d422-4e83-a36f-f865f61fe8d4
# 삽입 성공, UUID: 16ebfbfb-a381-4089-b81e-d8bd08cfddef
# 삽입 성공, UUID: 67537d34-cde7-4aa9-bb81-b9c78cec92ef
# 삽입 성공, UUID: d8c9d0d0-9745-455c-9d89-6fc31cad625e
# 삽입 성공, UUID: 75d3254e-dac5-4e32-a3ac-42023518d3f1
# 삽입 성공, UUID: 8f53f499-152d-4dac-819c-2cc254599034
# 삽입 성공, UUID: 07367c0e-1f81-4802-ba71-4cf4d02ba00d
# 삽입 성공, UUID: 3ab3199e-3c3e-42c6-a01f-9ca74fbee614
# 삽입 성공, UUID: dce041e9-72b7-4c1e-b204-c1ba8c7fd885
# 삽입 성공, UUID: ad472ec3-f0d1-4b0e-96c3-fc25192bc758
# 삽입 성공, UUID: 07393c89-6ff1-471e-b153-ac68c4858cae
# 삽입 성공, UUID: 1ae982e8-6c7a-4475-9f99-11bca8a7a72a
# 삽입 성공, UUID: 3cab91ea-aca2-4eb7-9b07-72fcdcbdb050
# 삽입 성공, UUID: ba4fb48a-9772-4da2-852f-ec49358e6476
# 삽입 성공, UUID: c82964b9-fde6-4afe-b8cf-9da6033ad0f2
# 삽입 성공, UUID: 8b022eb0-93ff-4613-ac05-154384b5b241
# 삽입 성공, UUID: fd68704b-89aa-460a-9193-995a6f4b6d5a
# 삽입 성공, UUID: 8194c6de-5490-4ef9-940d-2cd00f563394
# 삽입 성공, UUID: dc3e2d14-a6d3-4051-9773-ab2f5158a6a7
# 삽입 성공, UUID: 94adf09f-6a8a-4bff-ba71-d93886f47409
# 삽입 성공, UUID: ff74ecab-1dcd-4916-b2d2-da5cfdbf0657
# 삽입 성공, UUID: 4c2f8286-49e2-40ad-8fee-8a41e3977505
# 삽입 성공, UUID: c7120fb1-7698-4c93-a0c3-069c3db20af2
# 삽입 성공, UUID: 3028d6b8-567f-418f-968c-fc76673aef8e
# 삽입 성공, UUID: 092c6a8d-6bfd-4be3-8773-3ea589c5a3e1
# 삽입 성공, UUID: cd42c56a-63b3-4387-bbf6-69a93f7ec975
# 삽입 성공, UUID: 377bf5b8-ec26-4765-beea-8eaf732e5cfe
# 삽입 성공, UUID: 56e4b3f5-e3ae-40fd-b010-99ccd0b37d77
# 삽입 성공, UUID: 1cab2098-d967-435b-8f84-f071e3614134
# 삽입 성공, UUID: 966d4eb0-639a-42c0-940e-32c45f080000
# 삽입 성공, UUID: 91ae076a-5f51-4623-9521-459d3a8a73fa
# 삽입 성공, UUID: ffd5d677-34fc-4cd9-b95d-a02cacd998a4
# 삽입 성공, UUID: 61230066-b129-4f4d-b51d-21d04afec9e8
# 삽입 성공, UUID: 86cf0e36-2f7d-417b-b2ff-b37808ed1e80
# 삽입 성공, UUID: 0ac291ba-f1b8-41c3-a389-96b52b4baeb7
# 삽입 성공, UUID: c43d28e2-292f-4570-a6b0-87733d461db7
# 삽입 성공, UUID: d046ab5f-a2bc-4f11-ba34-0971f5c98e7e
# 삽입 성공, UUID: 7e52e5e2-df0e-4659-86b7-6a417136e1b0
# 삽입 성공, UUID: 07050b8e-fe6c-483b-aa47-59a873a4be55
# 삽입 성공, UUID: a8064808-f678-4c8e-b10a-bb6243856471
# 삽입 성공, UUID: 972affa3-381e-4d66-8a67-3935ec9f40dd
# 삽입 성공, UUID: 192034c0-db7f-4dc0-8e21-3dad69ea9bce
# 삽입 성공, UUID: 3cf3336e-f3af-4169-9ac1-4ee175062c4e
# 삽입 성공, UUID: ff35bc50-6178-4e1f-9ef7-14d9ed1fecf6
# 삽입 성공, UUID: 8963e059-22f5-4ae0-a7c4-7f4354082482
# 삽입 성공, UUID: c962876e-89c8-41ae-b871-e04d075ab3c9
# 삽입 성공, UUID: 094929fa-a5de-49ee-8855-991464e63e55
# 삽입 성공, UUID: 1ec88b88-1190-485c-8f29-3f53f8c0dc2e
# 삽입 성공, UUID: a4564311-38c3-480b-a59a-95f2576477bb
# 삽입 성공, UUID: 1c3d0b85-038d-411c-bc44-b3adbe03643c
# 삽입 성공, UUID: 30d4d709-dde8-47fc-bb4e-1e4027977fb0
# 삽입 성공, UUID: 6f5b1c9d-8486-4f1c-acad-cc2fdcfff584
# 삽입 성공, UUID: a22a1d3f-479f-4d68-95ac-e215be1f7ec9
# 삽입 성공, UUID: 3cb10dca-8b41-49fd-9051-5498cf8d08c6
# 삽입 성공, UUID: 0ffc6759-e6e8-4862-ba24-3375f632551b
# 삽입 성공, UUID: ee1d0ce8-8196-42dc-aeae-061d62a7532c
# 삽입 성공, UUID: 557eb30e-da2a-4cc7-9106-8005556a56ef
# 삽입 성공, UUID: 5c7accd4-402e-4a2e-b5ac-8509ac6d1422
# 삽입 성공, UUID: 74bce9db-8813-4946-8190-2a8d2f4fe19a
# 삽입 성공, UUID: ddad1123-33e4-4a97-b6d0-c3233a614515
# 삽입 성공, UUID: ad477af9-70bd-415a-80ff-cf4957c3d879
# 삽입 성공, UUID: 5b520158-02d6-4b17-a646-87ab3b0f4ed7
# 삽입 성공, UUID: b4daa8a1-7ea2-4445-a7d9-b5177e8596d7
# 삽입 성공, UUID: 43b14c42-8bfa-4342-8a0b-42aa53273e24
# 삽입 성공, UUID: 84795534-b0b3-4ff4-b20c-c52506e2bfec
# 삽입 성공, UUID: 227b937d-5720-45cc-9dfd-4fdffc49e841
# 삽입 성공, UUID: 548d20b0-c4d2-461a-9453-c8506041b597
# 삽입 성공, UUID: 8943b214-e85e-45c1-9bc4-68551c8eff46
# 삽입 성공, UUID: 2ee85e28-06b9-406b-96f8-11c170bebf57
# 삽입 성공, UUID: 7d16864c-fb55-43d6-a648-6b87f8557047
# 삽입 성공, UUID: ca6e342a-285a-4222-a80f-50422227a00d
# 삽입 성공, UUID: 404003e8-f81e-4ac9-b4dd-706e96f6d27e
# 삽입 성공, UUID: 7214a054-3d16-4910-b331-c850d53ab8b2
# 삽입 성공, UUID: 7a8a0dd9-00dd-4b1a-bbe9-d00a7fdf85f0
# 삽입 성공, UUID: ae298a52-55b5-4d05-a845-42e9efba89b1
# 삽입 성공, UUID: 85764a4b-de4d-47d2-85cc-fd96c5b4f033
# 삽입 성공, UUID: df7bd0ae-3529-4602-81e3-fcea0783123b
# 삽입 성공, UUID: 487b036a-fcbb-432d-a68e-021b66d7b152
# 삽입 성공, UUID: 3c6df529-aaee-4091-8b41-f72095d15584
# 삽입 성공, UUID: f32a4382-4724-410d-bc90-44dccbe75dd6
# 삽입 성공, UUID: e197f909-8e4e-4e0b-be32-b1f0f844f293
# 삽입 성공, UUID: 7842206c-c834-4b31-89ca-79fa4e9c4dfd
# 삽입 성공, UUID: 9c48be44-1d2f-4543-ba68-f35b77024d44
# 삽입 성공, UUID: 38069c13-55e5-444d-b5b1-0762b2e4f275
# 삽입 성공, UUID: 7aae1ddc-d726-4589-885a-aad26eb518f7
# 삽입 성공, UUID: 0234453c-a07d-41c0-89dc-580eb1dd0bb8
# 삽입 성공, UUID: fb91efdd-f52f-4f31-9eeb-8e7cf3567d90
# 삽입 성공, UUID: 63acaadf-fe0f-4981-9c0d-26b0c80d0114
# 삽입 성공, UUID: bb19a537-b0a3-4ffc-8766-a1a6dcce2f40
# 삽입 성공, UUID: 2a2cc41d-4a06-4a91-8c77-57036e9af8cc
# 삽입 성공, UUID: 73b82a54-45e9-4ab5-b334-08d459e7b1e7
# 삽입 성공, UUID: f63d81f7-bcf2-46e7-b692-6003b966d2c0
# 삽입 성공, UUID: a30bc145-f38c-4bd3-9e13-085c2f7eb699
# 삽입 성공, UUID: ff6850d8-3e87-4e95-8a04-9acdd363dca0
# 삽입 성공, UUID: 29eeb6c8-f5c2-40ef-bc93-33a34f6bf710
# 삽입 성공, UUID: 30e5932e-a263-4ac0-8f40-0e12c82ec2cd
# 삽입 성공, UUID: 409867c3-2075-49d8-8348-dc76442b8974
# 삽입 성공, UUID: d80b0c9a-5cf1-4bf1-8358-ae3bfe079fd7
# 삽입 성공, UUID: 6faf3c6b-e2f3-4754-a2ee-deb86bd3a56c
# 삽입 성공, UUID: cd0abebf-5f93-498d-b085-e3f1e24a337d
# 삽입 성공, UUID: 9f854f49-8110-4664-a790-5e04a39f96b6
# 삽입 성공, UUID: 48c60062-961a-4717-94fb-df3086a2afa8
# 삽입 성공, UUID: 9a489e8d-f1e6-4dde-b53b-091f4466fb91
# 삽입 성공, UUID: 9e32a56e-f191-481e-b26d-5f7eb8f425a6
# 삽입 성공, UUID: 0b7eee32-3df7-4f53-9420-e5e6b8a16bf1
# 삽입 성공, UUID: 3d7a9d6e-a7a7-4c18-aea1-1611a215ae3d
# 삽입 성공, UUID: f7acb5c0-fe15-4a24-8cca-427c9107518c
# 삽입 성공, UUID: feef445c-bbd1-4be1-adbe-5e49f002f2fc
# 삽입 성공, UUID: f86b73c6-08b4-4390-b989-594c5bf21869
# 삽입 성공, UUID: da445335-8b81-41e1-a067-fb9e4e7ac385
# 삽입 성공, UUID: 9481c3d1-dedd-4627-b1e0-312673116bed
# 삽입 성공, UUID: 35d7089f-49d3-437d-b765-6cadab839869
# 삽입 성공, UUID: 7d938df6-96e4-4b7b-8e43-f57a03db0613
# 삽입 성공, UUID: 95dfd4cd-08d9-4c4b-aed3-9e579b93d29d
# 삽입 성공, UUID: 0be2629b-f206-4129-9680-fe31fd14f2aa
# 삽입 성공, UUID: 59bfdb1e-320c-4672-aaf6-1b5d8b4da039
# 삽입 성공, UUID: 44f4dbca-ad49-493f-83d6-218fc0f822a9
# 삽입 성공, UUID: 45157660-c2c0-4c9f-b9ce-961aa3cae678
# 삽입 성공, UUID: 1d6ceddf-73d8-478a-81a3-49a1e335e27d
# 삽입 성공, UUID: eae6ea7c-feaa-419f-95a7-36eba16ba3c0
# 삽입 성공, UUID: 6f0e3296-0df7-401d-93ef-3ff58e13bf00
# 삽입 성공, UUID: b6c9c1a5-3c63-4231-893c-33bccd95a8d4
# 삽입 성공, UUID: 8c57b85a-38c9-47a9-9682-1b79bfb947fb
# 삽입 성공, UUID: f8188448-4ac7-4e94-bb05-a4789dd34c00
# 삽입 성공, UUID: 3ade7302-93ec-4bb2-8219-e9c245918409
# 삽입 성공, UUID: 44228fd7-b842-4a2f-83f2-f42258004e29
# 삽입 성공, UUID: 97fab0a5-3944-4ed6-86ca-6504af9165fe
# 삽입 성공, UUID: 827ddaf1-ec80-409a-bd5c-93cdfde46061
# 삽입 성공, UUID: fd3007e3-a5b6-4e4f-8e92-dbf88739d370
# 삽입 성공, UUID: 84a379b3-ef26-4c0d-a64a-6b7a8de099ec
# 삽입 성공, UUID: 7f4d1935-5afe-4e07-96c7-fde6e71fee61
# 삽입 성공, UUID: 3a6bcb97-7520-4bba-a09c-369c347b8ea2
# 삽입 성공, UUID: 3cd5910d-be91-4169-b37f-b1decb9869ec
# 삽입 성공, UUID: ecd44f6a-1a91-4341-afb6-38061647a469
# 삽입 성공, UUID: a2496c6d-3add-4f4b-b5a7-f73f0fc9e18a
# 삽입 성공, UUID: eeab773e-6659-48b2-9fa4-8122351d9bb6
# 삽입 성공, UUID: 37a07713-14b5-4e66-ab80-74eb6b79bb84
# 삽입 성공, UUID: d54180ed-af4c-447e-bd4f-1129b23c507a
# 삽입 성공, UUID: 0f9f9da1-645d-40aa-a244-91078a7b1390
# 삽입 성공, UUID: 8fe80293-9dd3-4ab8-a3c3-cb24369d1e3e
# 삽입 성공, UUID: 7e9c7c8d-66ac-4200-9467-3d868db64ac0
# 삽입 성공, UUID: a916573f-7de7-42b1-bdb1-66ecef2fa310
# 삽입 성공, UUID: c4f2ff41-ad23-4d6d-b2ae-ce513f9d1444
# 삽입 성공, UUID: dbea3868-5378-4a83-bf7d-5bdacffc60cc
# 삽입 성공, UUID: 1aa7ac51-5665-4f48-af3e-5b32e83b004f
# 삽입 성공, UUID: 458fed81-8e42-4547-8749-8a7bca206a8a
# 삽입 성공, UUID: 5636461b-ee52-4386-8a9f-16aec83d365e
# 삽입 성공, UUID: ee9879d4-b5d0-4e4b-9a5b-559ba985e51f
# 삽입 성공, UUID: 248b2f12-7228-4b15-b7e9-740fac3a3aa4
# 삽입 성공, UUID: b8f252ed-0091-457e-b64a-14952c2fcd89
# 삽입 성공, UUID: 0236a316-f2d4-4c49-8194-2d1f58e2e666
# 삽입 성공, UUID: 36587b29-085f-4a93-a9b5-466111866ede
# 삽입 성공, UUID: 0c6fcc2f-93a2-48e5-87f6-ff1b675b2edd
# 삽입 성공, UUID: 1c505fc0-a922-4c73-8c9b-d28d540d989c
# 삽입 성공, UUID: 674c60c4-9728-4809-b600-1dd8ab34a9e7
# 삽입 성공, UUID: 0bae4ddc-ba0f-4206-b364-c5e2ec9b4988
# 삽입 성공, UUID: 62488ccc-6883-48f6-a89d-4f4a252e9467
# 삽입 성공, UUID: 830d7996-f838-4250-8e16-8475cd1f3d43
# 삽입 성공, UUID: 7889c407-8d5d-483a-881a-0c023b083448
# 삽입 성공, UUID: 7fd62fe3-5c33-416d-af18-cd66e4d51aaa
# 삽입 성공, UUID: 097a112e-3a0c-4145-9a3e-0ed9b5852dad
# 삽입 성공, UUID: a660a39b-1e17-4a23-be27-53f29574e034
# 삽입 성공, UUID: d2d8c039-329e-49be-8408-7b52c1d01abe
# 삽입 성공, UUID: c71da062-dad2-4afd-b1ea-4d226d77981c
# 삽입 성공, UUID: 9d95b06a-d412-4680-a2e3-59ba2940b186
# 삽입 성공, UUID: 08c2cd49-a287-4bcc-ab57-d7a98c0cadd3
# 삽입 성공, UUID: 77901278-77d3-4ae7-977d-10e3133b7f41
# 삽입 성공, UUID: 8eeedca9-d14b-4eb9-89a3-c769be355e55
# 삽입 성공, UUID: e53e6aee-5fac-455a-947e-e27d0bcb423b
# 삽입 성공, UUID: 65b58d46-5db0-4c5f-90d8-c74d1a730cda
# 삽입 성공, UUID: 4a80714c-71fb-4884-8b48-5b483fa40617
# 삽입 성공, UUID: d84c9c1a-840a-4b0d-9ab2-99ebc4a21f8a
# 삽입 성공, UUID: f4883d59-3b23-4c2c-b5df-b7a35b809560
# 삽입 성공, UUID: c4843f81-cbb0-4c7e-b2de-a345c1b1e8a6
# 삽입 성공, UUID: 9c758de2-1e60-4eef-a51d-826e1e5e4875
# 삽입 성공, UUID: e01f6425-56fc-4c6c-b8df-9fdee183a54b
# 삽입 성공, UUID: c7a6aa6e-d477-40cc-be6d-603ba8c499c5
# 삽입 성공, UUID: 2ef664fb-190c-4f1d-ad64-e485f5529b37
# 삽입 성공, UUID: f1bdf039-85ba-4b9b-8b68-1f17ec535d16
# 삽입 성공, UUID: bf202064-f4bf-4348-b2da-f9c50cfee165
# 삽입 성공, UUID: 5fb6d35b-ad58-4b44-870d-4511ba6fbac4
# 삽입 성공, UUID: ac36524d-dc3b-4db8-b1e2-ff7bb5ec3c15
# 삽입 성공, UUID: 7f7b0715-8d49-4754-b5dd-f4faa33876f7
# 삽입 성공, UUID: 0e47fb97-b90e-4ed7-b897-7f5dfe909b22
# 삽입 성공, UUID: f67592ee-48e6-45d0-bc5d-76467dbf7dfb
# 삽입 성공, UUID: c4a6cd63-f7d6-420f-903f-6e1d79667fb5
# 삽입 성공, UUID: 7132f184-0612-49fe-86c0-4be903ad557c
# 삽입 성공, UUID: c6973721-b0e9-4f07-8d6b-9d72b6f8c59a
# 삽입 성공, UUID: 292248b2-e5f6-4a6d-b254-51393c72ec0e
# 삽입 성공, UUID: 3b519b3a-21e9-42e8-ab42-f5ca4eee47a8
# 삽입 성공, UUID: 34156486-7e91-4561-9a51-f562cbff3f2b
# 삽입 성공, UUID: 8df8b89d-0b2a-4034-b49f-4ba63cee352d
# 삽입 성공, UUID: 8e6f0d93-dba1-4c8f-b412-5f9c3470c592
# 삽입 성공, UUID: 0a5e5ae1-6914-4ce7-b7db-a7e55b7066bd
# 삽입 성공, UUID: 9be54402-f6d3-4690-8ff5-e77f2c5e5295
# 삽입 성공, UUID: 58aca0aa-7454-4315-a0ca-68399a9ba7d5
# 삽입 성공, UUID: 294a5289-cf1c-489b-a1f9-3fefaf1490de
# 삽입 성공, UUID: dc938590-758b-4679-919f-aa1791e95542
# 삽입 성공, UUID: 3df65ebe-f68a-4470-b5a6-d52957282486
# 삽입 성공, UUID: e9f04156-dc87-4d91-b60a-40c0722561d1
# 삽입 성공, UUID: df7f00c6-198e-4f09-b24f-01a4c005202c
# 삽입 성공, UUID: b3aa666f-5261-4431-a713-c8010a7fea45
# 삽입 성공, UUID: d2a7047e-55ff-4961-8d0c-08b95dcff174
# 삽입 성공, UUID: 599e3ec5-6efd-4ad8-b880-13eed548941d
# 삽입 성공, UUID: 498e3c8e-59e3-4113-9092-afa85d3df073
# 삽입 성공, UUID: bfd51c17-6d6a-493e-84be-97e813de8673
# 삽입 성공, UUID: c9b5fb4a-6038-4ce6-be83-8d9271bfe1a6
# 삽입 성공, UUID: d3cbe46c-1ac1-4467-b91c-80cb1efaedef
# 삽입 성공, UUID: 58cb1989-5ee8-41af-9222-c6e9cc35e618
# 삽입 성공, UUID: 958d4168-b22e-405a-8893-bc9087532cc4
# 삽입 성공, UUID: b8e8846c-1bfb-4939-964b-cc2df7b93d8a
# 삽입 성공, UUID: d74fddff-00a9-4565-8dec-73432428473e
# 삽입 성공, UUID: 07374999-46be-40ed-a2a1-6a731c002b0c
# 삽입 성공, UUID: b633cffb-f24b-424c-8d5e-e6d8c86f781e
# 삽입 성공, UUID: 09b8c70c-74cc-4460-abe0-9464ad064be6
# 삽입 성공, UUID: be62cb98-7cdf-47f3-a05b-cebaf5bcf242
# 삽입 성공, UUID: 6e9b1650-7152-48d9-bb3e-872e51e3d840
# 삽입 성공, UUID: e295e347-ced3-49af-a71f-4b1c40674d0b
# 삽입 성공, UUID: 30787348-a5b6-4dbe-ad87-f67e008289e0
# 삽입 성공, UUID: bd2dd5a0-27be-4a7e-8f96-9c3208af7d0b
# 삽입 성공, UUID: 064cd0f4-7262-4f7b-9273-ac2dabf68367
# 삽입 성공, UUID: e272df42-baf2-4769-88f6-a663e207e6fc
# 삽입 성공, UUID: 88e47427-0685-450a-9520-4e6b4e3eae25
# 삽입 성공, UUID: 99c9472b-5398-4657-ac0b-d5eec74a3bd0
# 삽입 성공, UUID: 0b071431-0a0a-4f5c-8bdb-4cc9bf36e691
# 삽입 성공, UUID: 2a1dd0ff-8f32-4bd0-9182-cde8de318a06
# 삽입 성공, UUID: 7987b870-b777-40ab-aaa3-d6540103bc9a
# 삽입 성공, UUID: 6f0bb65e-f91d-4eb8-bd62-2bbfb6c02970
# 삽입 성공, UUID: bc58827e-1db4-472d-8209-1bafc40eb011
# 삽입 성공, UUID: 9c5be9a0-1dd3-4da8-82fb-0003cd6c05e2
# 삽입 성공, UUID: 360a97e9-291a-47ba-a5ff-6e549cd54d85
# 삽입 성공, UUID: 7cbdb060-8514-4018-b958-429636baa290
# 삽입 성공, UUID: 139fe047-62ae-469a-94fc-76109fb581fc
# 삽입 성공, UUID: b861204c-6f82-4fc7-ba69-32aa1555733f
# 삽입 성공, UUID: d24a7d4e-05a5-4caf-b14c-64c4cc89d5c4
# 삽입 성공, UUID: c130ef7a-cf16-4a5d-b355-87bde726aceb
# 삽입 성공, UUID: 6795999e-4b05-403c-b18b-a689c713c67c
# 삽입 성공, UUID: c166430e-1fce-4368-ad9e-c36c2f8b320e
# 삽입 성공, UUID: a54a535e-31f7-4907-8042-c152d51cb82b
# 삽입 성공, UUID: 84799944-8576-4e17-9590-05d9ecafb4e5
# 삽입 성공, UUID: 50b4203d-f87a-4a8c-9bf0-2d0115d68e61
# 삽입 성공, UUID: 803519e3-11ef-4b2c-a90e-a96ffc98cac4
# 삽입 성공, UUID: 3b9accbe-10c6-415a-8f46-58ac572ff07f
# 삽입 성공, UUID: f5e732f4-1953-4bbd-a47b-7bb87566c011
# 삽입 성공, UUID: ff5ea0a2-403f-4f18-bf60-3a8894471c92
# 삽입 성공, UUID: 16d0de9e-fa47-47e7-8da8-f81b34304d1e
# 삽입 성공, UUID: 3e9811d3-e2ef-46df-bc16-f0e0943efbdf
# 삽입 성공, UUID: 6070492e-840d-4d49-98e4-a8dd3191e97a
# 삽입 성공, UUID: 235df21c-aba0-4641-80cd-f1d5b501ee44
# 삽입 성공, UUID: 0837d97b-b6e2-47fc-9a22-6105426ec31c
# 삽입 성공, UUID: 34d45320-c0b0-4db8-9cdb-b3ace3a17363
# 삽입 성공, UUID: eee95979-4ecb-47c6-a784-8553f5ab5add
# 삽입 성공, UUID: 40f6a803-8dad-422a-bcc9-16d00446508d
# 삽입 성공, UUID: 2cffc7c1-8549-44a2-9afc-137fd21d54f2
# 삽입 성공, UUID: 4451476a-0397-490b-bb0b-bc5a33b2ab8d
# 삽입 성공, UUID: 04b46d95-b0aa-47ab-81ca-9d336a81ec3b
# 삽입 성공, UUID: 18ce3732-9c26-4615-8d92-a8b9ca1b0062
# 삽입 성공, UUID: 04fbab2c-37ba-4495-9aae-524563444f80
# 삽입 성공, UUID: 34d08ef4-3ff3-4403-8308-db4a5bba4b8c
# 삽입 성공, UUID: b76d4942-480f-4e63-8d5a-1de684822d38
# 삽입 성공, UUID: 06afe223-8820-438e-890d-23c9b1f35abe
# 삽입 성공, UUID: 46650cb0-0c8f-4c8e-9045-183f286d2863
# 삽입 성공, UUID: e3201d6a-9616-4592-a408-d94fde3217d1
# 삽입 성공, UUID: 6d009f88-42e8-417f-b8b1-c2409b4b3575
# 삽입 성공, UUID: ddcabaa5-a839-489a-b157-d0c80d065acc
# 삽입 성공, UUID: 6380fd9c-19a6-46e1-89de-ec7403fbec02
# 삽입 성공, UUID: 96ba823f-12b5-4597-aca6-3f52c21acc63
# 삽입 성공, UUID: c83d3d4f-9fbe-4385-8367-c88c1b9cbfb5
# 삽입 성공, UUID: 32c8e925-ba00-408d-b28a-66582d385096
# 삽입 성공, UUID: 571dbbc1-4c92-48de-955d-1c69d188517e
# 삽입 성공, UUID: 60015923-e655-4d81-a1fe-48ecfa126df4
# 삽입 성공, UUID: ee1967e4-6c88-4cb2-bde9-e6aa718e7e11
# 삽입 성공, UUID: 96cca7bb-d912-42a1-b22d-94d91ac06212
# 삽입 성공, UUID: 7345c2b8-1a23-4fb9-b97e-e1090ef015b3
# 삽입 성공, UUID: 6777d8c8-629d-430b-a699-1ccd1187fd60
# 삽입 성공, UUID: 5c3f650f-0d08-49b4-8800-d94e6561809e
# 삽입 성공, UUID: ef47b48a-25a8-4e5c-b610-a2df5a0c91fb
# 삽입 성공, UUID: 912d8fbf-c628-48b5-8e2e-160d1bad39eb
# 삽입 성공, UUID: 9b85bc5f-45a7-4a6e-a942-a4f021ac4c6e
# 삽입 성공, UUID: 27c466c2-c7d4-40da-9782-fc4ffbbabd63
# 삽입 성공, UUID: d97789c6-6f3d-473b-a3af-3be9812c24ed
# 삽입 성공, UUID: e8a44974-bb33-4207-b4d0-91e8e2b1eda2
# 삽입 성공, UUID: 3386306b-2c6c-4614-9819-d960e8cb95b9
# 삽입 성공, UUID: 3e576b6f-94ab-4465-9433-b8cb0c7aefd3
# 삽입 성공, UUID: 49872df1-8315-43d1-ac81-e8ee240c20a2
# 삽입 성공, UUID: 26f56164-0544-4ccd-ad2a-ed54b22ba4b1
# 삽입 성공, UUID: 718410eb-9d15-42fe-bf48-743fcfb9db9e
# 삽입 성공, UUID: 94ec4bbf-c497-4dd8-b203-31954a57b6bd
# 삽입 성공, UUID: 3d9e328f-fb63-4b8c-a287-0723a660ae1c
# 삽입 성공, UUID: 3eadd1d5-84a8-42de-8bfd-122e7406b01f
# 삽입 성공, UUID: 936c9428-5a49-4e72-aff5-6a1b29521ab3
# 삽입 성공, UUID: 67c18dbc-9097-4968-967c-97ac9aa4701d
# 삽입 성공, UUID: c825b204-4cae-436f-b85b-a28f3919a786
# 삽입 성공, UUID: b9042ed9-2355-4bbd-abc5-2add2a76d1ba
# 삽입 성공, UUID: d4b56d85-1cea-48cb-ac9e-616279ee9b82
# 삽입 성공, UUID: 782025b1-69ae-4c73-8313-c8fc1d100655
# 삽입 성공, UUID: 49dd9ddd-eed6-4330-8286-007719201874
# 삽입 성공, UUID: dab3d3f3-b2ff-4417-a855-a3645ae3d760
# 삽입 성공, UUID: 19901c04-7b15-41e0-b433-95522fbf69c2
# 삽입 성공, UUID: 406d5ec0-3144-4c9a-ab18-a27a47cfae4c
# 삽입 성공, UUID: 2f1d4a6d-3262-4ccb-be2e-15014a8bc607
# 삽입 성공, UUID: cab25118-ead9-49e5-a4ce-cbd1a6463e19
# 삽입 성공, UUID: cf6ad392-0e62-4d33-9d9b-e3d9bb855f8d
# 삽입 성공, UUID: b701c181-628c-46b7-9c52-ecf59d1cb1ae
# 삽입 성공, UUID: c26fd278-4f0f-474e-89f0-96554811cd74
# 삽입 성공, UUID: c864266a-ac57-4a2c-998c-e44dc13540c6
# 삽입 성공, UUID: 6c024d45-8b26-4b99-9ff1-1c9c4c4156d2
# 삽입 성공, UUID: 20f2fd1d-1eb1-49d6-8b59-775906101bd4
# 삽입 성공, UUID: 19cba88a-0832-4d3d-b141-3369fef10ab1
# 삽입 성공, UUID: 851d784d-da36-4c96-afab-bbcbffd4dd54
# 삽입 성공, UUID: f7bbd8b8-184b-48e5-86ad-224b30ee60f1
# 삽입 성공, UUID: 0f94cbf6-d527-43b3-980f-454bbe3926fa
# 삽입 성공, UUID: 48c05a50-c990-4250-924f-7260ffd31a32
# 삽입 성공, UUID: 58cd25ac-cf42-4fb9-9b35-9d8f3c95fb7a
# 삽입 성공, UUID: 57dd00ce-4473-4d0d-8aa2-60784bea5f4e
# 삽입 성공, UUID: eb27d7be-5d82-46aa-91e0-cb8f51d70a08
# 삽입 성공, UUID: 851ad17e-2fb3-4de5-b6a8-79a13f18b94d
# 삽입 성공, UUID: e93e5d6b-32ea-4e3e-b5c9-62034ca55a21
# 삽입 성공, UUID: 22644e85-c228-49e4-940b-a6e77e9c8a08
# 삽입 성공, UUID: 84d67450-2bc4-43e8-8ec0-e28ce35bc817
# 삽입 성공, UUID: a61cd033-948d-4510-8021-b6bf386debfd
# 삽입 성공, UUID: 7fcf46cf-dbf8-4627-9c75-c3da7a7c2525
# 삽입 성공, UUID: 9c376063-89cf-46e3-9fa3-8f12f3437f52
# 삽입 성공, UUID: 2dfdad67-7cee-4344-b354-9ac72539dc03
# 삽입 성공, UUID: b2848dd8-a350-4860-8cb5-c6acf9afe145
# 삽입 성공, UUID: 31b52cb8-0bfc-41a6-bb5a-736df7ab8052
# 삽입 성공, UUID: 868ae0f4-8d3e-4f7f-a44d-c6f87439b2aa
# 삽입 성공, UUID: 0de60b5e-925d-4e1b-b555-8a8a72c6e20e
# 삽입 성공, UUID: 401c496a-5a5e-421d-9c63-25cf50b5db18
# 삽입 성공, UUID: 2764e746-9c61-4570-ad9d-a24e39f91b8b
# 삽입 성공, UUID: dee3ba06-015a-420f-bbc0-c91de890f870
# 삽입 성공, UUID: 18fa93b9-edac-48cf-81f9-baf63373f9a3
# 삽입 성공, UUID: f135c9f7-1135-425c-a1e2-77224b8dadfa
# 삽입 성공, UUID: 4015a6fb-329d-4873-bf59-2ea363d4023d
# 삽입 성공, UUID: d232bf5f-af57-4bd7-9cae-c7a473fce0cb
# 삽입 성공, UUID: 5a371695-0c3b-4eb0-bb1a-4e2d896acc77
# 삽입 성공, UUID: af920635-c779-4688-b5ea-407b73466d5a
# 삽입 성공, UUID: 367acba4-e0db-485c-82b7-e57740b658a3
# 삽입 성공, UUID: 1bca77e0-5d27-4d1b-abb6-4b0d7c696210
# 삽입 성공, UUID: 73b1816c-3ad3-4594-981c-43dd0893fc69
# 삽입 성공, UUID: 0da6bd91-4561-4677-8391-cd3463cd6ff7
# 삽입 성공, UUID: db243040-704c-4fff-8c3b-8ff54f398f12
# 삽입 성공, UUID: 3e7e9acc-1cb5-437d-bab7-3dbd50bc7d97
# 삽입 성공, UUID: c6b2e962-d6e0-495f-accd-209f7fe98fd4
# 삽입 성공, UUID: 3e8ac509-f787-4aeb-8141-86327d7abe36
# 삽입 성공, UUID: 671da030-128b-44e9-a2de-6b47896f0cbc
# 삽입 성공, UUID: a8148b46-09c8-4a1e-8551-cc57f92689fc
# 삽입 성공, UUID: 46373264-fff6-4fa5-8e69-edc8d88f5615
# 삽입 성공, UUID: 5a76058a-7546-49d8-9893-b8a66e1b906d
# 삽입 성공, UUID: 6ca51d26-6024-467d-b440-2f938836c2aa
# 삽입 성공, UUID: b1b19adc-0799-41ab-b7cb-357ec5ce2d7c
# 삽입 성공, UUID: b9fd988a-d53a-4815-8b54-0b62024cc80a
# 삽입 성공, UUID: 73f58d6c-20b8-48d0-986b-f8a406be3951
# 삽입 성공, UUID: 914b341e-ee54-4c46-984c-03703fe7c2b8
# 삽입 성공, UUID: a39509a9-3e59-438d-aae4-4ce31f1e5925
# 삽입 성공, UUID: 6b21b2dc-5bb2-4a66-9c5e-c8b9d3e37a00
# 삽입 성공, UUID: 430dbd0a-5c2b-40b5-9c7e-2e5de81a8401
# 삽입 성공, UUID: 30c88dad-2a08-4473-8adc-e550d8d06669
# 삽입 성공, UUID: ab6e279a-8997-445e-a135-b16a937cd7df
# 삽입 성공, UUID: 6b869e0c-c6cc-4e7c-a017-0c2996392c62
# 삽입 성공, UUID: 733bb6b6-7787-4e92-931c-a3c5cc21ab40
# 삽입 성공, UUID: 44309c25-108e-4be8-b00b-1dbdd757eb70
# 삽입 성공, UUID: 292d3a29-0a87-40ab-97b5-a58518779a14
# 삽입 성공, UUID: a0505f0b-6f10-435c-a95e-e549396e09f1
# 삽입 성공, UUID: 5349dcd2-16bd-414b-b6b9-29958c87c724
# 삽입 성공, UUID: 6ed33e7f-f312-440e-aeea-f737e76a92ce
# 삽입 성공, UUID: b74771f6-cf97-4ae4-9377-302a91a176b3
# 삽입 성공, UUID: fffc06a5-8704-414e-a863-c591834aa4bf
# 삽입 성공, UUID: 6a9d77ef-0dbf-4b7f-9c2d-1407e264d1b2
# 삽입 성공, UUID: 32a5787e-cea0-46ad-b658-863c987befd3
# 삽입 성공, UUID: 83666b17-a386-4cf0-8c4a-5e32dbd85ecf
# 삽입 성공, UUID: 6134999c-a3d3-4635-adfd-6118256b7b83
# 삽입 성공, UUID: 9388b59d-6752-4330-9c78-f56da1a8442c
# 삽입 성공, UUID: e3cd2962-a989-49e5-895a-4311c3bcc04c
# 삽입 성공, UUID: f23235a5-bc6a-4d78-b4db-e650a1dfb322
# 삽입 성공, UUID: c2358b77-9a1a-41c8-8f06-13b16ae485f0
# 삽입 성공, UUID: fd828e56-ca51-4ceb-a363-a440d8223239
# 삽입 성공, UUID: 6907caee-92d0-4794-bd94-8fce27379c45
# 삽입 성공, UUID: 29583d0a-aa96-4b9c-afba-90b87c457a73
# 삽입 성공, UUID: 48ad5aa2-8963-46fc-a579-c2106f25ee6d
# 삽입 성공, UUID: 4d24409b-f83a-4aa5-a6dc-77c01eaf4922
# 삽입 성공, UUID: 07f84256-ffad-438a-b3c9-267ff3c73a24
# 삽입 성공, UUID: 6a619710-324b-452a-92f8-deb2f49f6f74
# 삽입 성공, UUID: 445a14a7-0f11-437e-ac19-dddf8623f41a
# 삽입 성공, UUID: b3a2a8b0-9266-4e42-8e36-e3f61dafc26e
# 삽입 성공, UUID: 30659de8-4661-4cd2-b285-a1de0b322d50
# 삽입 성공, UUID: 22594097-ec55-4807-9749-d0d3e22e65f5
# 삽입 성공, UUID: c0ee2c65-85db-41c3-9a0f-71d173779e29
# 삽입 성공, UUID: fa3cc747-6edd-4b2a-bcb7-18daed12deef
# 삽입 성공, UUID: 4eac034e-6eaf-4380-8e64-0765b5f5ce59
# 삽입 성공, UUID: beeff80d-ffa6-4932-acc3-c225aab92277
# 삽입 성공, UUID: b06faf5a-3b80-47bc-b93e-0a4ceb4270fd
# 삽입 성공, UUID: 7139b223-9632-4c29-bdbe-759c60d9913f
# 삽입 성공, UUID: 1850f874-a9dc-4c11-b207-8a0f292ee8fc
# 삽입 성공, UUID: 2c8d89dd-733b-4265-8459-6ab43ec1c322
# 삽입 성공, UUID: 18105f8f-f5b3-4e95-a32e-d0949ae8dabd
# 삽입 성공, UUID: ef7602b4-5786-47ab-9e12-67f431c22c12
# 삽입 성공, UUID: 75670bde-e4d9-4f39-90ac-e3b8982e31d6
# 삽입 성공, UUID: 5dba365b-e233-493d-b9d0-8256737302fa
# 삽입 성공, UUID: 2ee0ae9f-bb06-464d-a1aa-bb4ac303cf90
# 삽입 성공, UUID: e34cac85-a766-41e9-ac9d-2f75341635c6
# 삽입 성공, UUID: 38c53baf-d8ba-4d18-addd-b5a3fba4fb95
# 삽입 성공, UUID: 32ecb536-69f6-480e-9c02-c0724e5c0ef7
# 삽입 성공, UUID: 1a70d4ef-30e5-4103-9c6b-af5fb6a6258d
# 삽입 성공, UUID: 9bcbc624-e374-4c33-878d-cebe065d298d
# 삽입 성공, UUID: 847eac0a-be80-4c11-bf6c-dc9caaa9e504
# 삽입 성공, UUID: 6093730d-751c-4a0f-a9e0-a04e7be39c2f
# 삽입 성공, UUID: b9192cf2-68bd-4088-a81f-9033cc36246a
# 삽입 성공, UUID: 4014e526-43ff-4a89-ab41-8f08ff5cae72
# 삽입 성공, UUID: 53dfd3c9-b27c-46e2-9b0e-eb63dec9f5d0
# 삽입 성공, UUID: 32836082-8a1e-42fe-a302-eb0c3f1a3be4
# 삽입 성공, UUID: e054de75-36c8-4ab9-9a29-ebbf4a0d6491
# 삽입 성공, UUID: 1dca9f05-197c-4dc4-a818-04296958c4fd
# 삽입 성공, UUID: 6a25091f-ceae-45d4-9426-40162f9e0b26
# 삽입 성공, UUID: 12fd0f4b-2506-4cd9-9b67-70c078b8567d
# 삽입 성공, UUID: 9f937291-8571-462f-a07a-f38c57d2fd1c
# 삽입 성공, UUID: 0eae6603-f604-4cf1-a4f5-dd5187f1bc5f
# 삽입 성공, UUID: 85ceb8bb-a4d6-4ef5-b2a4-2ba75a1e2f81
# 삽입 성공, UUID: a982bb44-c481-4664-a329-e2fb72349889
# 삽입 성공, UUID: a3cf1bd7-a518-4d04-880e-cd488031d814
# 삽입 성공, UUID: 2676b6df-2785-4f55-9888-576e0b8cf3cf
# 삽입 성공, UUID: de238412-4e76-4fd8-a9a8-1fa638946ba9
# 삽입 성공, UUID: dba6c434-efa0-49b4-9285-b0e86fe76b47
# 삽입 성공, UUID: e0ef7733-83aa-46bd-8c2e-b09a5d995fa4
# 삽입 성공, UUID: 544b1562-b3c5-4376-b745-c9201e35dad5
# 삽입 성공, UUID: 9744ac56-cab1-486f-8d3c-0ee2d5ac3e30
# 삽입 성공, UUID: 2286a099-375c-4fc9-9bc0-8d1eab47211f
# 삽입 성공, UUID: 4ee5fc2f-c45a-4c18-ba06-d5acd0e5fe9d
# 삽입 성공, UUID: 7a753edd-9df0-42a7-bc64-bfe3756a52c3
# 삽입 성공, UUID: fd640ae6-1320-41d2-8857-3a167f83d07f
# 삽입 성공, UUID: 24a1ebf9-f701-4c39-9388-57576696c35f
# 삽입 성공, UUID: 60b05842-2cda-48cc-844a-6ef275e30494
# 삽입 성공, UUID: 8e3020f0-b697-4199-9d86-a55c01785e65
# 삽입 성공, UUID: e951b01f-ced4-4e98-88f5-bed840a063df
# 삽입 성공, UUID: 1f5e5afc-1a88-4ad2-a453-aa4982f32579
# 삽입 성공, UUID: e8b4519c-0cea-4325-92c4-ac991f4f7e1f
# 삽입 성공, UUID: e43d26fc-1716-473d-803a-fefc18c1b7ac
# 삽입 성공, UUID: 10ba039f-2e01-4784-9f12-ed2ff376d0be
# 삽입 성공, UUID: d65ad650-199e-4a9b-b1ee-04718ab6ba8c
# 삽입 성공, UUID: 54c0930a-d5e0-48ef-a25f-27fa1c1cfdd5
# 삽입 성공, UUID: ba8e1455-19e2-4fb1-8bd8-dde78e1387ee
# 삽입 성공, UUID: 0a23b7d9-84d7-42df-a034-a0704a347b98
# 삽입 성공, UUID: e9efeb99-8654-4def-a48b-9d06008c8f93
# 삽입 성공, UUID: 156c5c88-3a0e-49c2-9688-d605ab1aebc3
# 삽입 성공, UUID: bd8c2bcf-bc88-46ce-bd24-db654a26542e
# 삽입 성공, UUID: 26898229-0321-460a-9228-ffdfd8891518
# 삽입 성공, UUID: d2593f9b-db5e-4df3-85a1-36596a19e947
# 삽입 성공, UUID: 52465f1b-2598-4c75-8977-366366321c27
# 삽입 성공, UUID: 20b47d6e-d268-4646-be1a-c06e3f75d070
# 삽입 성공, UUID: 795a03ba-55ac-4d26-95f2-1677cf3b5e40
# 삽입 성공, UUID: 73e8208c-a236-407f-8eaa-4680ce95a9fc
# 삽입 성공, UUID: 0ad55757-fbb6-42ef-b4bd-393bdfa17941
# 삽입 성공, UUID: 6d441ebe-8bdb-45ce-9593-04175e3ee179
# 삽입 성공, UUID: 407973c3-f18d-4946-8442-cce4813b5980
# 삽입 성공, UUID: 38cbf844-3fa4-48cd-8f38-902a8cb6b305
# 삽입 성공, UUID: 5fcbb628-532b-40d8-b69f-96971a2dc45e
# 삽입 성공, UUID: 4cc2de15-0ee1-4928-8756-e100aa5a0188
# 삽입 성공, UUID: 62fb0610-9850-482b-bdb2-551a84013210
# 삽입 성공, UUID: 8ae24c22-2c39-4d1b-8f52-23eb236c932c
# 삽입 성공, UUID: 69e606f4-5aec-401d-8acc-e67d19249794
# 삽입 성공, UUID: 41c3699c-91e9-4518-90f4-70b626b90310
# 삽입 성공, UUID: 2483b40b-67bb-41bf-9326-4151e5819f95
# 삽입 성공, UUID: 22821986-2024-44e6-89fb-e079ad517e61
# 삽입 성공, UUID: 9b75bc75-cc8b-4ed9-aed1-06ab2c78fb35
# 삽입 성공, UUID: f5f4c434-f22b-422c-9d5a-c4a280e3045b
# 삽입 성공, UUID: 3de8ba57-8251-4ce9-aaf0-5a61a36c3a2b
# 삽입 성공, UUID: 916a3b9e-dcb9-493f-b85e-90b31ff8869b
# 삽입 성공, UUID: 62c787fd-bed8-47ee-8ed0-d41362cb1a56
# 삽입 성공, UUID: a81ddfe0-7808-4737-9c71-2e4dd78eff47
# 삽입 성공, UUID: 7d74eca1-9d19-4bf4-b114-49f7f2cb9347
# 삽입 성공, UUID: f34c7c13-c406-42d1-bc61-d0a4eebf9193
# 삽입 성공, UUID: 8aa57ff2-d238-455a-8f50-7ab7b95c6173
# 삽입 성공, UUID: eae10749-1eb5-4d7a-b97d-d5a2b6f9e591
# 삽입 성공, UUID: 53d09ea6-cbcf-4eae-a14c-703b643f7e80
# 삽입 성공, UUID: 8606bb3b-4bca-4556-9bdd-2a34c8859c60
# 삽입 성공, UUID: 1c61450d-e078-485c-a8f4-ea063b2814fc

# %%
def format_weaviate_context(weaviateRM_output):
    weaviateRM_output = [d['long_text'] for d in weaviateRM_output]
    weaviateRM_output = "".join(weaviateRM_output)
    return weaviateRM_output

# %%
from dspy.functional import TypedPredictor
import pydantic
from typing import List

class Topic(pydantic.BaseModel):
    topic: str
    topic_description: str

class Topics(pydantic.BaseModel):
    topics: List[Topic]

class TypedQuestion2BlogOutline(dspy.Signature):
    """Your task is to write a Weaviate blog post that will help answer the given question.\nPlease use the contexts from a web search and published Weaviate blog posts to evaluate the structure of the blog post."""
    
    question: str = dspy.InputField()
    blog_context: str = dspy.InputField()
    blog_outline: Topics = dspy.OutputField(desc="A list of topics the blog will cover. IMPORTANT!! This must follow a comma separated list of values!")

# %%
import functools

class TypedBlog2Outline(dspy.Module):
    def __init__(self, weaviate_rm):
        self.question_to_blog_outline = dspy.functional.TypedPredictor(TypedQuestion2BlogOutline)
        self.weaviate_rm = weaviate_rm

    def forward(self, question):
        blog_contexts = self.weaviate_rm(question, k=3)
        blog_contexts= format_weaviate_context(blog_contexts)
        question_to_blog_outline_outputs = self.question_to_blog_outline(question=question, blog_context=blog_contexts)
        return question_to_blog_outline_outputs.blog_outline

                                                                         
blog2outline = TypedBlog2Outline(weaviate_rm)
        
toy_question = "What are cross encoders?"


print(f"\033[91mResult for gpt-3.5-turbo\n")
print(f"\033[0m{blog2outline(question=toy_question)} \n")
# Out:
# Result for gpt-3.5-turbo
#
# topics=[Topic(topic='Introduction to Cross Encoders', topic_description='Explanation of what cross encoders are and how they are used for content-based re-ranking'), Topic(topic='Types of Cross Encoders', topic_description='Overview of different types of cross encoders available, such as sentence transformers'), Topic(topic='Functionality of Cross-Encoder Models', topic_description='Explanation of how cross-encoder models work, including the input-output mechanism and similarity calculation'), Topic(topic='Efficiency Challenges of Cross-Encoders', topic_description='Discussion on the inefficiency of using cross-encoder models for large-scale semantic search applications'), Topic(topic='Combining Bi-Encoders and Cross-Encoders', topic_description='Exploration of the benefits of combining bi-encoders and cross-encoders for improved search performance')]
