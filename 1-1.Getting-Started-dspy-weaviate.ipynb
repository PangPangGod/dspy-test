# %%
# Connect to Weaviate Retriever and configure LLM
import dspy
from dspy.retrieve.weaviate_rm import WeaviateRM
import weaviate
import os

llm = dspy.OpenAI(model="gpt-3.5-turbo")
weaviate_client = weaviate.Client("http://localhost:8080",
    additional_headers={
        "X-OpenAI-Api-Key": os.getenv("OPENAI_APIKEY"),
    }
)
retriever_model = WeaviateRM("WeaviateBlogChunk", weaviate_client=weaviate_client)
# Assumes the Weaviate collection has a text key `content`
dspy.settings.configure(lm=llm, rm=retriever_model)
# Out:
# d:\anaconda\envs\dspy\Lib\site-packages\weaviate\warnings.py:158: DeprecationWarning: Dep016: You are using the Weaviate v3 client, which is deprecated.
#             Consider upgrading to the new and improved v4 client instead!
#             See here for usage: https://weaviate.io/developers/weaviate/client-libraries/python
#
#   warnings.warn(

# %%
# class_name = "WeaviateBlogChunk"

# # 클래스 삭제 시도
# try:
#     weaviate_client.schema.delete_class(class_name)
#     print(f"클래스 '{class_name}'가 성공적으로 삭제되었습니다.")
# except weaviate.exceptions.SchemaValidationException as e:
#     print(f"클래스 삭제 중 오류 발생: {e}")
# Out:
# 클래스 'WeaviateBlogChunk'가 성공적으로 삭제되었습니다.

# %%
import weaviate.classes.config as wvcc
schema = {
  "classes": [
    {
      "class": "WeaviateBlogChunk",
      "vectorizer": "text2vec-openai",
      "properties": [
        {
          "name": "content",
          "dataType": ["text"],
        },
        {
          "name": "author",
          "dataType": ["text"],
        }
      ],
      "moduleConfig": {
        "text2vec-transformers": {
          "model": "text-embedding-3-large"
        }
      }
    }
  ]
}

# 스키마 생성
weaviate_client.schema.create(schema)

# %%
# ## Connection check and collection config(docker)
# response = weaviate_client.collections.list_all()

# print(weaviate_client.is_connected())
# print(response)

# %%
# Chunk Blogs

import os
import re

def chunk_list(lst, chunk_size):
    """Break a list into chunks of the specified size."""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

def split_into_sentences(text):
    """Split text into sentences using regular expressions."""
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    return [sentence.strip() for sentence in sentences if sentence.strip()]

def read_and_chunk_index_files(main_folder_path):
    """Read index.md files from subfolders, split into sentences, and chunk every 5 sentences."""
    blog_chunks = []
    for folder_name in os.listdir(main_folder_path):
        subfolder_path = os.path.join(main_folder_path, folder_name)
        if os.path.isdir(subfolder_path):
            index_file_path = os.path.join(subfolder_path, 'index.mdx')
            if os.path.isfile(index_file_path):
                with open(index_file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                    sentences = split_into_sentences(content)
                    sentence_chunks = chunk_list(sentences, 5)
                    sentence_chunks = [' '.join(chunk) for chunk in sentence_chunks]
                    blog_chunks.extend(sentence_chunks)
    return blog_chunks

# Example usage
main_folder_path = './blog'
blog_chunks = read_and_chunk_index_files(main_folder_path)


print(f"There are {len(blog_chunks)} chunks in the main folder path.")
# Out:
# There are 1413 chunks in the main folder path.

# %%
print(blog_chunks[0])
# Out:
# ---
# layout: post
# title: What if you could understand your unstructured data? slug: understand-your-unstructured-data
# authors: [laura]
# date: 2021-01-20
# tags: ['concepts']
# image: ./img/hero.png
# # canonical-url: https://medium.com/semi-technologies/what-if-you-could-understand-your-unstructured-data-92f0861e016
# # canonical-name: Medium
# description: "Learn how the AI-first vector database Weaviate unlocks the potential of unstructured data and why this is important."
# ---
# ![What if you could understand your unstructured data?](./img/hero.png)
#
# <!-- truncate -->
#
# ## Intro
# These days, more and more organizations are adopting a data-driven culture. Business processes and customer experience benefit from good data collection, management and analysis. But in order to really benefit from available data, it is essential to also understand the unstructured data, like free text in PDF documents, emails, invoices or voice transcriptions. Unstructured data is especially hard to index, manage and understand.

# %%
import weaviate
for blog_chunk in blog_chunks:
    blog_object = {
        "content": blog_chunk,
    }

    try:
        response = weaviate_client.data_object.create(
            data_object=blog_object,
            class_name="WeaviateBlogChunk"
        )
        print(f"삽입 성공, UUID: {response}")
    except Exception as e:
        print(f"데이터 삽입 중 오류 발생: {e}")
# Out:
# 삽입 성공, UUID: 8d186bf2-cf71-4ac3-9c64-84688734fee5
# 삽입 성공, UUID: 34414982-161e-46e9-9472-382b877c2a9e
# 삽입 성공, UUID: 21aea85b-9fba-464c-8030-cc3178cd6401
# 삽입 성공, UUID: 87ca403c-b876-456c-b403-b0e437664af3
# 삽입 성공, UUID: daa9acc8-4b62-4a00-89ec-c38156e837f5
# 삽입 성공, UUID: fecc5bcb-9ce9-4581-b8f9-9fc6db2f6477
# 삽입 성공, UUID: 7f92e60b-7da7-4456-b70d-4fd2e8c0718e
# 삽입 성공, UUID: 9d28d8d1-927a-424b-a235-a7c66d5da565
# 삽입 성공, UUID: 45c0128d-3166-4251-a778-e81df40da599
# 삽입 성공, UUID: 50e7680b-bd7e-40bc-b661-a46776c79a0f
# 삽입 성공, UUID: ea18b8c6-c79b-4625-8ca7-61243e5b8b95
# 삽입 성공, UUID: 8bfe1c08-8637-46c7-956d-176e7f98b5d7
# 삽입 성공, UUID: 95dca9fe-b57e-499e-a185-bb96c7688f14
# 삽입 성공, UUID: ccca58c9-0fa0-4f26-aad9-1dcfd57980b8
# 삽입 성공, UUID: b0eab62a-74d1-4a3a-986e-b2b8451179e1
# 삽입 성공, UUID: 5ba92e90-da31-4eca-a6df-89aac19f4983
# 삽입 성공, UUID: d06d8f97-b1eb-4ab2-8034-adea823235c1
# 삽입 성공, UUID: b33166c3-6340-48d8-86f8-4ffa063a6b72
# 삽입 성공, UUID: 2d586a28-7715-4e5c-b690-1bb48ffa4a7b
# 삽입 성공, UUID: 927e4473-b7fa-4067-8f1d-62586bf1ab62
# 삽입 성공, UUID: e0e87588-cb23-4e50-8795-46e49a36c5f7
# 삽입 성공, UUID: 97365e3f-772b-475d-9516-b073efd805f0
# 삽입 성공, UUID: 9105199d-7d18-407f-8fb7-71e5cc393ff6
# 삽입 성공, UUID: 13ecb10e-69de-4ef6-b1db-23b1b684fa95
# 삽입 성공, UUID: f1ce64ea-b305-4162-ac0e-5d45ca9c1840
# 삽입 성공, UUID: 4a576d30-81a8-4283-bed2-158c439169f5
# 삽입 성공, UUID: c0e2f449-8265-4d32-af79-8896db0bae65
# 삽입 성공, UUID: e602e0fc-acb5-4886-b2b1-baab7b5d456d
# 삽입 성공, UUID: cfa81435-44bc-4c7e-994a-c7094fd9066f
# 삽입 성공, UUID: 4784b3e1-0586-4ca4-9b04-7e368abe378b
# 삽입 성공, UUID: 275ad7b8-fb9b-41a8-8029-62bc0c4b812f
# 삽입 성공, UUID: 4b15007f-2689-4cdc-871d-7160f943ef31
# 삽입 성공, UUID: 7381dd4b-965e-4f2f-b871-9a4affed51d2
# 삽입 성공, UUID: f4248127-1524-4cc4-9a67-eb7c04e5898f
# 삽입 성공, UUID: 71b95beb-fac1-426f-ad46-662ce35213fc
# 삽입 성공, UUID: ffafd2fd-c3c9-4343-af1f-53a634de7a60
# 삽입 성공, UUID: 31428bf9-60f4-40dd-b137-ee33ed6f34da
# 삽입 성공, UUID: 72c9aab4-0b3f-4a6a-80c0-e9d73b10af9d
# 삽입 성공, UUID: 21ef30d2-e852-4d40-b523-fa1f897f5e49
# 삽입 성공, UUID: 344a6760-2c70-485d-891f-7c6cf921cbc3
# 삽입 성공, UUID: 4c912439-cfe7-4431-9b71-a73f8b153bac
# 삽입 성공, UUID: e4820ad0-ccf4-4b12-9c52-ab898e601c82
# 삽입 성공, UUID: aa5d9c5a-a104-46a2-897c-42bb23d79860
# 삽입 성공, UUID: 8b1b0605-693b-4354-8bd4-baae214f4008
# 삽입 성공, UUID: bae13dd5-563b-40b0-894a-6041feab30aa
# 삽입 성공, UUID: e0d437ca-46c3-478a-801e-56b9087ff80e
# 삽입 성공, UUID: f7d0de46-dabe-418a-a44d-02b9c276cdcc
# 삽입 성공, UUID: c6a5d53c-7973-481f-b657-9f6a62853546
# 삽입 성공, UUID: cdc271b7-5d06-43f9-8bb5-053517d468c7
# 삽입 성공, UUID: e7c44521-7201-4cbd-b80c-28dc7089fb4e
# 삽입 성공, UUID: 4d83f50f-21c3-4045-bf50-5c865c9d6720
# 삽입 성공, UUID: ac8a4c27-4435-4972-999a-91140e03ae94
# 삽입 성공, UUID: 882a98dc-01e6-48cc-aa6b-4572bb01b0ee
# 삽입 성공, UUID: 90deb58d-6d0c-4536-966e-3dcdf41da3ce
# 삽입 성공, UUID: 820d9212-a318-4a0d-90af-c3b870607a12
# 삽입 성공, UUID: 7c8988c3-c7d8-468a-8394-ba029eba9f4f
# 삽입 성공, UUID: fe0c9d89-72c5-43ed-8c13-008e44e7d64f
# 삽입 성공, UUID: 4585164f-6c08-4556-85c1-91721132aff5
# 삽입 성공, UUID: e4cc9f82-0550-4f6a-95a5-165ab32bce41
# 삽입 성공, UUID: 4169d80a-0ead-448e-8f3d-851a40ed61ca
# 삽입 성공, UUID: 2019c6aa-2a9c-4e11-bb76-45f314001c09
# 삽입 성공, UUID: 9f92fa18-7c21-4f1c-81d5-8fee0d3901dc
# 삽입 성공, UUID: edfc7354-80ea-4484-9193-fb230073f073
# 삽입 성공, UUID: 1c3e1f42-335a-49e3-9100-6b9f525bde0b
# 삽입 성공, UUID: 6a42b44b-eadc-478a-88c7-46a8cff47a4e
# 삽입 성공, UUID: d6cbb99b-09d6-47eb-a12d-64b60e6b4d70
# 삽입 성공, UUID: ad3256cb-b7ed-4df3-8428-128e0fdf32b3
# 삽입 성공, UUID: b53b958b-f2b6-43d7-b05f-ee31ede62237
# 삽입 성공, UUID: 7d092482-93ca-47da-8388-4e17af5a294f
# 삽입 성공, UUID: 1e8af114-4c45-488e-926c-6da11ede482b
# 삽입 성공, UUID: b86c01e5-529e-429f-841a-e530cc8a8469
# 삽입 성공, UUID: 8fcc81e0-786d-4efe-bd2c-82ca7cc54418
# 삽입 성공, UUID: 2c01cb8a-8388-4263-9912-537124ae43b1
# 삽입 성공, UUID: 5b6c5465-1208-4c56-a1e8-dd34d960df96
# 삽입 성공, UUID: 197f08e5-6382-419c-9676-fd958021f247
# 삽입 성공, UUID: 6ac9e5ee-8db6-4c94-b505-731e2b61c407
# 삽입 성공, UUID: 67eb6352-f51f-424b-9f73-02a9d54a6250
# 삽입 성공, UUID: fa9c26cf-d52d-4a1e-bf91-8d8a7e3e20aa
# 삽입 성공, UUID: 85f3b170-4944-40f0-9604-4c42a61031eb
# 삽입 성공, UUID: aac9a868-fc6d-4d80-a6eb-91df1a281ee2
# 삽입 성공, UUID: 79120960-de70-4b03-9c26-38932288ce4d
# 삽입 성공, UUID: 1ec6cc50-6bab-436c-a5b1-cbc1d0e48c7a
# 삽입 성공, UUID: 20a18d9a-d757-4b05-b3fd-a6958a88fe04
# 삽입 성공, UUID: 3c4a2d9a-4ce6-4f46-a476-d4c92d194833
# 삽입 성공, UUID: 1b48a2af-4e15-4f9d-8ac1-a887f714f8fa
# 삽입 성공, UUID: 1e1a4a24-a6a1-43fb-b172-e26d7ae2ed14
# 삽입 성공, UUID: 101b79c0-b507-4b12-91be-18025275f6d8
# 삽입 성공, UUID: 622e4192-6bb1-44b1-8801-51acab59c3ab
# 삽입 성공, UUID: 7291eca0-2b6e-4d84-bb2d-6a7c779bc2db
# 삽입 성공, UUID: 74696f1e-18d0-469f-9802-5d0ba406c689
# 삽입 성공, UUID: 2e9ee5d1-0d20-498a-ad93-4f63c406c226
# 삽입 성공, UUID: c01c787d-e35c-4bef-8d7c-a446d973eb50
# 삽입 성공, UUID: 8a0a21b6-db8b-471c-8688-03e718351e02
# 삽입 성공, UUID: 68cf22fa-f342-4aca-af60-f1212e43b178
# 삽입 성공, UUID: b31a8cdc-31fb-4da6-bd67-e19c8b0a52b1
# 삽입 성공, UUID: ecbe87a8-dff9-45f1-a610-7ba93f29bb09
# 삽입 성공, UUID: 9f25632a-fac2-40cc-9c07-66f365901d77
# 삽입 성공, UUID: 233b2700-070b-4d6d-bbd8-78e46b77bf65
# 삽입 성공, UUID: 367b7adb-c5de-4c50-82fd-d5a2b95e6f2b
# 삽입 성공, UUID: d36e31b1-07ab-4454-87ee-c2c81b21a49d
# 삽입 성공, UUID: 5fdf1163-23cc-40df-ab66-1ad17062bf2c
# 삽입 성공, UUID: 3f1ea023-1f92-41d4-909e-e2e867a7b279
# 삽입 성공, UUID: 4db53a04-02be-414f-ad6b-fc96bc633df8
# 삽입 성공, UUID: 3340fd18-42be-4edb-bb9c-02e934165957
# 삽입 성공, UUID: 36e4094e-b5d5-49ac-a783-3d0e63230b94
# 삽입 성공, UUID: 68c57191-8e4d-4958-be28-df40ba977281
# 삽입 성공, UUID: 36f602cd-9877-4f2c-807c-288659d08989
# 삽입 성공, UUID: 00fae425-f570-4e75-bdf5-7be6d3be362d
# 삽입 성공, UUID: 5d9b3a59-c332-4618-8957-95eab75c2ef6
# 삽입 성공, UUID: e46afed8-80aa-481d-a171-a7e4bc5ea80a
# 삽입 성공, UUID: 52a4256c-c160-4d9b-b0b4-b913739b6ec9
# 삽입 성공, UUID: 5b211ef3-ef63-47f0-bfff-6f33f8bd3762
# 삽입 성공, UUID: d7a811ee-5480-4c90-810e-a86cc327f1c9
# 삽입 성공, UUID: 6b6ddbd0-4a63-4ef3-b033-7ea23b7ec45a
# 삽입 성공, UUID: 42f62055-a4d0-4cd2-9e6f-276647cd3991
# 삽입 성공, UUID: 147c7ec6-c944-4211-989a-f055d48a3fb6
# 삽입 성공, UUID: 46eb5694-4d67-4aba-a2a7-7251dde09243
# 삽입 성공, UUID: 79e0aab0-6b16-4826-94ff-197862532479
# 삽입 성공, UUID: f7764bfb-ad0d-49ad-8663-82a32ccd2e34
# 삽입 성공, UUID: c897b33c-aa15-4461-ba6a-579737966479
# 삽입 성공, UUID: 8eb08886-1e2d-4aa4-819a-b537b10824df
# 삽입 성공, UUID: ad0b1741-3d16-4ff1-b9cb-c0220256a0d4
# 삽입 성공, UUID: b2e6c283-c2f9-48da-aff6-e2cd1bb7a64e
# 삽입 성공, UUID: 243b2be4-4e4a-43fd-93f6-6f3c52f89e42
# 삽입 성공, UUID: e4549c4d-5e67-4956-a563-ccbff0883bbb
# 삽입 성공, UUID: 24eda13c-764b-460d-9287-f982a4d1b3c2
# 삽입 성공, UUID: b209703c-a45a-405c-8e8e-9ec1da2fbc3c
# 삽입 성공, UUID: 91f8070a-d194-42c2-ba60-e66e60227f72
# 삽입 성공, UUID: 99b15cda-0ebc-47e5-9890-739d868a39a7
# 삽입 성공, UUID: 8e4a18e9-9958-4f23-af42-249fc229e14b
# 삽입 성공, UUID: 6436aece-4bf8-4fc1-a65b-342b8f8004f2
# 삽입 성공, UUID: 2e20d6be-65be-4078-aafd-cb85a6f6e8db
# 삽입 성공, UUID: 47e51725-152b-4df0-8e79-f5e68c9ff456
# 삽입 성공, UUID: a032d260-fa61-4b3a-9037-a75627d0416a
# 삽입 성공, UUID: bcdaab9b-bbcc-4ca8-84cb-bca8e619dee1
# 삽입 성공, UUID: 123895ad-7c67-4455-89c4-988b198b2084
# 삽입 성공, UUID: e71362ae-aea3-4a0a-9ec2-70425e7da74f
# 삽입 성공, UUID: 2b21537f-f1c2-4176-afee-4873aaea8c70
# 삽입 성공, UUID: a29fec97-2dd4-40c3-a369-bebb1ed7220c
# 삽입 성공, UUID: a8c89b92-3098-4bf4-8c15-a96091436477
# 삽입 성공, UUID: cc6b2e6f-cfb0-4cf9-a4b1-155275c8e244
# 삽입 성공, UUID: e7152092-d654-4a1a-a9e0-8cdb62f7dc9a
# 삽입 성공, UUID: f7cb0fa4-fc4b-43af-bbfb-a0fbf6680a36
# 삽입 성공, UUID: 94fff247-3b92-4521-9b34-bd3b662fe92b
# 삽입 성공, UUID: c7558a86-4714-481e-8453-df46b45d7d61
# 삽입 성공, UUID: 2021fac4-40d3-4e23-9d55-5e65bca46d63
# 삽입 성공, UUID: 9a143780-ed1d-4a7c-93c1-060027480316
# 삽입 성공, UUID: 3727a75c-0875-4ba8-a505-e7d20ef9c0a7
# 삽입 성공, UUID: a1563806-fff7-4346-8b19-e50be09264dd
# 삽입 성공, UUID: ad25c717-d57e-4db1-8a0e-edfc6b453e8c
# 삽입 성공, UUID: b9c922e5-56b8-46b2-991d-7378afa0ee81
# 삽입 성공, UUID: 1439f53c-d419-41f6-8af0-12c2e7412d4a
# 삽입 성공, UUID: 4848766d-5870-4805-8761-0f4ac548d496
# 삽입 성공, UUID: 8f71d789-74d6-43f5-bfec-2b596800ada5
# 삽입 성공, UUID: 07bea5d1-241f-4873-8b8f-7b18594ce1f2
# 삽입 성공, UUID: 5b9242ab-903a-4642-9230-aeb69be69ac1
# 삽입 성공, UUID: 018e99d0-3938-4880-b359-75b7434ad735
# 삽입 성공, UUID: 4b0ab01a-c2ed-410c-b263-c2c1037835fc
# 삽입 성공, UUID: 19dadbab-2177-4edc-96b6-9469007eef95
# 삽입 성공, UUID: 641958ce-480a-4673-bfdf-617269dceffb
# 삽입 성공, UUID: e15f933a-7ff2-42d4-b444-e42ca64dd8d6
# 삽입 성공, UUID: 57764c12-1cba-4eca-9fb6-1556a3e7fada
# 삽입 성공, UUID: e0bc9cc3-38eb-4e6e-9d61-d6adb9b51b3b
# 삽입 성공, UUID: 880d4587-6724-48f2-a3ea-4f396bc06d00
# 삽입 성공, UUID: c575e346-6f06-400c-9db6-4b2593b25651
# 삽입 성공, UUID: a5d20f61-6188-4efb-aa7a-3e6dbcbacf2e
# 삽입 성공, UUID: 2083b620-b5a7-49c6-a9dc-9a2f8e9f71d7
# 삽입 성공, UUID: b5e301b6-6949-4564-8b00-acd5bae99bfb
# 삽입 성공, UUID: 14c574a0-f65e-446a-91cb-59d7252af1e3
# 삽입 성공, UUID: a6ccb99b-0792-4597-bc45-5b4f8925c910
# 삽입 성공, UUID: abbe4b7f-334a-4800-a751-9c7937f48bac
# 삽입 성공, UUID: 9a45710b-cd56-4aca-9410-6197bee57127
# 삽입 성공, UUID: 9ff4fd81-3a00-43ea-becd-31e043c83bff
# 삽입 성공, UUID: 1ccc9674-8723-4887-be92-110ea9e3f6eb
# 삽입 성공, UUID: d57a2de0-ad5f-4831-aeb2-a389ef2f6252
# 삽입 성공, UUID: 0e1213b9-838e-4166-9410-a774202d3d66
# 삽입 성공, UUID: 7a4ab8b0-a585-4cd5-b8ca-c82d2d5a52d2
# 삽입 성공, UUID: f37a9ee6-695c-4b3f-b291-fe9e1f7eb2d3
# 삽입 성공, UUID: ea42adc8-146b-427b-a18f-e6a9fc557e38
# 삽입 성공, UUID: 7bcf6067-ca78-4b37-942e-eacbc54ce8dc
# 삽입 성공, UUID: c1194d49-dcf7-4521-bd0d-e43f76fd2937
# 삽입 성공, UUID: 3bcb9335-86ba-4802-b986-fed2a10711fc
# 삽입 성공, UUID: 0633b44b-4b43-4e67-98cb-6875eeb1627a
# 삽입 성공, UUID: b7a1e3dc-dcc3-4c3a-8e2f-81414bedfce0
# 삽입 성공, UUID: 24ab00ff-3527-4e73-8e89-c6f43eec575d
# 삽입 성공, UUID: c8fd438c-967b-474b-8517-1dbbb55ba3a8
# 삽입 성공, UUID: e7cd9d97-6d65-4372-b58c-53e851d9cdcb
# 삽입 성공, UUID: 10cc74c9-63d7-4ac2-8a55-8b75ddea6c8e
# 삽입 성공, UUID: 5819c127-c233-479d-8230-0d8ce6399741
# 삽입 성공, UUID: 6501962a-b25a-485e-828f-9cd84c881adb
# 삽입 성공, UUID: a6cf037c-3da6-4958-ae08-fa14af703722
# 삽입 성공, UUID: e0aec2b6-9b53-46b5-8a54-407b413fe81c
# 삽입 성공, UUID: 16987fc6-1e4b-44f5-86d9-b347dc460733
# 삽입 성공, UUID: 7787e4d7-a9b1-498e-97c2-c53d17517ad2
# 삽입 성공, UUID: 384607f9-a259-484f-9ecb-6539183e773b
# 삽입 성공, UUID: b1c2d2fe-7de0-4234-bf27-7e6efa11607a
# 삽입 성공, UUID: b3cd0adb-9de9-4828-8236-236a883e3190
# 삽입 성공, UUID: db2b3eb7-a18d-4981-b31c-2127fd12ff6b
# 삽입 성공, UUID: e2944486-f35b-44ef-8dae-99284468c49e
# 삽입 성공, UUID: 3b4188be-43f5-403b-b81b-797c955e7a9c
# 삽입 성공, UUID: d4baf05a-1ca6-4430-a25b-b948dcf22e08
# 삽입 성공, UUID: a7ae37c6-752c-4fc1-9aa7-f4eb123c6700
# 삽입 성공, UUID: 8ca2aede-7633-4b6f-a110-c6a5025d927b
# 삽입 성공, UUID: 2b57638d-88d0-4bb2-a29b-48bfa1f030c7
# 삽입 성공, UUID: 4610c92e-ab6b-44bf-ab15-688e4d3a2f74
# 삽입 성공, UUID: 1847347c-4d89-447c-b641-977ba37d6a5b
# 삽입 성공, UUID: a48169e8-f9a9-4138-b4d2-cf43c67e54e6
# 삽입 성공, UUID: a399037a-3223-4cc3-bdb2-d0ad1c84dfd1
# 삽입 성공, UUID: af80c4ac-b91e-4a4c-a021-23e61e7f6fca
# 삽입 성공, UUID: fe1ad82b-e22b-4571-8ec7-e277e20db72d
# 삽입 성공, UUID: ec45b27f-7579-4aa3-9237-6b798ca55f3d
# 삽입 성공, UUID: 264c5e1c-c18d-4b64-b715-43f26a649906
# 삽입 성공, UUID: 3f8fd728-f9fd-41af-b1b7-5840ded6bcc9
# 삽입 성공, UUID: 4ab5bcd5-7da0-4a35-ae00-438564fdfd42
# 삽입 성공, UUID: 36486b22-afde-4ffc-88af-ba1d57af7616
# 삽입 성공, UUID: e0495f1a-5012-48a7-bae0-45a83b094eaf
# 삽입 성공, UUID: 7cd9d8b1-caa8-42c5-908a-b762242a0dbe
# 삽입 성공, UUID: 2ce4050b-756a-46a0-87fc-678bbceefb7b
# 삽입 성공, UUID: eac606e9-b1b2-4d8e-b394-79a9f5710116
# 삽입 성공, UUID: 83e4758e-152e-4540-bb69-921dd768253a
# 삽입 성공, UUID: 2b95a510-5c39-476b-bcb1-4dcf0bf6f98d
# 삽입 성공, UUID: 5c644be5-37df-4f6e-90fa-3feb4cfd7ba6
# 삽입 성공, UUID: 09fe059c-6234-4fc6-a549-d798e8460f93
# 삽입 성공, UUID: 9722e745-a10e-45c6-9052-90c4d5525414
# 삽입 성공, UUID: 2a4718d6-db67-49ae-a2a8-166970d2ca5a
# 삽입 성공, UUID: 7b71976d-fe82-49a6-bbf4-494c29b7b49c
# 삽입 성공, UUID: b44a6f49-2364-4a01-be36-bf529b92a4a2
# 삽입 성공, UUID: f489b1c7-47bf-42f7-ac15-4b4eb0af39f1
# 삽입 성공, UUID: f8303756-3476-48e5-939c-fd405edfc6aa
# 삽입 성공, UUID: 683956e4-df97-46ff-b5da-336e87cc65ff
# 삽입 성공, UUID: ee77d5a3-4700-48ec-a4a9-7e2fdbd7ea25
# 삽입 성공, UUID: ba68f00a-dbc2-4695-ba53-4ed481d75074
# 삽입 성공, UUID: cdc960a6-dbb7-4c0b-8733-6e479e743697
# 삽입 성공, UUID: 3426df84-3a4e-4290-8ccd-23e17caab1ea
# 삽입 성공, UUID: 7bfc8d44-c6a9-4fe7-95b5-18c1f806da71
# 삽입 성공, UUID: f0ce2afa-11c6-4889-bb70-9788f148df5e
# 삽입 성공, UUID: 9c441843-e428-41c0-877a-7ce1854ec576
# 삽입 성공, UUID: fdd4cbda-5490-4311-aaac-506c5bde0d08
# 삽입 성공, UUID: 4f2eb707-c2de-498a-ae8b-86ba1bce7b83
# 삽입 성공, UUID: 10cacc2c-6fcb-4f6d-a992-00949b4b6d21
# 삽입 성공, UUID: aa982418-cd5b-48d1-bdf2-1c7c1933b15f
# 삽입 성공, UUID: 084e5325-a507-48b9-a0fe-4f1eca96e11d
# 삽입 성공, UUID: 356a8218-300d-4f41-950f-7d06f1aebebe
# 삽입 성공, UUID: 306bcc31-050a-42ca-8928-36296814f1b6
# 삽입 성공, UUID: bc8d9bc1-0077-457b-8cca-b745bc1bf56f
# 삽입 성공, UUID: b75073f5-ea48-43fa-8c9e-5bb95709406a
# 삽입 성공, UUID: b520890b-d794-4044-8c0c-a4c94eb53ed8
# 삽입 성공, UUID: 715381e8-3022-4430-ae91-5fff8123a4de
# 삽입 성공, UUID: bbb20885-7bd7-452c-a206-452ad1885b07
# 삽입 성공, UUID: 6eb27f8a-54b4-4926-9388-be92fc2573fb
# 삽입 성공, UUID: c817e4d2-0aa3-4359-b44b-605e1e63f263
# 삽입 성공, UUID: 434c84b0-9bc5-4f60-9005-2a06a9c1be0e
# 삽입 성공, UUID: 3ab641c0-393a-4ef1-9044-dd363ba84274
# 삽입 성공, UUID: 762ec11a-34e3-4701-a62f-6f2d6756e536
# 삽입 성공, UUID: 9be22b4a-7ce1-4e79-a9f6-5d7c4d51df08
# 삽입 성공, UUID: 6c0a7d4b-ae32-4c27-98eb-f0c802fd2149
# 삽입 성공, UUID: 4695f6e7-f7bc-4567-9663-7f86d7da100f
# 삽입 성공, UUID: 0c40bed8-7866-4e2e-9f37-719503cbd62c
# 삽입 성공, UUID: 7b489730-0e51-4f26-a6c2-d0971f20d6b9
# 삽입 성공, UUID: 5a232237-5b1c-4000-98a3-7b586f15057a
# 삽입 성공, UUID: 7089e4b0-b2a7-4839-8b26-74a2bb56466c
# 삽입 성공, UUID: 5b1d366e-ee5c-427f-8b47-47c52a6b5097
# 삽입 성공, UUID: a83d2449-fa7d-46fd-9c7d-a8a6a325fb01
# 삽입 성공, UUID: 305609a8-fd81-4e91-8074-ab2bb6cfc846
# 삽입 성공, UUID: 819f2633-1724-4bb9-b570-260ca8d41176
# 삽입 성공, UUID: d2138c35-3a5f-4d3b-8cae-965a3106022a
# 삽입 성공, UUID: 2d0ced3e-73a5-4cb7-8d3b-d4a0cd9430e1
# 삽입 성공, UUID: e62ee9e0-9b9a-4f2a-830c-70e1074b45a8
# 삽입 성공, UUID: ffb229f8-efca-4b2c-a587-6fdae0c81b16
# 삽입 성공, UUID: ed55cd17-f3c0-4ddd-a6fd-d8d84f3d3a14
# 삽입 성공, UUID: c4f9b6e4-0eaa-405b-aea2-2d73793779e8
# 삽입 성공, UUID: 53420094-8cc7-47b2-9445-8117451616b7
# 삽입 성공, UUID: 818949cd-0a53-4647-8618-c673d80fa4ce
# 삽입 성공, UUID: 7fab1d08-c614-46c9-930e-99cd447ca4aa
# 삽입 성공, UUID: 78992a03-acc5-404c-bb70-d98d6f597a17
# 삽입 성공, UUID: 6bea6819-841c-4b33-b980-96025b4e2226
# 삽입 성공, UUID: 50d945f8-17db-49c3-a395-959ef161e654
# 삽입 성공, UUID: 0f6a6700-945a-4e09-924f-6ac1b6ca5698
# 삽입 성공, UUID: 4e9a6ed1-fe20-4746-a1e5-43e8bf7a899f
# 삽입 성공, UUID: b1f61035-acf1-46c5-8a4b-cf9cdcb4d702
# 삽입 성공, UUID: d839f40b-ddce-4e2b-9562-05a0c8832987
# 삽입 성공, UUID: c65e4cd3-b213-44cb-911e-ed184ff9c8ba
# 삽입 성공, UUID: e6f5ef4a-981d-4947-adc4-465a25be4461
# 삽입 성공, UUID: efe03c49-e9cc-4527-8cf0-d33cbaf12ef8
# 삽입 성공, UUID: cd011308-3737-40e5-a713-f73e8f0989a6
# 삽입 성공, UUID: eb02eee8-43d3-4a70-ae22-742c614cc551
# 삽입 성공, UUID: 6988c3ab-b611-44f0-b665-f849cbd57250
# 삽입 성공, UUID: 51e150c1-1511-4bb8-9afc-651ebe2364ab
# 삽입 성공, UUID: 4477f6a9-c7da-41f3-b8b9-6425f94ab3cf
# 삽입 성공, UUID: 22bcbaab-7f65-4bdb-ac0c-96d709f1e2d6
# 삽입 성공, UUID: 36a3b805-cce7-4832-82dd-816c0adfd85c
# 삽입 성공, UUID: e5f75bb6-4ce0-494c-a2fb-18acc653dae8
# 삽입 성공, UUID: 077769bd-4f5f-489d-ba84-f5eaf454a4a5
# 삽입 성공, UUID: 153efb46-82b6-4b6d-ad61-d897541bd5bd
# 삽입 성공, UUID: 6f15923b-20c1-4ac2-b02e-3d6c5d65ab4f
# 삽입 성공, UUID: 2c24d429-70e1-4637-8b39-71a58dfe54c3
# 삽입 성공, UUID: 0fafc80d-883b-49e8-a8b3-8555626097a5
# 삽입 성공, UUID: c7d49d7a-706c-4b28-b76e-cdd073c96bf7
# 삽입 성공, UUID: 39356969-49ed-4442-b02e-1dfbca196a72
# 삽입 성공, UUID: c46ff6be-05fa-4f44-baf9-0426b69352af
# 삽입 성공, UUID: e6849f84-a48f-46fe-aa41-577a95ecf3ea
# 삽입 성공, UUID: 66ee7e0f-da48-4958-8bb2-16a82fbd4d9c
# 삽입 성공, UUID: 0e7dcaca-2470-441f-a1e7-187dbb059454
# 삽입 성공, UUID: ea3ad39b-51c6-4862-9ec4-6f806ae04b62
# 삽입 성공, UUID: 2081f3c1-8f17-4f6a-a91d-7bdb0133e2ee
# 삽입 성공, UUID: 5c40812b-8cfa-4ddd-921d-e97ad8fa1d69
# 삽입 성공, UUID: 66e80152-bf43-4f89-bbf9-561f4fd12aa5
# 삽입 성공, UUID: dba2584d-a79c-440d-93ee-dffe4b48e5f8
# 삽입 성공, UUID: 95ecff74-ec9f-49d1-b96f-9bfaa311ff62
# 삽입 성공, UUID: 1f78afe2-f281-4cb3-9622-49348cd7a692
# 삽입 성공, UUID: 757e90b3-2b94-42a2-9856-b590f9d38e92
# 삽입 성공, UUID: f99a3211-0f82-4906-ae3e-8dfe0ca76b9a
# 삽입 성공, UUID: 8790295e-852e-420c-8cf1-b2a4ae5d48ec
# 삽입 성공, UUID: db4a81ad-e447-4802-b3ff-5a2324e80ea6
# 삽입 성공, UUID: b9adbfe1-934d-402f-b6a9-a0a029b1b294
# 삽입 성공, UUID: 9bb3a674-9cd3-4765-bee9-0d5cbe236b98
# 삽입 성공, UUID: ce554194-0bab-469d-8e26-2da7c770973f
# 삽입 성공, UUID: 0bcadce4-984e-4b85-9f1b-b6bb1767eefe
# 삽입 성공, UUID: d9340c14-c2eb-49a1-8d81-8cd11ebb2f0c
# 삽입 성공, UUID: 6682b216-97d5-4fff-9078-56318549dc1e
# 삽입 성공, UUID: 6f369066-f234-4174-b750-cbf46961dd50
# 삽입 성공, UUID: 643181b9-b7ab-4a9f-beeb-a6ac098ee754
# 삽입 성공, UUID: 7684bef9-cad3-4cd4-a1d1-1e64b94e69da
# 삽입 성공, UUID: 5a79d8ad-d5f0-46a3-beb7-0c11882728fc
# 삽입 성공, UUID: a5e79819-ace2-4954-ba94-1915c86f7091
# 삽입 성공, UUID: 5aa98187-05ce-44bb-8f6d-bf8049cd4a03
# 삽입 성공, UUID: ff5dea5a-d69c-4b8e-933b-eacc52d83e92
# 삽입 성공, UUID: 531702b4-13da-4daf-9dc0-dd57d0880ffb
# 삽입 성공, UUID: 21f91b94-bd1a-4115-a08e-f05a227ba4fb
# 삽입 성공, UUID: fcc1f855-8132-486d-b05a-36f0c76deacd
# 삽입 성공, UUID: 6562142b-fc0a-49fd-91d8-58eb982f4d89
# 삽입 성공, UUID: e5dc1140-e1ff-41c9-a77a-87557fbd155e
# 삽입 성공, UUID: 9f60c4df-1f2c-4061-b9e3-e227820b5ac5
# 삽입 성공, UUID: b6b4ef51-3adc-471d-b31b-5d2d311aa3ff
# 삽입 성공, UUID: 92f34b82-1277-4deb-abe1-d4711cbd92a8
# 삽입 성공, UUID: bb4991c2-46a9-4fa9-93db-6addb1b7f791
# 삽입 성공, UUID: dcc77761-9290-4cc4-b4fd-052e3bb14cc0
# 삽입 성공, UUID: 207681ed-ca7b-4e95-af25-d4958921bb63
# 삽입 성공, UUID: d62e909b-c11c-4ebb-8325-3798f63f5a78
# 삽입 성공, UUID: 7f433fa8-9c91-431c-b33a-0c429ff93145
# 삽입 성공, UUID: 1feba2ec-53ce-4b9b-a2c3-07bea1c09bd5
# 삽입 성공, UUID: 596d0e72-02b6-4b24-8a35-f152a125be91
# 삽입 성공, UUID: e787032b-453d-4ef8-8959-32cf319954e3
# 삽입 성공, UUID: 0075a2e9-42c2-49f1-bef9-6cb64b592882
# 삽입 성공, UUID: fcc8b11c-78dc-4716-94ae-8d0d74c67c0b
# 삽입 성공, UUID: ba38a79b-4255-4aba-8f86-f41e3a56fa99
# 삽입 성공, UUID: d5ef94cf-77c9-44a1-a4fa-322b974311ee
# 삽입 성공, UUID: 27982716-73b3-494e-8a0a-e7c3fdfa2456
# 삽입 성공, UUID: 4932f276-f00c-4a8b-af2d-d043943e0540
# 삽입 성공, UUID: e41eb246-7365-4119-b7b0-1d28097ff033
# 삽입 성공, UUID: ad7d6e66-9881-43f2-bb89-9257f6ba45f9
# 삽입 성공, UUID: cfe300aa-250b-4b47-a963-f633421353e5
# 삽입 성공, UUID: 83214f8e-a51b-43d1-b186-5a7c7c02b36c
# 삽입 성공, UUID: 97bb3ec0-21c6-4a43-a501-0949c95fd2fb
# 삽입 성공, UUID: 29777dec-b88f-4364-9420-12940688479a
# 삽입 성공, UUID: d8de3f76-e322-4b14-8b64-87c201ae4cad
# 삽입 성공, UUID: 0e64628e-591e-445f-b2e4-a484c962a4ea
# 삽입 성공, UUID: d0c814bc-302c-4701-b7a2-abb85aadf938
# 삽입 성공, UUID: ed46d7f3-6a9b-4031-9230-9e64921fd75e
# 삽입 성공, UUID: cd3aa06a-9b1f-4a8e-b563-e479f83e95ac
# 삽입 성공, UUID: 926e37ca-8c72-48a2-9926-618e5bed2733
# 삽입 성공, UUID: 0f8797f3-5694-48fd-b4d5-ba79907fc3ed
# 삽입 성공, UUID: f09b5545-f086-4d2b-98e8-e28eaf0a01ed
# 삽입 성공, UUID: fd516155-bfb5-45fa-a301-2ad9a165c680
# 삽입 성공, UUID: 3e270053-9c1e-4a4b-9f63-077982cf6ff1
# 삽입 성공, UUID: a3e2c91b-0550-42f9-9cab-5f629ae4bf01
# 삽입 성공, UUID: f2c6512a-50ca-4c9b-9773-ae9b5932e367
# 삽입 성공, UUID: 24bf8968-1760-473f-98ff-d5108f6bf1b2
# 삽입 성공, UUID: 3250a382-f534-4010-a0ee-17ae2a38da13
# 삽입 성공, UUID: 0c348c01-12ac-41b6-8797-878d90f01290
# 삽입 성공, UUID: bd0139d9-cbad-4341-8224-58d586bfb10e
# 삽입 성공, UUID: 8847b7aa-b0df-4d6b-b67c-74508179d6c2
# 삽입 성공, UUID: 81be44b3-91dc-4827-aa19-2289791ff5e8
# 삽입 성공, UUID: aa62e2d9-52e8-49cd-8e77-4f84fae394c7
# 삽입 성공, UUID: a2c649a5-397d-44d4-9bb2-0f4fb723d310
# 삽입 성공, UUID: 5483a79d-2571-434f-bf6a-837c58f776cf
# 삽입 성공, UUID: b759cb9c-619a-458f-8bcf-0b26f808a0d6
# 삽입 성공, UUID: 42156a0c-1bae-4fd5-b730-9affcc8ea23c
# 삽입 성공, UUID: 33e38083-2531-49e6-b184-e92485ce158a
# 삽입 성공, UUID: bbad3e1d-cabb-4536-abeb-c74c21946682
# 삽입 성공, UUID: d199f633-87e6-474d-a8a3-15441ca9b4af
# 삽입 성공, UUID: e87199e6-1487-46e3-b2ba-74d6f78fac0d
# 삽입 성공, UUID: 2e1c0d8f-20ee-4822-ad16-452c1aa5dc05
# 삽입 성공, UUID: 09e494f1-86f8-48da-b665-6302c8dc6856
# 삽입 성공, UUID: d8e34fed-b407-4862-9bb9-d4c6e939d70d
# 삽입 성공, UUID: df8e861f-b6a1-4856-b626-dc07b293796d
# 삽입 성공, UUID: 9484b629-c494-463f-88c0-96113e3c49eb
# 삽입 성공, UUID: 7b7d1c0a-9103-4ba8-a67e-4f172cb756ec
# 삽입 성공, UUID: 339dc312-7c17-4809-90bf-0a4034d68447
# 삽입 성공, UUID: 7f11a1e7-ea85-4863-8986-a101c4eb080f
# 삽입 성공, UUID: ed10a43d-fdb9-48df-ba69-588a7ba9e33f
# 삽입 성공, UUID: c6996a17-96ba-4bc8-b447-0da46aa337c5
# 삽입 성공, UUID: 92327a5f-330f-4f9d-bdfb-e937c3215231
# 삽입 성공, UUID: f21ff3c4-b561-4d62-9c97-8d815c5e6a6e
# 삽입 성공, UUID: 3a9837ea-17eb-4278-b0c3-30dcf4bb9d04
# 삽입 성공, UUID: 5df42cd9-150e-4942-b16e-022a15ba14ef
# 삽입 성공, UUID: c375fd7b-d051-41fa-be4f-fdd8ddceebc9
# 삽입 성공, UUID: 74dc3ccf-c287-475f-989f-6257ae72b103
# 삽입 성공, UUID: c0cf68db-970b-4b4f-9e8f-0146939d5174
# 삽입 성공, UUID: 960c6774-8dc3-4972-ae65-696be43dc903
# 삽입 성공, UUID: b6ea4b39-d684-4329-826b-0b87ff348c7a
# 삽입 성공, UUID: cc4f2c71-61f4-4d68-991e-085fe5b13883
# 삽입 성공, UUID: 298fb770-9640-4ee8-b2bb-8e7d8f847b0d
# 삽입 성공, UUID: 419c4cea-55c5-477a-8af8-98ebf262c2e3
# 삽입 성공, UUID: 6fe7e217-526f-4367-9fa4-e2f524055a54
# 삽입 성공, UUID: 96d58194-3e96-4ba6-8416-2511c77baa8a
# 삽입 성공, UUID: be31dc22-4c78-4e2d-9610-9e4fff6e5a9a
# 삽입 성공, UUID: e47358ad-bf11-457b-8bc9-94fbde2b0f31
# 삽입 성공, UUID: b5f940b5-6279-4f40-badd-66ae293912ff
# 삽입 성공, UUID: 23f8752f-19db-4f4c-b21b-900f3dece011
# 삽입 성공, UUID: 3b610730-2692-481a-b165-0e9e0d7d47f5
# 삽입 성공, UUID: 0e2f8bd2-eb96-472c-a2b9-38b2c497611d
# 삽입 성공, UUID: d1ba3a66-49fc-476a-b064-4150618be21d
# 삽입 성공, UUID: f39e3086-f83e-425c-a612-f101b8e6977d
# 삽입 성공, UUID: 8bc93ab9-9722-4377-841d-d890c7c40b25
# 삽입 성공, UUID: af764a67-df6f-45d5-8e23-3ab526776fc1
# 삽입 성공, UUID: 785b09b2-860c-4367-976f-04880e1eb031
# 삽입 성공, UUID: ba068572-63cc-44c5-bb3b-a4434ef8ec7b
# 삽입 성공, UUID: 3bd3870a-8652-49a8-84e3-6ff787c43682
# 삽입 성공, UUID: ac82b649-e5d6-4a6e-9416-1c78699013ef
# 삽입 성공, UUID: 64ced910-4aac-42bb-9365-7b3d53923587
# 삽입 성공, UUID: 0013a8cc-83eb-4b0e-8b38-4098f80a8e1e
# 삽입 성공, UUID: 68b31f0e-f0fb-4518-af85-978af41a2042
# 삽입 성공, UUID: 8bc7d549-f374-4d62-811d-b31955b65459
# 삽입 성공, UUID: 29e771b0-f286-4940-b3be-dff57401aca2
# 삽입 성공, UUID: 265e4d95-d77c-4bcf-ae8e-7df59ac6b37f
# 삽입 성공, UUID: 5882dd16-70de-4765-b803-98e76c67b0b4
# 삽입 성공, UUID: 3081e84b-ace8-4c54-89ce-bddc1d68995e
# 삽입 성공, UUID: 1bdb80a0-60f1-4eb6-89b8-06ade7cd5bb9
# 삽입 성공, UUID: 9034f38e-291a-441f-8845-cc0a0c81c5f3
# 삽입 성공, UUID: dd94bfb8-1171-44ba-9162-3030abbea674
# 삽입 성공, UUID: 21550cba-a468-41e6-b86c-d6ff175eddfb
# 삽입 성공, UUID: 7f5e0eaa-c2b2-4994-a01a-ad8988db7e84
# 삽입 성공, UUID: fb13e7af-f88d-4eb5-9e05-3109f697224c
# 삽입 성공, UUID: 1838d8a8-b605-41fe-a98a-b12a908156d4
# 삽입 성공, UUID: f36f0762-777c-46e8-b844-c302ee83db96
# 삽입 성공, UUID: 4749a044-ae49-434d-bc19-b83192227687
# 삽입 성공, UUID: 7ed5b978-6a52-472a-b274-c7ef9d08117a
# 삽입 성공, UUID: 0f74839d-e419-4516-8e0a-2837fb4f3664
# 삽입 성공, UUID: c257305d-4e94-43e1-89e6-afa3a4109543
# 삽입 성공, UUID: bbf848fe-b124-49a6-b13a-c9cc450c8d03
# 삽입 성공, UUID: a2e4755a-ce52-40db-b573-73729da7ffb8
# 삽입 성공, UUID: a6a4b952-709b-49e6-93ee-c3c2b3b34ba9
# 삽입 성공, UUID: 050d9317-1def-4b5c-859d-eda335cd5148
# 삽입 성공, UUID: b7527dc1-493d-4ec5-86bb-d4c463268283
# 삽입 성공, UUID: 00e896b6-f8da-44b0-8e46-f1b925710f67
# 삽입 성공, UUID: db2c2afd-1e47-4a33-9d9d-923970cabbb1
# 삽입 성공, UUID: 913565e7-6d75-4b7a-a061-e6bf445970e6
# 삽입 성공, UUID: 83291891-611c-4a12-a2c2-66c027561a57
# 삽입 성공, UUID: 7eeb80e3-14f5-44b0-9a6a-e0c46f69e984
# 삽입 성공, UUID: 932fa19e-9c10-4e8b-af89-b140683b6296
# 삽입 성공, UUID: 6f3c3feb-f372-4acd-9e8c-150a9bfcc07f
# 삽입 성공, UUID: ca4a454b-3de0-43e7-ac63-6d26cd115518
# 삽입 성공, UUID: 55e735c7-5d68-4ffe-a229-85015e578c6c
# 삽입 성공, UUID: 136d861e-ceb0-4071-8b10-00ebae668207
# 삽입 성공, UUID: 1e975ca4-9218-4279-977a-12cd4b31bb2a
# 삽입 성공, UUID: d084e504-a5cc-4387-bca7-d072ce0dbaf9
# 삽입 성공, UUID: 76f86f4b-7236-4e45-908d-37ce027d8467
# 삽입 성공, UUID: 41c37049-ccd1-4241-9102-04717211b47d
# 삽입 성공, UUID: 47993d7d-810f-48df-a4e8-f2e69498813e
# 삽입 성공, UUID: a8af7860-87cb-45e9-9d26-7abc9f36e314
# 삽입 성공, UUID: 4b4443e0-793a-4695-96db-9bee55fb404f
# 삽입 성공, UUID: ad8bbd1d-9ada-439c-9b0b-5dc667f2f8da
# 삽입 성공, UUID: cdfa6437-6317-4da9-be55-cf9c9f53ea75
# 삽입 성공, UUID: 46773f29-0750-4b8c-8c1c-4aacb8bfb39a
# 삽입 성공, UUID: 389b95cd-7773-43c7-94d8-724ed55c4ab9
# 삽입 성공, UUID: 7ad0dabc-f9f1-4c57-808f-ee58938425c9
# 삽입 성공, UUID: 90bff103-be3a-4132-8a1f-cde6f955723b
# 삽입 성공, UUID: 67da6602-c5bd-46de-a811-b0d5ffe6ea02
# 삽입 성공, UUID: a89da636-f592-4396-8c82-a2f4645d1507
# 삽입 성공, UUID: 860d121d-5e47-46b7-bd1c-109a52b72ae3
# 삽입 성공, UUID: cc6a03e6-d7d5-466e-8b0a-9bec520c0d21
# 삽입 성공, UUID: 6fbf8c80-eac3-4be2-9cc0-6a2dd1301eaf
# 삽입 성공, UUID: fffdc7b1-60d6-4a3c-97cd-7f5193d2534f
# 삽입 성공, UUID: d37786b9-49b3-4a37-aa35-d99a31d3d3a8
# 삽입 성공, UUID: c48957e1-b3ee-446d-ab6d-160624972c54
# 삽입 성공, UUID: 3e025db7-e53f-415b-8bf7-58803796a598
# 삽입 성공, UUID: ecacb979-ca59-44bd-9326-48ea46e64ed1
# 삽입 성공, UUID: 287a30c9-209a-4764-9f79-a226da10d6cc
# 삽입 성공, UUID: 750cab7f-cdf1-43f6-81ba-1e72def7ffc2
# 삽입 성공, UUID: 366c1790-b03c-4a28-8c9c-404279633270
# 삽입 성공, UUID: 9ea1a3de-8f8a-43c0-9a08-b773de76f36b
# 삽입 성공, UUID: daa28863-ea28-4a31-93f4-0a857b752743
# 삽입 성공, UUID: e0490fe0-aef1-4e59-9c07-152e1f302cf3
# 삽입 성공, UUID: 0951d099-51d8-43bc-8e59-24d8e666a8c1
# 삽입 성공, UUID: b89ee55a-05d5-4e19-a9c7-687ebaa24491
# 삽입 성공, UUID: 99a86ab8-8742-4dde-a5c7-49c87b1ed691
# 삽입 성공, UUID: cf9279c3-2df2-4de5-b968-ec07188cb2fb
# 삽입 성공, UUID: 99a90c7c-add9-4904-bd76-7260a7719914
# 삽입 성공, UUID: 3546594a-6483-4a5d-bc38-82f4f3c7851f
# 삽입 성공, UUID: 557f69df-61ac-46be-b42b-29632047d965
# 삽입 성공, UUID: c5af6d84-f462-4b35-ad46-6ec3ddaf49e4
# 삽입 성공, UUID: f4413521-ea52-40db-971f-fb67def6ec96
# 삽입 성공, UUID: bff92396-fb52-4084-82ac-8a1b6b849528
# 삽입 성공, UUID: 60aacfa4-99a9-4a81-8eb0-8b1c395a1b47
# 삽입 성공, UUID: 474690a7-f07b-4a09-97f6-490f22d64cac
# 삽입 성공, UUID: 8c86bf96-ea50-4d7e-a907-d04f36c0f892
# 삽입 성공, UUID: aa243e93-ba10-42e3-9d1c-dd8cc684ca13
# 삽입 성공, UUID: ad23c930-b6d4-493e-9dc5-dcdb5628a721
# 삽입 성공, UUID: 366d9f4a-fb47-46a5-8f4b-1a9302249a6f
# 삽입 성공, UUID: ae933648-6cd2-4a45-b52f-b9ca8d3cd4b6
# 삽입 성공, UUID: 5975c1be-b9ff-42a5-8400-a13566f515ef
# 삽입 성공, UUID: 5181f934-7f97-4284-a054-c2b5858c5ba8
# 삽입 성공, UUID: 85e79b80-8bfd-4f28-9174-d7a5c457da81
# 삽입 성공, UUID: c30ebf82-6e73-4d9c-8514-1e629c4f34bd
# 삽입 성공, UUID: a3905e72-8e99-4113-a2b9-96b4c385cfe7
# 삽입 성공, UUID: 299fc559-5680-42d6-be64-1df955843108
# 삽입 성공, UUID: 4fcdcbb7-5c8d-44dc-925c-09cee94ca6e6
# 삽입 성공, UUID: 8ca38f66-03f9-441f-9c5e-9cd03259cb47
# 삽입 성공, UUID: 5155243c-13c9-410d-88b1-e5023017b9ee
# 삽입 성공, UUID: e703a3b1-b1aa-4ab0-8cc9-09aed534859c
# 삽입 성공, UUID: 524be9bc-23f6-44a6-9fac-86acfccbc8b5
# 삽입 성공, UUID: d507f935-ec64-4f3b-bdf9-3648fa2d6b18
# 삽입 성공, UUID: c764e2f8-8cbe-4573-ada6-623aba3099fb
# 삽입 성공, UUID: a6624bc6-6d70-4454-b433-070d0161f337
# 삽입 성공, UUID: a22341a3-f394-44ac-943e-6d6ff4b0cd25
# 삽입 성공, UUID: c2a8564c-c506-4729-91eb-731d35570c02
# 삽입 성공, UUID: 5670ee9e-928e-4ca6-a3b9-c24f534200cd
# 삽입 성공, UUID: 9b53e4dc-48fe-4e3b-b544-3ffc687961fd
# 삽입 성공, UUID: ede1ffb6-eebf-456c-aa0f-1fed8070494e
# 삽입 성공, UUID: e9b7278c-fc68-4624-9d1a-f5cc1503ff79
# 삽입 성공, UUID: 7912b585-3b6c-41a5-975e-1463fcf17325
# 삽입 성공, UUID: 7eb6e802-cb9a-48e7-8d19-0a5f5ebaf8d0
# 삽입 성공, UUID: 99bec0a5-03e6-4cb0-a300-3cf22e8c1706
# 삽입 성공, UUID: a2edf398-4314-4e35-897f-e9771347fab3
# 삽입 성공, UUID: ad27b6ef-ce8c-4a7f-80e2-30fd30377974
# 삽입 성공, UUID: 2615130a-e517-4f31-b89f-16643d2aa244
# 삽입 성공, UUID: 39a0179a-63a4-4f95-9f79-263048b58c84
# 삽입 성공, UUID: 1672738a-7cc5-47fb-8c24-d2500cad1756
# 삽입 성공, UUID: e9820f40-b803-44b4-b02d-268cfd1b5882
# 삽입 성공, UUID: 9ae38475-43c6-416a-88b0-bdb5ef1ab19a
# 삽입 성공, UUID: 8f518620-9304-4b54-aa17-a01121ce5fd2
# 삽입 성공, UUID: 53299c7a-228d-488e-bdd9-264264b69740
# 삽입 성공, UUID: 399d8537-a17b-4bba-a4f8-a4eb227ca4f2
# 삽입 성공, UUID: cb107b17-d06c-4e4c-8112-b83e885d4ccc
# 삽입 성공, UUID: 38c6f933-15de-4c32-8a3b-2c6618819769
# 삽입 성공, UUID: ce42467e-8a8c-4e2e-b953-21f1e8af9463
# 삽입 성공, UUID: 80a5f520-e084-4f92-926f-7c79acd21d7b
# 삽입 성공, UUID: 1198fc24-9420-4e78-aaf6-3d6183dd6bdb
# 삽입 성공, UUID: ea3ef3ee-9004-4477-9cb4-838ae86bd4b5
# 삽입 성공, UUID: 16a3e3e6-490d-450e-bfbd-69e2c4453305
# 삽입 성공, UUID: 80ae7645-1b5f-4c89-ad0e-66dc7a527900
# 삽입 성공, UUID: c7f2e9e8-015e-407e-9ece-3247a77725fe
# 삽입 성공, UUID: 5bb64f00-18ea-4a30-aa83-25104502f84c
# 삽입 성공, UUID: 407be9a2-634b-4489-acc1-ae0a3b914222
# 삽입 성공, UUID: f6ab3428-016f-4024-8935-ade45eff5b3c
# 삽입 성공, UUID: 35c5774b-c421-4835-88e0-3734bb7d3aea
# 삽입 성공, UUID: 8bdcc198-2987-4e70-8723-54678ba8de15
# 삽입 성공, UUID: 25b317ed-b6dc-4d13-a5b7-57aca7b202b3
# 삽입 성공, UUID: 02cb5e20-f2c2-48c3-98d0-52a3c85ed5e6
# 삽입 성공, UUID: 656e4e4e-bbd2-49a5-8bd7-044b63c7a2eb
# 삽입 성공, UUID: 96d8c06e-e29f-4227-8959-f27c1fb0418a
# 삽입 성공, UUID: d5bb1b74-59d4-4d95-8adb-4f0d960effde
# 삽입 성공, UUID: 285401ab-c823-4657-bfa2-8caa1aeda46a
# 삽입 성공, UUID: 9f57b98d-33e9-42f5-8033-01729019bb97
# 삽입 성공, UUID: 8773ca9b-3775-4922-8a7d-b93430ada8ed
# 삽입 성공, UUID: 1ae9d097-6a41-4a0d-a8aa-21375616b992
# 삽입 성공, UUID: 51523a16-5c99-4350-b9a9-edb2fc717add
# 삽입 성공, UUID: 2880279e-fa44-41ae-a972-808d84367765
# 삽입 성공, UUID: b8d7e3da-f822-4562-903a-7da6de535703
# 삽입 성공, UUID: c6a8ccfc-7076-4c7f-9330-27a3bf390286
# 삽입 성공, UUID: d1470329-51cf-4ce3-844e-7386aa2c8f15
# 삽입 성공, UUID: 4f6eda05-1f6f-4d72-b4e7-117f7850bacf
# 삽입 성공, UUID: 60f612c7-d67e-45f3-a999-97d36a8f2382
# 삽입 성공, UUID: f7a9b93f-8b65-4d16-907e-5cb344243bdf
# 삽입 성공, UUID: b7909878-1d03-47e7-bf45-6eb161717ffd
# 삽입 성공, UUID: 3c278040-f5e3-4532-b93c-99f6235a4d14
# 삽입 성공, UUID: 1e263179-4ff8-44b4-9c65-5e520918937b
# 삽입 성공, UUID: 2e9474d3-7c0c-46b4-990f-ed1df9aaf3ce
# 삽입 성공, UUID: 94833ca3-3d55-4102-a63d-87717d44325d
# 삽입 성공, UUID: 2826acc0-736a-4f0c-8a29-2f6ea3dd55bb
# 삽입 성공, UUID: 236a6e67-b1f3-41b6-9949-9d4b34cf8618
# 삽입 성공, UUID: c939c0f1-4c4c-40c5-93f7-0be21c7bdad6
# 삽입 성공, UUID: af775447-2fe5-4e9e-908e-45327723b9c8
# 삽입 성공, UUID: 7dd18511-bf6b-47cb-bce6-b421c9f7da2f
# 삽입 성공, UUID: b623585b-6c35-46e0-aec9-3e7e4e114462
# 삽입 성공, UUID: 49a831a0-c690-47e8-82fe-d3bd8035365e
# 삽입 성공, UUID: 5abc5e33-6086-42cb-9ca6-45abc6fdc67f
# 삽입 성공, UUID: b34bea89-9c78-40b2-9853-a7cd4cd78a9c
# 삽입 성공, UUID: 2b94c6f8-4de8-4f24-94f7-101ca64eba63
# 삽입 성공, UUID: 9b9d71ae-5e6a-4c37-82e1-71f566af67e2
# 삽입 성공, UUID: 4669ec83-9fba-45a2-93d4-1aaffb93b0c3
# 삽입 성공, UUID: ee455cf5-286f-4c6c-a3ef-22d84bbc8353
# 삽입 성공, UUID: 7b09f618-263f-4c6a-833e-38beda502fbe
# 삽입 성공, UUID: 9692d5ef-f8b0-416a-8930-90f1ae13efc0
# 삽입 성공, UUID: 134cabac-8c70-465b-873e-9fc27ca9f05c
# 삽입 성공, UUID: 0cc56b9f-969b-4b48-9f73-9eda65ac71e5
# 삽입 성공, UUID: 8d26af0a-b77a-40ae-9372-4a81f68f17a9
# 삽입 성공, UUID: 4370e757-0756-462c-9a6e-0875d8c749e1
# 삽입 성공, UUID: 5a32f781-6b94-4545-8eaf-a03dc99e9b7d
# 삽입 성공, UUID: a9bce950-07fd-4297-9f4b-aab33c3954cf
# 삽입 성공, UUID: d5330534-a8d9-4f6c-bc54-df5ddb6623e1
# 삽입 성공, UUID: 6da7aebe-cf48-4a77-9ca4-df32c1bc65e0
# 삽입 성공, UUID: c003ba5d-736a-445d-815b-bb33a2553b55
# 삽입 성공, UUID: 717aec9f-2e2f-47cb-95f8-afa1331c7645
# 삽입 성공, UUID: a0edcbbe-51f1-41ef-8df1-97473e58e443
# 삽입 성공, UUID: 7dfe4251-f243-4c0b-85cd-caa968609029
# 삽입 성공, UUID: 3a2c3816-246c-4ffd-978b-f9a73d0d3b1c
# 삽입 성공, UUID: ef180de3-ece7-4658-a958-7f76e1d02fc5
# 삽입 성공, UUID: 5c79707d-0f41-478d-b573-65f1769eb902
# 삽입 성공, UUID: 0f21b416-70cf-4c15-b420-1e34a9881776
# 삽입 성공, UUID: 6e691290-68ce-4c99-9dca-fef4297a9b01
# 삽입 성공, UUID: 7ee6e907-aa13-4b69-81cb-6b8b7d9057c1
# 삽입 성공, UUID: cec04baa-4395-4883-bee9-5142e3f4d933
# 삽입 성공, UUID: 6615c561-77a7-4848-8e16-7a368c00e6ac
# 삽입 성공, UUID: 88b71f32-d53b-446a-a575-83c79733bce6
# 삽입 성공, UUID: 45e50e12-3be8-4fb1-a3eb-81f058eb3387
# 삽입 성공, UUID: 3457274e-bfa9-45a5-b126-1a8e9b4b24bc
# 삽입 성공, UUID: 395ee61a-15be-4c76-be62-ccf4d8b73b6e
# 삽입 성공, UUID: 262337b5-f805-489e-b71c-74e88462d354
# 삽입 성공, UUID: 8b209e7a-62a9-4d2a-bc43-1f912b5704eb
# 삽입 성공, UUID: cb30b2ad-c7f8-43e8-8798-39a60403a625
# 삽입 성공, UUID: 8d632bd7-252e-48ba-8067-de316e518ebb
# 삽입 성공, UUID: 0986ed72-2d24-4c72-b11f-28fe76576efd
# 삽입 성공, UUID: 8d1df172-ee13-4b19-a407-369bb7c6d1da
# 삽입 성공, UUID: b52bae7e-5aa3-4d3e-9d54-74ff0b5f9c09
# 삽입 성공, UUID: 3dad28ed-a637-47fd-8174-56650dda5aa2
# 삽입 성공, UUID: 81f42141-e1b0-49e6-8f3b-814a94bcb90c
# 삽입 성공, UUID: a6461c39-7c82-4ec8-96f7-1f5e0df834b8
# 삽입 성공, UUID: 6039fcad-53af-431a-bfd4-2cc8534ca99f
# 삽입 성공, UUID: ec69ab54-f8b7-416e-ab15-2248ad1d0602
# 삽입 성공, UUID: bbb73928-7667-4bb8-ab81-29f7a46a4788
# 삽입 성공, UUID: f4b577e3-71f8-469f-bcc1-28e8a01a76eb
# 삽입 성공, UUID: 57b66173-b062-44d7-a2e6-1a3825dcbb8f
# 삽입 성공, UUID: cb611920-c4c1-4f73-8f2b-ba206dd499c1
# 삽입 성공, UUID: a5bb0a46-dd8e-45a4-9308-276ba8519bd7
# 삽입 성공, UUID: 0d9d9886-95d2-4927-8415-fc4b0e8241a3
# 삽입 성공, UUID: 06126a16-4162-401a-97c8-39465aba419a
# 삽입 성공, UUID: 6e272368-7cca-41df-9b9c-204b0297f559
# 삽입 성공, UUID: 5ec2e389-f27e-43c7-af56-1cac21f2ecfc
# 삽입 성공, UUID: e7d2d6a0-6831-40f2-b2b2-011a64abd8db
# 삽입 성공, UUID: 35498293-1370-41cc-9274-ed9d49036cb2
# 삽입 성공, UUID: 1b05b619-e53b-40d1-b3bd-5427ba2e963b
# 삽입 성공, UUID: 7cc0c979-9ba3-4c9f-a1e0-9e825e6ff27d
# 삽입 성공, UUID: 5cabf781-b68c-4212-a99b-9d5bb4e26e1c
# 삽입 성공, UUID: 55a6460b-6fe8-446a-a61c-8c5f6c7172f7
# 삽입 성공, UUID: cbfc4aa7-be48-4e6b-9473-4a7dcca221a1
# 삽입 성공, UUID: 58b28e0d-7871-454a-9aaa-83ba3f701d58
# 삽입 성공, UUID: bea6a2ba-dbd2-47a2-b6e6-7460f1cee598
# 삽입 성공, UUID: d4947896-d92e-4903-a51b-015be476df8e
# 삽입 성공, UUID: 38ba0266-83ac-44f8-a55f-1dcde3954267
# 삽입 성공, UUID: c06c3f44-2dc2-49ed-9e04-0eef6941a6be
# 삽입 성공, UUID: 4bbdd4c6-06e0-41f7-9268-bf9619df1655
# 삽입 성공, UUID: 8aea4f42-a82f-4799-adc6-3a6407f9c2ea
# 삽입 성공, UUID: 77d100c1-2968-4fa1-86d1-51c1b8f77d35
# 삽입 성공, UUID: 5b67f107-1528-4cec-ae88-ba2d89cd15b1
# 삽입 성공, UUID: 09f4c838-69b6-4a6c-ab6a-0c826f389f17
# 삽입 성공, UUID: e267f2fd-580e-48c1-acf1-86e3ca5b596c
# 삽입 성공, UUID: 3c6678b9-af45-495a-9df2-505e4f7b7f50
# 삽입 성공, UUID: 9b7a82b0-ec5b-46ed-aa18-561339f698b1
# 삽입 성공, UUID: 5174fba0-7384-4e4c-a587-4216098b702e
# 삽입 성공, UUID: 3447323e-420d-41c3-b443-6c1ea48930fd
# 삽입 성공, UUID: 559983f0-1d26-460c-a38f-e6bdf9e30251
# 삽입 성공, UUID: 8ee76fb9-ccd7-4b72-a763-4ff1215a8da6
# 삽입 성공, UUID: 884a14af-ed41-4689-b327-1415f80f97b4
# 삽입 성공, UUID: 315adcc8-68d7-4c36-b657-6a6ba6cc38f1
# 삽입 성공, UUID: 52c481dc-3242-4e8b-8a76-5b77e8522c57
# 삽입 성공, UUID: 924f46f9-9b78-43c9-9328-a55494d720ac
# 삽입 성공, UUID: e5c3cace-c3f0-4e87-81e4-d5de411405c2
# 삽입 성공, UUID: 3d6fb985-a248-498c-a09f-4e4b39e97105
# 삽입 성공, UUID: 5c94922c-e1b6-4bc2-968c-80e3029133e3
# 삽입 성공, UUID: a6700fe3-384c-48a6-a0a0-2884a7faffd2
# 삽입 성공, UUID: 0cae448f-e75b-4bd6-9995-d19b5d1c2be4
# 삽입 성공, UUID: 7efd6911-f23d-47e3-ac14-9348f592b860
# 삽입 성공, UUID: 59123141-4f09-4b2c-8924-2a35ee30fd09
# 삽입 성공, UUID: b5234913-ceb5-41c4-b570-bc040c9b382d
# 삽입 성공, UUID: 7a472446-62ea-440f-8978-7200894fb1f2
# 삽입 성공, UUID: 5b7056e5-e597-4a45-b419-4e3d26f6d65d
# 삽입 성공, UUID: 05ac0153-bd46-46fe-9c42-b8f3bb3a4965
# 삽입 성공, UUID: 73181670-bcc6-4e9f-8a6f-f1089c50fda7
# 삽입 성공, UUID: ccfde179-53ee-4b71-95d8-bef61a6fa438
# 삽입 성공, UUID: fb0082ba-3fec-4d3d-8d65-d924ade2f5b7
# 삽입 성공, UUID: 035e4093-095a-4eff-9b29-edf32c9f5fbe
# 삽입 성공, UUID: 3758ee3a-fb99-4288-b090-c8f90e8f400d
# 삽입 성공, UUID: 78b3bfaf-4f99-4162-a32b-c80e5fb96977
# 삽입 성공, UUID: d836834e-6d59-4fe9-8680-43d1e1825c27
# 삽입 성공, UUID: a7b90778-1b9d-4e3f-b80d-0dbd8bc19ca7
# 삽입 성공, UUID: b45c0576-9f64-47fb-b8c9-f467f4298547
# 삽입 성공, UUID: 53d4e0b6-fdbe-41d7-a201-1934ba1d4ef2
# 삽입 성공, UUID: c8633f1b-d8c2-4797-a270-6d4c9318fe6e
# 삽입 성공, UUID: 30cab078-2d7a-4489-b5e3-e15ddf637bcb
# 삽입 성공, UUID: c0599bbc-be76-4501-a63c-4980e97d2427
# 삽입 성공, UUID: 3f9e51f3-dec0-4b79-9d57-f973caafc9b5
# 삽입 성공, UUID: 89fc3e7f-e4da-4bfa-b0a3-3ca25a99bb68
# 삽입 성공, UUID: 71507af5-0a86-44b6-918c-30d1e0963eec
# 삽입 성공, UUID: c7f8b70a-a7d4-43e8-b3ac-f08094294f17
# 삽입 성공, UUID: c9dec059-fd47-4520-8a79-3da3aa51f00b
# 삽입 성공, UUID: 70536070-0d90-470b-aab2-edd42d99dba0
# 삽입 성공, UUID: bda3923c-cf47-43a9-b0e8-f37693ec188f
# 삽입 성공, UUID: 07aba489-9075-4bd4-85ba-baf2e5b4a050
# 삽입 성공, UUID: 6f08e4c7-93d5-4fc2-a439-a621ef9a69b4
# 삽입 성공, UUID: 56bff8c8-2e40-44b2-a554-65b7b21f5ace
# 삽입 성공, UUID: b57d05f5-5c3e-4d32-bf87-227ac47fa5fc
# 삽입 성공, UUID: 3ee07b2c-68fd-4ce3-babb-58a1ce8c97d1
# 삽입 성공, UUID: 57999f55-dffe-40b6-aa83-132e63b67e9a
# 삽입 성공, UUID: b4a06240-fd00-44de-b181-4f2db8ab53ee
# 삽입 성공, UUID: ce030402-1a63-4c12-854a-649955f07a92
# 삽입 성공, UUID: 931ccc0b-75ae-41b4-83b1-17d042689f7c
# 삽입 성공, UUID: 7de919b8-3e2e-4507-833f-1f71932ffebd
# 삽입 성공, UUID: f1affc58-be1e-42a7-b953-26ab14acbb03
# 삽입 성공, UUID: a3921013-c26f-4186-8e12-1cc456908a75
# 삽입 성공, UUID: 24eb36c4-e50e-4553-90b4-bef19f1abd51
# 삽입 성공, UUID: 8183a57f-6ea7-40b9-96c4-19d274d43248
# 삽입 성공, UUID: 10528f2b-f30a-4650-8cc1-d4e17516c54c
# 삽입 성공, UUID: f21316b2-06cf-4a8d-a8f6-f6b7047f0a42
# 삽입 성공, UUID: 07bb36b8-1daa-429b-bb8f-c7cb6abd07f4
# 삽입 성공, UUID: 1d80aff2-3fe1-4464-bca0-4e66681329dd
# 삽입 성공, UUID: 2f399a14-3b3d-4bd0-a74d-93c845ace78a
# 삽입 성공, UUID: 6c9a452e-e2c2-4fce-8389-3d92fbf2b962
# 삽입 성공, UUID: 8e1b6b4a-9b45-4580-b91f-2a62eb825380
# 삽입 성공, UUID: 285cf752-3fb3-495e-a8b9-bddbaecc45a1
# 삽입 성공, UUID: 7c91656b-d098-47b9-b412-ba03540c2db4
# 삽입 성공, UUID: 4ca1ac4e-d059-4c03-8f30-209a4bd45589
# 삽입 성공, UUID: b7afcd1a-ca99-4b0d-a590-104561c432af
# 삽입 성공, UUID: dbfccf26-4d72-4140-9132-749483c8ce08
# 삽입 성공, UUID: ae32685b-642b-4580-a46b-1e43be1a460a
# 삽입 성공, UUID: 554d7fb1-9d48-42f8-ae87-c29f492f8fad
# 삽입 성공, UUID: dd946594-8887-4441-91c5-10e245849ecb
# 삽입 성공, UUID: ea51b64b-5757-498b-ba58-50b9a40e7e27
# 삽입 성공, UUID: f36fdf3c-5844-467b-bdc7-43b44245c079
# 삽입 성공, UUID: c77347da-3a3c-4501-9f53-13ea8fe84a21
# 삽입 성공, UUID: 5f5f32ff-0184-4462-80df-4cd9decba0a4
# 삽입 성공, UUID: c67b6478-a930-48fe-8d72-d3fe847e46ee
# 삽입 성공, UUID: 97590b59-99b4-425d-a033-60e1d9531112
# 삽입 성공, UUID: ced4de1f-46f7-414c-b902-31ca9361d75b
# 삽입 성공, UUID: 49a8cdd6-cb36-429f-84f2-2632c9f34e44
# 삽입 성공, UUID: 9bbd8074-79e6-439d-bf27-effba5c847c8
# 삽입 성공, UUID: e730f13b-8268-442c-934c-950c21d8cccb
# 삽입 성공, UUID: 263b5f5a-47f6-4495-8d6f-d34779d91cb6
# 삽입 성공, UUID: 4eebe2db-eb4f-44bf-9913-6352535d3fa5
# 삽입 성공, UUID: dcc8423f-4b3a-4484-9287-dcc2a4020e3d
# 삽입 성공, UUID: 452af832-741c-4b34-a6cc-e5c21e8e9514
# 삽입 성공, UUID: 658cfb60-9071-4433-b9df-fa3b725d2171
# 삽입 성공, UUID: 4a5f4b9d-746f-4435-b47e-4aa4a6a5043e
# 삽입 성공, UUID: 08b4f9df-c026-4e85-8d35-4cfbc10c9acc
# 삽입 성공, UUID: 3d6c4247-3a5a-4b37-8013-3778682d26c4
# 삽입 성공, UUID: f7323bb1-2eda-4860-95cf-86c51b1ef340
# 삽입 성공, UUID: 66293998-d885-4b11-aec4-b3e518fe5356
# 삽입 성공, UUID: ea16fb8c-6f59-4b3b-86a7-6c9d6f9d7648
# 삽입 성공, UUID: 5195c9b3-d272-490a-b8ea-420498d02680
# 삽입 성공, UUID: 0a7d3f73-635d-478c-95df-207a18d9732c
# 삽입 성공, UUID: c881b0d0-2b89-4c19-a052-ea99f4f94472
# 삽입 성공, UUID: 3641bc33-3fa6-47a6-a128-9412f01cd222
# 삽입 성공, UUID: 74309802-3bd1-47ea-8acd-b3f6fbf7daaf
# 삽입 성공, UUID: 4b650b5e-5c8f-4e9f-84d6-ab795adf4cbd
# 삽입 성공, UUID: 8259d660-6ab5-4a1b-b0d8-11d2dc92672e
# 삽입 성공, UUID: c0214061-2e2c-4517-8ff9-7f2dff35a566
# 삽입 성공, UUID: beb5ee51-0361-474d-b5d3-3330ed5d2a90
# 삽입 성공, UUID: dbbc63de-60d5-4c9f-9630-e63badd9013c
# 삽입 성공, UUID: 4c9db82e-970b-4a4a-9539-4e4906edf445
# 삽입 성공, UUID: 6f49ad24-c8b8-42e7-827a-2bb0ffa8309e
# 삽입 성공, UUID: dd367e42-4717-43a1-9688-10225d70d9a9
# 삽입 성공, UUID: 1ed29456-f3eb-41fc-a853-389ebd3f8f95
# 삽입 성공, UUID: 6738c5d3-d489-45e4-923f-31cfa06a2639
# 삽입 성공, UUID: d4f59c8e-f879-4fc3-ac27-81b780734a88
# 삽입 성공, UUID: e4ae7c8f-d20b-4e1e-9ee5-98d547af5d09
# 삽입 성공, UUID: edb31e1e-61bb-47b8-8b21-60084ee66693
# 삽입 성공, UUID: dd4aa981-302b-4099-9fa3-82cd3016846e
# 삽입 성공, UUID: e4f8549d-0593-4090-9d97-004aa7cd0174
# 삽입 성공, UUID: d592bb99-eb96-45a3-ba5a-a565b1933915
# 삽입 성공, UUID: 2c3206b5-1a54-4197-b0dd-75b3a1cd3d07
# 삽입 성공, UUID: 6f8a8732-eacb-465f-b5a2-510c9ef6285f
# 삽입 성공, UUID: 9cd88ad8-ac14-4e6a-add2-ee9277d7b713
# 삽입 성공, UUID: debabf8a-d117-44cd-8e7a-64dcdf4ea29c
# 삽입 성공, UUID: 5e1da41e-a980-4e15-9ca7-0fed2e1dd902
# 삽입 성공, UUID: 0ec5566a-a91c-4bf0-a730-33bffcb64755
# 삽입 성공, UUID: a66fda9b-868f-43d2-a27d-4f99d01c1732
# 삽입 성공, UUID: 9decc072-c4da-4fcb-8d70-664da50fdb19
# 삽입 성공, UUID: 969da4ef-8ca9-43a9-9675-fc78a4108ad6
# 삽입 성공, UUID: 8b7a3079-80b9-4433-a58d-0b385d035dc7
# 삽입 성공, UUID: 9882c05b-d6d5-401f-8a50-80a27f9dd377
# 삽입 성공, UUID: 5358ece8-40ac-4e0b-b988-2ac5e7e8e7e7
# 삽입 성공, UUID: 37a1dbb5-bdfd-4124-885e-56461e8a2572
# 삽입 성공, UUID: ffd8cc74-1392-4992-86f5-76b709190bc5
# 삽입 성공, UUID: 24282f75-76c5-4dd4-87ce-853db8d4ea66
# 삽입 성공, UUID: 41c9f114-692d-4dd5-b60f-96dcf5ab5db5
# 삽입 성공, UUID: e82f9bcd-8578-4636-b514-074ea01bc246
# 삽입 성공, UUID: e4f825ce-eda9-4923-b20b-4d14592573f6
# 삽입 성공, UUID: 3b091b08-f4fd-4c4b-9405-db55a50df52f
# 삽입 성공, UUID: 58c77ae9-6e01-4419-b528-50f0a138b212
# 삽입 성공, UUID: 45b656c9-bef3-4b41-b5d1-b6f7c0025caf
# 삽입 성공, UUID: 7c0925ba-8754-4a4f-99aa-2b7656252ba7
# 삽입 성공, UUID: eb17d7ed-2bc0-48ff-99f3-40031dd39c62
# 삽입 성공, UUID: c1cdb0e6-8d0d-4027-99dc-765fd3427abb
# 삽입 성공, UUID: 566991a2-22e8-43aa-9570-b7e0b80e10b7
# 삽입 성공, UUID: 085860ab-e1a1-4812-a2d5-255b87a90e78
# 삽입 성공, UUID: 70437cda-a247-4cad-8464-80539a050e99
# 삽입 성공, UUID: 4c68ac38-1fc1-49e5-8ea7-7042d61e3bdb
# 삽입 성공, UUID: deea66f2-99e0-4ece-aad5-492a20d15af4
# 삽입 성공, UUID: 83e3ce46-edd2-48a5-8c62-f011912236cc
# 삽입 성공, UUID: 5b5eaf7a-a1b2-4055-97c2-0a6bb4aa5e12
# 삽입 성공, UUID: 35f14ff1-8773-417d-97a1-29fadd91495b
# 삽입 성공, UUID: 5d96ebe8-8cb6-47de-8f5e-b18b379ed4c6
# 삽입 성공, UUID: a6bf2287-4ef2-460c-8b0b-ed3260849d53
# 삽입 성공, UUID: 6a2163c0-2b45-45fa-bec8-1cf81c21864e
# 삽입 성공, UUID: 64ba800a-3eb3-4d76-b87d-466ade65df47
# 삽입 성공, UUID: 099e7948-ae8a-43ba-983b-d1dc1b15ec5c
# 삽입 성공, UUID: 1c140a72-d9ef-405c-9fb8-65ef0eda4969
# 삽입 성공, UUID: 885de1b2-e983-4c13-a655-6247c62e9e8b
# 삽입 성공, UUID: 6ccc6492-933a-406a-8acd-057b53d024f0
# 삽입 성공, UUID: 895a1949-dd8e-4652-95af-1aca2a0d45dc
# 삽입 성공, UUID: 3ae79f70-abfc-4e20-8231-c9c027f9bd73
# 삽입 성공, UUID: a45b8d3d-88b7-4128-a9d6-7cb1960e2e7b
# 삽입 성공, UUID: 3b010c6b-db80-473c-ab9f-8feabfaeb727
# 삽입 성공, UUID: 8c8737e5-fa48-4f42-aefa-630a14ea34e2
# 삽입 성공, UUID: 7f46f2a6-f7cd-432c-b0a0-06c3a4d86d36
# 삽입 성공, UUID: 01590a63-df99-49db-9df0-863dc5ec79d2
# 삽입 성공, UUID: 6a8d9904-4f37-4957-befd-040c68abce69
# 삽입 성공, UUID: a4e58ca7-6fa7-4c90-8393-e63c2af918a5
# 삽입 성공, UUID: 233013b4-0de9-409a-864f-d4b502f761a9
# 삽입 성공, UUID: ff122725-7b9d-4aca-8317-4e9d2e0e3246
# 삽입 성공, UUID: ddbc7e37-6251-4bf8-80f7-3db2975e3ab6
# 삽입 성공, UUID: 25751b94-071d-46c6-b8c6-e842a84d55f1
# 삽입 성공, UUID: b8a2b27f-5997-4a96-b986-0b34a83dd442
# 삽입 성공, UUID: f894d864-1540-45af-a3fd-1627f16ca34e
# 삽입 성공, UUID: 93161245-0667-49d7-b3a5-f7b430e0081d
# 삽입 성공, UUID: 76d614bb-6905-4952-8708-f2a220801e06
# 삽입 성공, UUID: 39f7d453-6566-4023-bdc0-58bbf7c45d32
# 삽입 성공, UUID: 1751371a-3823-46bd-9b2b-cd758f3d0274
# 삽입 성공, UUID: c0f3d78b-f6e1-4d43-abf3-dca7ee55f932
# 삽입 성공, UUID: ceac2b72-faf5-4b83-a5dc-f9654a8f5001
# 삽입 성공, UUID: ada4f8f2-5149-46c4-82d5-d3de413c6330
# 삽입 성공, UUID: 2138a2fe-e1d3-47fc-90cd-08f1744ad484
# 삽입 성공, UUID: c0bdd1be-bd33-4664-ad61-e73e23dc2c98
# 삽입 성공, UUID: 275ce94f-7276-4201-9d3e-51a419c4ccf7
# 삽입 성공, UUID: b91c2c6b-aa12-43e9-99d9-69042a7f2c7a
# 삽입 성공, UUID: 2fac78ac-63c9-4998-a275-d4c5a4cd49cb
# 삽입 성공, UUID: 964763cd-9ce9-4357-812e-5b70d7cf665f
# 삽입 성공, UUID: e2bbb42b-412a-4219-89a9-da6fe90d329a
# 삽입 성공, UUID: 32cbd97e-a4fd-412a-bac8-f1fdcb635759
# 삽입 성공, UUID: 707d7c8d-98fe-4865-9da3-2a6f07040452
# 삽입 성공, UUID: b5095d5a-4cf5-401f-be00-93577a91ef14
# 삽입 성공, UUID: 1666de17-b185-4b5e-b7eb-7618a14fe78e
# 삽입 성공, UUID: d66d0b4a-a71b-44a6-bf85-288e30decd4c
# 삽입 성공, UUID: 0dc33a5f-37d4-436c-91e4-7ef5b73e3d90
# 삽입 성공, UUID: 6c3a32cc-5869-412a-8b90-57ee1a13ad44
# 삽입 성공, UUID: 6b7d9ba3-1f9e-44f1-96d4-c2199888f988
# 삽입 성공, UUID: 1a803ed9-b87d-4087-84c5-889448b671a6
# 삽입 성공, UUID: 2cb84321-266b-4a1d-b1c6-69ca453f1693
# 삽입 성공, UUID: 8d96f493-1122-4e5b-8b94-9f7941edf325
# 삽입 성공, UUID: e1d2a8bf-a34e-4ec3-944c-3863988ab22a
# 삽입 성공, UUID: e8718526-1145-46e6-b135-c51cd5992b06
# 삽입 성공, UUID: 4f9af02e-1e4a-4ca6-afca-619e00395836
# 삽입 성공, UUID: 905c22ec-ea5c-4eac-af7e-f20aff50f663
# 삽입 성공, UUID: ceb5c31a-bd61-464b-8982-0e28e054a951
# 삽입 성공, UUID: 98c380e8-1877-4373-b1ff-fd3c357cf63e
# 삽입 성공, UUID: b0adc8f2-f5a6-4584-9ced-b29a6b0f0c1c
# 삽입 성공, UUID: a1dbc8b3-936a-4721-9810-2dafc1b3df7b
# 삽입 성공, UUID: 62667d60-7b21-4306-958e-e4e2d038ac70
# 삽입 성공, UUID: 3a7b2241-9fd4-4a90-a345-ed433efee0af
# 삽입 성공, UUID: c0fd2367-a59c-459a-8b9f-244f2eb1b8dd
# 삽입 성공, UUID: 7c6ba807-ab55-4b3d-9c3f-f891cb74e08d
# 삽입 성공, UUID: da2ecc4f-6069-42a8-adda-9b965516f0d2
# 삽입 성공, UUID: f63ecd47-5dc6-4a02-8159-94e4b70434d0
# 삽입 성공, UUID: bd201e98-3ff8-4cee-a9d5-0e7e41e1d3fa
# 삽입 성공, UUID: f3633a0d-b4cd-4a2a-b7df-d184ad8fb52b
# 삽입 성공, UUID: e21f22db-76b3-44e8-9b29-a47004181ba4
# 삽입 성공, UUID: a71fca5b-c3af-4f88-95dd-dd99a67759d5
# 삽입 성공, UUID: 2d670d51-6795-4edf-8b33-16f65c79ef73
# 삽입 성공, UUID: 49186f82-8d47-461a-a44e-a0325752ad24
# 삽입 성공, UUID: eb85450b-6062-49e2-bd93-dfdd1c2d6a2e
# 삽입 성공, UUID: 3bab8c3a-46d9-432d-adb8-4c5d4bf3a1cd
# 삽입 성공, UUID: fcbfe675-6ed5-4ad4-9820-a1f6ae288605
# 삽입 성공, UUID: ea43b108-39d7-4982-b689-ecd55889c963
# 삽입 성공, UUID: 59f23269-0cf7-4da7-aeae-4ddbdb8c3034
# 삽입 성공, UUID: 75609a63-8984-41e0-aafa-a300e17075c9
# 삽입 성공, UUID: e2a5ab94-dd15-42fa-aab7-80a3d01ac81c
# 삽입 성공, UUID: b342a8c4-e03e-4274-9812-5aba8c52936d
# 삽입 성공, UUID: 7f2df36e-a18f-418e-8fe8-fcb37a1fe0e2
# 삽입 성공, UUID: 7855b58e-28dc-447f-9fa5-f87e4c008926
# 삽입 성공, UUID: a4fdcb23-2758-4a5f-ab8b-922b29d4c677
# 삽입 성공, UUID: ac244bb1-6c36-46bb-9dd8-8bdcccaf504d
# 삽입 성공, UUID: bcf3e4f4-7ecb-46ac-accf-659937dee348
# 삽입 성공, UUID: 28ee03d8-502a-4e6e-9168-b755343d7b7c
# 삽입 성공, UUID: 59b6e910-3423-4e6d-9c71-da56956d7550
# 삽입 성공, UUID: 29da1385-906c-4459-b263-94703aab1b15
# 삽입 성공, UUID: 6cc58fe8-6916-4e51-8a7d-7808569e30f7
# 삽입 성공, UUID: 9e944434-a61f-41f9-82bf-453cf6ba811a
# 삽입 성공, UUID: ffc952a5-113c-4452-8c94-657ea0f6b617
# 삽입 성공, UUID: 649ce872-2b80-4d14-91be-852c0a65b11d
# 삽입 성공, UUID: ef3fc45a-dc8e-43bf-aecd-fd15093d4897
# 삽입 성공, UUID: 166ab9e7-a854-401f-92b1-092f441eb6c9
# 삽입 성공, UUID: 607b333b-1b5d-4dd1-ad50-50fcdabcabdc
# 삽입 성공, UUID: b6eb202d-b1a5-4421-9096-f72ceb678da4
# 삽입 성공, UUID: 477a4e20-fc1c-4bd3-a6c1-d2bb41688189
# 삽입 성공, UUID: 7388e2fa-7632-4875-abf9-f5417fceb5cd
# 삽입 성공, UUID: 1b653e9e-21d4-4a8b-be44-fa34a3925011
# 삽입 성공, UUID: b394d945-9df5-408e-91df-d8c219828afd
# 삽입 성공, UUID: ca63e275-f5e5-451e-980f-5b2c98977d66
# 삽입 성공, UUID: c00d4962-4023-4d24-90e2-444ae67abf3f
# 삽입 성공, UUID: 41872f47-43cf-4599-b942-91acf92df57d
# 삽입 성공, UUID: 789de346-8872-44dd-91e9-1aa7a2017450
# 삽입 성공, UUID: 8be798db-e9cc-4277-8c82-fe468eee121c
# 삽입 성공, UUID: 89c9eb1d-120a-4ab7-83c3-b7e9b635339c
# 삽입 성공, UUID: b4d4c17d-2125-45e1-a614-d51c60202fb6
# 삽입 성공, UUID: 0fdddc8a-779a-49cb-be51-48b825c786fd
# 삽입 성공, UUID: c6fd2190-5644-494c-8add-953c8c0315f0
# 삽입 성공, UUID: 94146e3d-f6ba-4d73-8e8f-99b5e5be77aa
# 삽입 성공, UUID: ceb57e87-b4c1-46ec-9a0a-03a9573c5327
# 삽입 성공, UUID: 73146eb9-f2aa-4ea9-8990-93032448695d
# 삽입 성공, UUID: 5a712ff9-f020-48e1-8fc1-e085b7db7b7e
# 삽입 성공, UUID: 32eea6a5-79a6-46a3-80a1-4d94c26658db
# 삽입 성공, UUID: 56932181-969c-456b-b5d7-6bbb5e3b6a36
# 삽입 성공, UUID: 17304a56-550a-4b25-8f17-faae39d4f1ef
# 삽입 성공, UUID: 858dba6b-3e92-4c88-8546-e419d2d8383e
# 삽입 성공, UUID: 65d2d550-b37d-4b9a-b688-88c807b36f7d
# 삽입 성공, UUID: b2d3a685-51e9-4db1-9562-0e8b1e7b5e07
# 삽입 성공, UUID: 0418a896-8df0-43f2-8e49-ba7551171c72
# 삽입 성공, UUID: 93f4edb6-aac8-4a63-bc2c-651812f214e7
# 삽입 성공, UUID: 300609c4-c311-4ac1-994d-ee15cf7ae847
# 삽입 성공, UUID: 47bd14b5-591c-4c0c-a30c-c7bc8504d825
# 삽입 성공, UUID: 8e94a985-f705-4f67-ae33-95b72150b691
# 삽입 성공, UUID: 0328dffc-da9b-426e-aba6-926247f84c1d
# 삽입 성공, UUID: 322ec6ed-08d2-4533-88ec-cab02fe61967
# 삽입 성공, UUID: 64e69c18-bd53-407c-8ca5-4e30ec737459
# 삽입 성공, UUID: 65fe4809-c2d1-4886-bf09-0b1cff391b98
# 삽입 성공, UUID: 58b4eef6-856b-4361-94ba-ac2cbbf25175
# 삽입 성공, UUID: 786d4167-ba7e-4b05-96ec-b5b6bcde209c
# 삽입 성공, UUID: 2b10a263-1d87-4351-89cb-c64f78db98e5
# 삽입 성공, UUID: 3ec9a894-aa3f-41dd-8cef-c209237a1a82
# 삽입 성공, UUID: 57f32bd4-ff3e-4573-9f99-49e3ce6fe7c8
# 삽입 성공, UUID: e1dec496-0e60-45c9-9dcf-4e60ac6c865f
# 삽입 성공, UUID: 218653e4-826e-4635-ad30-6ab62778e228
# 삽입 성공, UUID: 1f036a3b-840e-44a4-ab42-67f2667dd0a0
# 삽입 성공, UUID: 0461904c-8cee-40cc-a2d8-d18f0dc7f0b6
# 삽입 성공, UUID: 45d4fefd-3dbd-4f1b-bb2b-be4174a66813
# 삽입 성공, UUID: e081b193-08af-4295-8942-45e9cace2427
# 삽입 성공, UUID: 3bf898be-0201-482e-bfc5-42e934b0b375
# 삽입 성공, UUID: 3a486238-00c0-4efb-88de-53e35cb3f16a
# 삽입 성공, UUID: 0b9a11fe-5646-4a60-8a77-9ec36fcd1b97
# 삽입 성공, UUID: 4e781725-b106-4427-a2d9-c6f56f7b06e8
# 삽입 성공, UUID: 0f53c1b3-b2e4-4a93-836d-b8039a4fb5f8
# 삽입 성공, UUID: 190c20ee-6f96-4f97-8a09-91e02b608c75
# 삽입 성공, UUID: 8b7b1ec6-d26e-4a49-ac4f-ddf7e0cecd03
# 삽입 성공, UUID: 8b228b3d-9784-47c0-a5ad-80af4313b9b9
# 삽입 성공, UUID: c344d5c1-0bc9-441e-b332-2c3e0be1e5b2
# 삽입 성공, UUID: 8e25e2a7-cc82-424e-b204-2789e19b99e4
# 삽입 성공, UUID: ae53dccd-ce9c-4d00-9248-244e0a0531df
# 삽입 성공, UUID: 46358c74-3b75-44d0-8aee-0c5a7f67a2e1
# 삽입 성공, UUID: 8c4ee8d8-f1a5-4782-b662-1f56b117b2c2
# 삽입 성공, UUID: 3c503249-b8ab-4f7e-be89-43c4ce87edd2
# 삽입 성공, UUID: 103f28ab-c667-4b25-905e-b43f76fe03c8
# 삽입 성공, UUID: 0cd46889-7d27-4f5c-9f4f-74e48c288257
# 삽입 성공, UUID: 41adff58-c026-4a78-a755-161980907a8b
# 삽입 성공, UUID: ab3d7b45-e13e-4599-8f7a-34bc6d448635
# 삽입 성공, UUID: f896783c-5c9f-410c-b107-d35d89b72b42
# 삽입 성공, UUID: 6cd29f91-790c-467f-954b-39549ffdf7d6
# 삽입 성공, UUID: 88ea2b72-56a0-4ba2-9c46-636200121961
# 삽입 성공, UUID: f496b738-ae17-4794-be1e-534ba6d553a6
# 삽입 성공, UUID: 6335cff4-3541-406d-8809-05d778930489
# 삽입 성공, UUID: a9d93c66-746e-4946-a2a8-446cee42019e
# 삽입 성공, UUID: a28d64c1-3222-4caa-97da-6992a1e6a25b
# 삽입 성공, UUID: fcbd10af-4a6f-4ffc-8215-0ebf9e54df9a
# 삽입 성공, UUID: 5bef33bb-2785-4661-ab55-92d75aebb0bf
# 삽입 성공, UUID: 02927287-8fe3-4ff3-977d-7145b3fb48a3
# 삽입 성공, UUID: d4b884c4-b6d0-46aa-8432-054d6a4e981d
# 삽입 성공, UUID: bfc84c92-6955-4eb0-ad97-f0aee8fdb548
# 삽입 성공, UUID: a16bfec9-6c15-4b76-99d6-657931790e9a
# 삽입 성공, UUID: 027aee56-8bb1-4e6f-8fad-23b75dde4a03
# 삽입 성공, UUID: 8fdfe4c8-a017-449f-abeb-0b89a6284c53
# ...
# 삽입 성공, UUID: b1b3893f-239b-47ad-b813-0a6708ccd1f2
# 삽입 성공, UUID: f134616b-445f-4284-8a3c-9512bceb2194
# 삽입 성공, UUID: 2d772570-6f62-47b0-99df-8146a3ea9fb7
# 삽입 성공, UUID: d86fd977-979d-48c0-97f1-ec515692060e
# 삽입 성공, UUID: 32dbc55e-b907-43e3-8da0-fb0f962de873
# 삽입 성공, UUID: 523f08ac-f0a6-48b8-bd40-ad1c680e86d8
# 삽입 성공, UUID: 85326dcd-2068-4a62-a65e-112af9a7d4eb
# 삽입 성공, UUID: 5c7352ef-cee6-407f-b545-f0b58b9f06db
# 삽입 성공, UUID: 5cf7024e-3541-403e-987e-53764900f119
# 삽입 성공, UUID: ca841aab-eecd-4227-b928-f52961e32c08
# 삽입 성공, UUID: 11109a2b-3208-4d28-bd9f-a3c7a7116780
# 삽입 성공, UUID: c66aa661-4a66-4e86-a88a-7c5cf525e9be
# 삽입 성공, UUID: 344544f3-f270-41c5-b0aa-34018f4650aa
# 삽입 성공, UUID: c0c6d416-1ce6-4bfa-ac94-71a48594ead5
# 삽입 성공, UUID: fbbd8f7a-a97f-4725-832e-9c14cfddbb01
# 삽입 성공, UUID: 415599c6-2a72-4d3c-b124-a11cab499d94
# 삽입 성공, UUID: d470f2a8-d04a-4345-a55f-ed7080db64be
# 삽입 성공, UUID: 5241783c-c357-4490-9039-8cbaa75d315e
# 삽입 성공, UUID: 09fc4dc8-7493-45c8-a916-3fc7e0273f6b
# 삽입 성공, UUID: 8101c283-cc80-4ab5-8b4a-f81cbf4f42ff
# 삽입 성공, UUID: 2b03d272-c047-4f2d-b618-c6fe5b29e9e4
# 삽입 성공, UUID: 39f71a57-6e9f-402e-a5d1-6447a3fafb52
# 삽입 성공, UUID: 75d977bd-68e9-468b-a5b3-ee0b90250063
# 삽입 성공, UUID: 71bf3077-20c0-47b4-a4b6-d1c88147cee6
# 삽입 성공, UUID: dff7d2d6-0835-44c9-ad01-f1f75e5caba9
# 삽입 성공, UUID: f2af03c4-687b-4521-8ee7-3e51b5b6c17d
# 삽입 성공, UUID: b94a16d2-2ac2-4761-aac6-4f8a927e97d5
# 삽입 성공, UUID: 54c63f40-55ca-490a-9c86-19cd35a93476
# 삽입 성공, UUID: a1913da9-7b8b-4b54-8f73-6249e1780b67
# 삽입 성공, UUID: 9df4fe62-af45-4bf5-bdd6-a476f44a2f8f
# 삽입 성공, UUID: 351f3324-e72b-47c0-a1aa-11a0f50fa297
# 삽입 성공, UUID: f480bd8e-36de-433d-86f6-dda485fa0f0a
# 삽입 성공, UUID: 17194ea5-a8ae-43da-baba-f0f340afd2ed
# 삽입 성공, UUID: a3993da9-c247-4ea5-be5e-bcaa3b9de746
# 삽입 성공, UUID: 8cdaf8c9-89b9-47a2-b45f-d5bc7be0bdca
# 삽입 성공, UUID: 6d9c896b-0ebc-420f-94c2-186d499ca8b8
# 삽입 성공, UUID: 59ad1cfe-e894-4cc6-8aa9-4cecc7577b5b
# 삽입 성공, UUID: 03b91a7b-070a-4b3f-b3ab-1d5c0234ced0
# 삽입 성공, UUID: b493bd0b-b4c6-4df6-81b8-424385faa3ed
# 삽입 성공, UUID: 6777bb0a-0aca-42b8-b69c-850e3f93ddc7
# 삽입 성공, UUID: 000fd05f-8cbe-45b3-8c47-adc453def419
# 삽입 성공, UUID: bd0d2083-aaf8-41cc-bd99-204befe13bff
# 삽입 성공, UUID: 108c7f4c-ab13-449f-9367-57328e8af3db
# 삽입 성공, UUID: e29da732-18a3-4293-896e-24956c45b906
# 삽입 성공, UUID: fda4ebb8-cd7d-4866-ae6f-72137039c38f
# 삽입 성공, UUID: 8ee8d841-4808-486f-8481-042363f780cf
# 삽입 성공, UUID: 4ac6dfa0-a4a9-4642-809a-6edc7fdaa592
# 삽입 성공, UUID: 3abe20f5-4c64-4d1b-816f-739cfbcef645
# 삽입 성공, UUID: 6fa6e328-2fe1-4023-83e2-d34353a8697a
# 삽입 성공, UUID: 3e51cf03-88da-48ce-9112-253652417c6a
# 삽입 성공, UUID: cb1c35ad-cd79-4009-bf86-6daa5ab21bae
# 삽입 성공, UUID: f2605784-8c55-4ab7-b1d6-10817632cca3
# 삽입 성공, UUID: 6e6a5555-eb6d-4740-94b9-93a7a3366118
# 삽입 성공, UUID: f49fca4c-b112-48d5-bda2-664da93f7f49
# 삽입 성공, UUID: 20858741-0cae-44bd-ba75-fc56b69e0dfe
# 삽입 성공, UUID: 784895aa-8491-44a7-be37-b29a9fc03d8b
# 삽입 성공, UUID: 0c79974c-7607-4c32-9623-5ae0cef29c71
# 삽입 성공, UUID: 4c216c88-3d4e-448c-8f1c-592f6e5e26a0
# 삽입 성공, UUID: 628356d8-b38d-465a-879a-711f57c07994
# 삽입 성공, UUID: 3f0713d1-9fca-4a36-b254-add78efa9b14
# 삽입 성공, UUID: 66d5f8c8-14c5-404c-be39-06296094c911
# 삽입 성공, UUID: 0f320305-2a18-4213-acef-15b4a45f36aa
# 삽입 성공, UUID: 80b5bcbd-8af9-452c-ab79-cda99aa0fc64
# 삽입 성공, UUID: 5ae6f0a8-0c1f-40d2-9648-79bc6fb00f78
# 삽입 성공, UUID: bc93db49-ec16-49c8-bb37-a2c21c179ea6
# 삽입 성공, UUID: 53d422a6-a2d5-4089-8f70-08394ef8d6bc
# 삽입 성공, UUID: 5dd1d844-c4e9-4d29-981b-31cdda284606
# 삽입 성공, UUID: 1bc7d1c8-ecb5-418c-ade5-1ab0814c2a8a
# 삽입 성공, UUID: 5118fc9f-b68f-4823-ab6a-e696a00fdc12
# 삽입 성공, UUID: 1d9daeb8-241e-4c29-827d-49b30f8da351
# 삽입 성공, UUID: 8c989b47-ad93-40ef-b13b-70fd3698ba41
# 삽입 성공, UUID: bf5381c2-54e6-47b1-a32a-416df69df01d
# 삽입 성공, UUID: b91a2d78-a6c3-40bf-9b1a-c0bfaf6739e2
# 삽입 성공, UUID: c3d9c98e-2f84-485f-80f5-a047930c2f26
# 삽입 성공, UUID: f49c4ec2-996d-4ce3-b079-5d2bcc730ca7
# 삽입 성공, UUID: 9d8753f0-6498-499c-9244-3f25caae42f9
# 삽입 성공, UUID: 9b3f4a67-40ab-4322-917b-4858cd81f25f
# 삽입 성공, UUID: fa4d643a-2c9b-4cf7-be03-4d41ab645087
# 삽입 성공, UUID: 4b99ffbd-0713-45f9-b9e2-dbfd30de8404
# 삽입 성공, UUID: 1940365a-c28a-4848-bd34-142ad0617a97
# 삽입 성공, UUID: 0fb0a6f5-1924-4e59-a42f-ef1b2fc83a41
# 삽입 성공, UUID: 7a5fdc5e-3978-43e4-ac4b-8c3425c83baa
# 삽입 성공, UUID: 9b169877-f0ab-4e0f-a37c-b659f37a2b2b
# 삽입 성공, UUID: 72379668-f878-4318-897e-630f0246e962
# 삽입 성공, UUID: 748864a1-7a74-4528-8c81-cbca6cac949c
# 삽입 성공, UUID: ba013b30-2d10-414e-b510-f26c0779cbbd
# 삽입 성공, UUID: 0a99257a-2938-400b-a4b2-49486f365ccf
# 삽입 성공, UUID: d9ae6b78-bddb-448c-96c0-93cb7d4902e5
# 삽입 성공, UUID: a9b24613-7022-46fc-a0c2-944e58b32577
# 삽입 성공, UUID: 8fcdc980-6622-42bd-a7f3-0a35ba0201a2
# 삽입 성공, UUID: 2968cffb-4d23-41ad-bfb7-24f8f333b06e
# 삽입 성공, UUID: a69defda-7ece-4853-9109-9d38b76483b6
# 삽입 성공, UUID: 4f1f321b-f790-4638-b504-c25d4d28bc0c
# 삽입 성공, UUID: f1800b24-298c-44da-8daf-d9164e9d52d7
# 삽입 성공, UUID: 8db8fb0f-926e-43c8-8b5f-dd3fb347cd08
# 삽입 성공, UUID: 04231f5a-d2d8-4455-b2f1-3732ec491926
# 삽입 성공, UUID: 15570730-b94e-46c3-a4b7-bdb851563ba8
# 삽입 성공, UUID: 45c0e482-6e11-4a77-ba21-e76856c98c89
# 삽입 성공, UUID: e46c3b8b-5402-490a-ba67-d4b599166238
# 삽입 성공, UUID: a36be515-2978-482f-b6dc-88717ab083f3
# 삽입 성공, UUID: 28b961c9-aab5-49ad-98f5-1b4a46cd148e
# 삽입 성공, UUID: 41f2efe7-26c3-4edf-a74c-14c319778eb9
# 삽입 성공, UUID: 01363ff2-2b2b-47d9-8913-27f9cf6e5509
# 삽입 성공, UUID: 6ce392a0-a102-4ee6-935f-7118f679b1a1
# 삽입 성공, UUID: 1a0b7b92-18d3-47b1-a6be-a2d368593f4d
# 삽입 성공, UUID: a5a4df7c-1033-4bfd-b01d-005409ae8bee
# 삽입 성공, UUID: 66d2bb28-65f2-4953-a34e-58aa261e49ce
# 삽입 성공, UUID: 0ad39063-87af-4bbe-b52e-613dc0595df7
# 삽입 성공, UUID: 438b73ce-7754-486e-b336-da72e69418cb
# 삽입 성공, UUID: d5d6a2c5-469d-43e7-b09f-39ae5806ff20
# 삽입 성공, UUID: b3ad4d64-fe1c-4a31-a912-71ced90c05f4
# 삽입 성공, UUID: d9ef74e7-0021-4635-87b1-5b35d85ee540
# 삽입 성공, UUID: 7303557b-151d-49e5-8136-5393bfd18ce8
# 삽입 성공, UUID: 3dde610c-7e86-473e-9767-2715ade58bc0
# 삽입 성공, UUID: 46e8c82d-495d-474c-a78c-f1f8486476f4
# 삽입 성공, UUID: d31c5625-6881-4d79-b477-7329f9fabbd0
# 삽입 성공, UUID: ef51b383-186a-4bac-862c-1e7045dcf3e3
# 삽입 성공, UUID: 5aa71422-85db-49c4-9cc3-7c07271230d1
# 삽입 성공, UUID: 41a7e68e-abc7-41e0-8dbd-3f8bc5df6063
# 삽입 성공, UUID: 14fbc265-13fc-4ed5-b505-44ac9c8382f0
# 삽입 성공, UUID: 4c0bfea1-9c74-4f78-a36c-8092dbbb0097
# 삽입 성공, UUID: 11fdf9e1-a352-407d-a039-09636d7e2624
# 삽입 성공, UUID: 2ef47a7b-8fdd-4b0c-8f32-f09ec805d746
# 삽입 성공, UUID: 061686ce-cdfb-42b5-926e-f12f675f7886
# 삽입 성공, UUID: c3741b00-856d-40dd-9cda-e1bab7d539a8
# 삽입 성공, UUID: 5d0e4f2c-75e6-4ae0-be26-fd6faffda4d2
# 삽입 성공, UUID: d7073d83-f6ef-4ede-bde1-5479d8451de1
# 삽입 성공, UUID: f1a5b936-2cfe-49c5-b861-bdaa604e7976
# 삽입 성공, UUID: 5d655772-991d-46f0-85e1-7d35f6a51f81
# 삽입 성공, UUID: 1571efca-abf5-40b4-8822-4e3f8179bc5e
# 삽입 성공, UUID: ec7ecf4f-199f-4cb4-a389-9a5a51ef6fd7
# 삽입 성공, UUID: 9d8e241b-d4ec-4bbc-8fa1-5126bf700b1c
# 삽입 성공, UUID: aa9f2440-cff7-48f6-84a9-a727808aea67
# 삽입 성공, UUID: b874ee9a-8967-44b0-9dfa-7777521aa9b0
# 삽입 성공, UUID: 55549978-f355-4cd4-bcff-207f118adfea
# 삽입 성공, UUID: 1f4ef62f-fb5e-4060-ba92-0ebe22153b14
# 삽입 성공, UUID: 770e2891-1b75-4770-8ee3-bf9a55551442
# 삽입 성공, UUID: 6a40eb68-f510-4531-920b-191d736aca12
# 삽입 성공, UUID: dab6201a-79a7-4fcb-bb38-3e9ace5cb7e9
# 삽입 성공, UUID: 6fc8d4bc-d182-4689-a132-191cd016c9a5
# 삽입 성공, UUID: 1a90387b-1bba-451e-9d94-7ebd325a47de
# 삽입 성공, UUID: bc145fa4-0165-4de8-9db9-0f1e118a4f0e
# 삽입 성공, UUID: 429d882c-fed4-4bee-847b-3d276907b4cd
# 삽입 성공, UUID: 25cd086d-9f17-4295-976d-cd3db3eaeb62
# 삽입 성공, UUID: 8a08f24d-ab77-4da1-9f5f-41e5cf1cd581
# 삽입 성공, UUID: 7864aa05-dd4e-478c-9c44-c89571526da8
# 삽입 성공, UUID: 976d6d90-1cfa-4df0-9bea-e32a0430b9cb
# 삽입 성공, UUID: c90559de-8125-4faf-8074-8c7a565961af
# 삽입 성공, UUID: 9023a600-cbb0-400c-9ffd-3fde54acaada
# 삽입 성공, UUID: 22454bcf-44e5-409b-a5ea-e781f42b15f4
# 삽입 성공, UUID: dfcd6aee-6803-4814-a001-2d33b79bfcd2
# 삽입 성공, UUID: 183194c9-4d86-492f-aa2f-82c125f26278
# 삽입 성공, UUID: d02e4d50-35df-4ea0-8c11-e5ab636bd7e8
# 삽입 성공, UUID: b000380c-4877-48b5-9920-ddb28611c06b
# 삽입 성공, UUID: 9c65f277-561a-4cd0-96fc-111d598bd292
# 삽입 성공, UUID: 278bd8a5-f754-4631-a481-4e7c3580bbf0
# 삽입 성공, UUID: 29a95de9-671e-442c-af47-f66bd97336ed
# 삽입 성공, UUID: 73fa7294-ddff-44b8-87c5-0a2448ed5f0c
# 삽입 성공, UUID: 768dcb23-f0d3-4c21-acaf-c641f66e0e93
# 삽입 성공, UUID: fcbb806a-df3b-4f75-9c54-1c914be2882b
# 삽입 성공, UUID: ac545d4c-f132-45d8-bfff-675cb219bc86
# 삽입 성공, UUID: 7f3ea645-a89e-4718-82e1-a5715693d71a
# 삽입 성공, UUID: 1b949a52-3ed9-41e9-9192-2ddd29776c52
# 삽입 성공, UUID: be38b407-f5f3-4d1f-a227-56b690ddfbf4
# 삽입 성공, UUID: f1cb12ff-e287-4b9b-b1fc-1814cd6f0df1
# 삽입 성공, UUID: ae990cd8-777f-4962-8ae9-4846b3ca933e
# 삽입 성공, UUID: e410f6fc-c8b7-4aea-b7af-faef6895c3a9
# 삽입 성공, UUID: 319b08fc-6c31-4404-b8e9-447f8e0a607d
# 삽입 성공, UUID: 50d82b7b-ec1b-4854-811e-7805a01f9a0e
# 삽입 성공, UUID: bef08c63-3860-4412-b41a-7695620ff659
# 삽입 성공, UUID: 828bdaa8-ef74-4afd-9f66-fd6feec7cf3c
# 삽입 성공, UUID: 6471c7bb-551b-4478-931c-82b16601c3b4
# 삽입 성공, UUID: 00e7f4cf-2d3b-4275-88af-2e99106c5dd1
# 삽입 성공, UUID: 1b8fcfe6-0600-4a5b-aa3e-5dbcf84dd1c6
# 삽입 성공, UUID: 2ac78fa3-96ee-453d-ad4f-1bfb3d5459ae
# 삽입 성공, UUID: 7b6e90e9-a5c8-47cc-a6c7-b4589d0e476d
# 삽입 성공, UUID: b37af41d-8657-4220-a519-6c5c33427e54
# 삽입 성공, UUID: ca86fdfa-fe0a-43db-b7ff-889352361a02
# 삽입 성공, UUID: 455436f9-a2ec-4c92-bf9a-dbb12ce3a5fc
# 삽입 성공, UUID: 9624f88b-979b-4825-a9fe-ee373ba1dc09
# 삽입 성공, UUID: df1cdaac-1eb8-479b-afa3-77257fa1893b
# 삽입 성공, UUID: c98a6ac2-eda2-4eb7-be2b-176de196d340
# 삽입 성공, UUID: f95a0150-e4d8-4ce8-b116-6f2aa702785f
# 삽입 성공, UUID: fb40e92f-4468-446d-a066-38f4eba5b624
# 삽입 성공, UUID: 5cd6d8fa-3474-402d-8cdb-b288689b1bc2
# 삽입 성공, UUID: 1fe557de-d167-4aae-b299-d6a2ad6f456f
# 삽입 성공, UUID: e741b9a9-f372-434b-8305-c04b0f6ab8c8
# 삽입 성공, UUID: 4f51abc8-412f-4284-93ee-afe99c23ddd3
# 삽입 성공, UUID: 82ac174d-5299-4034-925b-6edb26cb95b2
# 삽입 성공, UUID: 7a248ebe-2ea0-4c8b-889b-c3dd0192d72f
# 삽입 성공, UUID: b53b5a38-e1e9-45e9-b580-1411f8118e23
# 삽입 성공, UUID: 69e24aaa-0833-4c5c-8eb0-a75cb844fc27
# 삽입 성공, UUID: 37e9c871-640f-496f-bb2f-65adc7bb2152
# 삽입 성공, UUID: 0a6eda48-d4ab-4ac4-98d6-bc6575e0a50f
# 삽입 성공, UUID: cca10b23-c234-4a74-8baa-124de6cd1255
# 삽입 성공, UUID: 419fc2c7-2ad4-49c4-a828-3dec055ce462
# 삽입 성공, UUID: e5633d86-54e3-4e31-a7c9-b6703d31b96b
# 삽입 성공, UUID: 97322274-a30d-46cb-83ca-35939d1e7db7
# 삽입 성공, UUID: 197d51b0-75a3-4b0f-996c-efd895499910
# 삽입 성공, UUID: 72f611bf-a3b3-428a-81c9-c7db5899f290
# 삽입 성공, UUID: 27af3fbd-707a-4cec-b2e2-057f9efb66bd
# 삽입 성공, UUID: f8766a43-05ee-46e7-8827-57976403bf70
# 삽입 성공, UUID: b13c3e71-c360-4eb0-8581-8d989dd6e697
# 삽입 성공, UUID: cbb8aa4c-304a-427f-bd91-349c1f03572f
# 삽입 성공, UUID: 1a4ce2f0-6024-424b-a1ed-46a8e1399968
# 삽입 성공, UUID: f479c382-f34a-432b-951b-ed0e7bb15848
# 삽입 성공, UUID: 1a71f268-eb64-44a9-a33f-896c609fd1f2
# 삽입 성공, UUID: 16f6cd3e-6ae3-4328-b0ae-8e6db51580f4
# 삽입 성공, UUID: f6729dc4-600d-4380-b097-c44e32b76319
# 삽입 성공, UUID: b946e325-32ee-4513-90fc-164100dd328f
# 삽입 성공, UUID: ca3578c8-bb6c-43a7-b9d9-abbaeb96aea7
# 삽입 성공, UUID: bf038b13-fa0d-4674-ba96-d3ae22ed504b
# 삽입 성공, UUID: ef5eb01f-194a-4a69-8697-f96f1b6ee2bd
# 삽입 성공, UUID: 3e51acb4-2d4a-46a0-ac60-03d2d248d39f
# 삽입 성공, UUID: 082271ed-d5d9-4faa-9177-2022d697258f
# 삽입 성공, UUID: e1cdd940-036a-45d8-a579-dc203f625874
# 삽입 성공, UUID: 6453a095-634f-4593-82fc-2701ffe38e8e
# 삽입 성공, UUID: 63d57019-d657-4fa2-92e8-3a48828a981a
# 삽입 성공, UUID: 31399a0d-db86-4bcb-8aae-4aed01e13d60
# 삽입 성공, UUID: a68ea3cd-a7c8-4998-b13d-f7b56b7dd19d
# 삽입 성공, UUID: 8b883902-2bb6-4b40-b820-7339d9a21d60
# 삽입 성공, UUID: ce57ac0a-ce6d-4140-831f-e53ee7d9fb47
# 삽입 성공, UUID: 3340574f-0000-4d6a-a449-052e0367a8d1
# 삽입 성공, UUID: 9ec88ea6-2ae6-4d7c-81b6-54a0181131be
# 삽입 성공, UUID: 932b8682-e8cf-4be9-b874-73dadc4f1660
# 삽입 성공, UUID: bbee4603-9012-48f1-a3a2-a5c811ebd880
# 삽입 성공, UUID: 2765e523-92a3-41c8-835a-5fe9ea9c9b27
# 삽입 성공, UUID: 9955659c-f655-4dc5-a387-e2033ed258e2
# 삽입 성공, UUID: 5747c098-f95e-4d53-b2fd-423782a1e3d7
# 삽입 성공, UUID: 00aace0b-dc00-4fa8-965b-e886487ca8d0
# 삽입 성공, UUID: 87760c4c-8aa2-4f21-849c-23e47889dd4f
# 삽입 성공, UUID: 4c32e46d-d8e2-40df-ab57-5a4279051e87
# 삽입 성공, UUID: 6c79c3c1-c9c9-476b-970f-0adf2e823d57
# 삽입 성공, UUID: bfb0bb33-d5b6-4b21-8878-e68c6963207d
# 삽입 성공, UUID: a47e31af-e45c-422b-b88d-815d28b900e4
# 삽입 성공, UUID: d7d90b78-e01b-49c2-99d7-0c3c26d08fb6
# 삽입 성공, UUID: 906ffc09-5875-44e6-99d9-b468d4153a52
# 삽입 성공, UUID: 3d595a86-c6b7-43ab-b2a7-31983464817a
# 삽입 성공, UUID: 3fb7396f-c6da-4667-b14e-0580d1903f72
# 삽입 성공, UUID: fbc48ed5-8f6c-4c7e-a377-cdc1fe202cba
# 삽입 성공, UUID: 97e937f2-e079-400e-b6b3-e3c35d15d082
# 삽입 성공, UUID: 514ff3eb-921e-40e9-8df6-d36e9e9f8c4e
# 삽입 성공, UUID: 7a9c0b95-a31b-4c45-b20a-6632e02aa272
# 삽입 성공, UUID: 16b3f485-d73a-4ddc-820e-aeec1b882187
# 삽입 성공, UUID: d2a698b1-60bf-413f-bde0-473993edad79
# 삽입 성공, UUID: ab9c843d-c0b1-46e2-b0ce-108335435450
# 삽입 성공, UUID: 960767a2-b39e-4bee-9fda-26f54cbb516b
# 삽입 성공, UUID: 6a646eb0-9ca7-43f1-b4de-358dbf450a8a
# 삽입 성공, UUID: e4d25fc1-a6aa-40e0-b4ae-b2a138399f4e
# 삽입 성공, UUID: 804e98a8-f634-498c-bb71-42eccf649044
# 삽입 성공, UUID: ab6d3ff5-f021-49fe-93a3-b83b24b6f9ad
# 삽입 성공, UUID: 2da74f0c-b6ec-480f-a18f-005a93774283
# 삽입 성공, UUID: aa4fb7e3-fb39-4781-b835-fd5b83a865f8
# 삽입 성공, UUID: 7e508f44-4c75-45b9-8ca5-a4aa61cfe92b
# 삽입 성공, UUID: 219e376a-6a5a-423d-ba0b-91dde2eecafc
# 삽입 성공, UUID: 6fd4d4bc-a6bc-4802-bfca-1a2145ebaa52
# 삽입 성공, UUID: 8d5bb198-9c9d-455a-a014-c6e79d89f297
# 삽입 성공, UUID: 3fc5c666-2eef-46c8-885e-67afa4cb03d1
# 삽입 성공, UUID: bc86bab8-937f-462b-8bed-a12050e58683
# 삽입 성공, UUID: 56051145-efe6-4ff0-afd9-9367733388a1
# 삽입 성공, UUID: 5a933a42-394f-4f25-9a68-077f4f075c2d
# 삽입 성공, UUID: 49e73259-34bc-4fab-beae-b240719e4639
# 삽입 성공, UUID: e00b6d81-1032-4721-befe-6e892a606be9
# 삽입 성공, UUID: 246f92fb-d1a9-4314-bd1a-7857ccc6e7c4
# 삽입 성공, UUID: df642f17-8686-4e42-9a02-126f6dbc9032
# 삽입 성공, UUID: 729bc159-24b5-4c44-b920-2da2d07a8c11
# 삽입 성공, UUID: d39daebf-e090-4031-b3da-37d64eafde4a
# 삽입 성공, UUID: be9de119-ac07-4240-b45b-97fe392677ac
# 삽입 성공, UUID: da419541-d2fd-4f5a-8def-14ae04d13e39
# 삽입 성공, UUID: 2bc72f82-ba3b-45e8-ae6d-f8682ee7e301
# 삽입 성공, UUID: c7180086-cdd3-4dc9-898e-48452b2f5e15
# 삽입 성공, UUID: e380a7a1-6311-4be5-8aef-02560a4b133f
# 삽입 성공, UUID: 55260f87-e6ab-4484-ae7f-65e55892ac22
# 삽입 성공, UUID: d8b5284d-5dbd-4a62-9ffc-455a69caa843
# 삽입 성공, UUID: 3df9a5f9-e19b-4e8c-8f47-5d4ac1f1a714
# 삽입 성공, UUID: 48467ff0-ca98-45fb-8861-c0532e2298a8
# 삽입 성공, UUID: 12e71bb3-574a-417c-82dd-8bab3a161cad
# 삽입 성공, UUID: cf6251a3-5125-4b2e-8096-f7e8400a4b6c
# 삽입 성공, UUID: de4200c1-30f4-48e4-8242-f046fb3ae1ea
# 삽입 성공, UUID: b3da7ed3-a59f-4e3a-bb73-9afc1e7a7219
# 삽입 성공, UUID: 62c654c7-9755-4645-ae86-da4c44b8b3af
# 삽입 성공, UUID: aa74f65c-287c-4f38-b623-fc865f83720a
# 삽입 성공, UUID: f7b07336-063a-4408-8ff8-f839ae272007
# 삽입 성공, UUID: 47eb2df8-1398-4c55-94cc-1bcc9e7dbd4c
# 삽입 성공, UUID: 21cfd00e-d679-403b-b77f-38a1efde42ac
# 삽입 성공, UUID: dba16629-3e17-4788-aaa1-860dfe4a53dc
# 삽입 성공, UUID: 882da87f-df39-4f53-af65-80d633372ca6
# 삽입 성공, UUID: cebccb89-9140-43d7-b1ff-229d09ad7a21
# 삽입 성공, UUID: 7b3443a3-162d-4dcd-adec-7e57e7e6b348
# 삽입 성공, UUID: 8815e4f7-0053-4be0-9ea7-0fed3f60a3b0
# 삽입 성공, UUID: 1bea1521-8520-4485-bc9f-7c9d6cb2bfb2
# 삽입 성공, UUID: 0437c0c6-254b-4ec9-ad15-e5acdccd42ba
# 삽입 성공, UUID: 19891a2a-d753-403f-aeec-29e8af089c29
# 삽입 성공, UUID: b641944a-75c5-422f-b5e6-c0de951d308f
# 삽입 성공, UUID: 0a5655dd-e99b-4a34-b382-19a4b37c8c25
# 삽입 성공, UUID: 254c298e-691e-4868-845f-f1e28a29d8a0
# 삽입 성공, UUID: 26d74ca9-e0e2-4ad9-9a1c-16217bcb3c22
# 삽입 성공, UUID: c4970b2d-dc88-4be3-931d-eac1c01f4bc3
# 삽입 성공, UUID: f87f8f93-7fcf-4eeb-bac4-5fff8cc2b0d7
# 삽입 성공, UUID: 050ed4fb-3c51-4dbb-9503-ee451a20196f
# 삽입 성공, UUID: a7ef6e64-637c-4618-8f96-97764d5e476e
# 삽입 성공, UUID: a86129c2-b42a-4559-b40a-d19a2ce3acf4
# 삽입 성공, UUID: ab9de25a-671f-4537-b739-dc13644e0011
# 삽입 성공, UUID: 06d2b01f-189e-4cd1-81ba-deb6bd590df8
# 삽입 성공, UUID: 305d7ae1-5483-45ed-b849-6361e2429dfb
# 삽입 성공, UUID: eacc70f5-3851-4a63-94d6-357087a8dd77
# 삽입 성공, UUID: b242b31c-6a5a-4ade-bc83-4abe6ef21c6a
# 삽입 성공, UUID: 380bd138-1397-42f0-af96-f1752343cb2b
# 삽입 성공, UUID: 1676deb4-35ed-498c-aa1e-16a72c51dd00
# 삽입 성공, UUID: 46fa57ba-b10e-4fc8-905d-81a94f42d58e
# 삽입 성공, UUID: bf18398c-7ee9-4ad2-89f3-fad954f67eb8
# 삽입 성공, UUID: 13e462ad-c3f4-4a70-8895-ea172e5920bb
# 삽입 성공, UUID: e1984d23-95d5-497c-acf8-fe8e9facc655
# 삽입 성공, UUID: 06778c32-0b1e-406e-b9f0-ac7a82d62691
# 삽입 성공, UUID: 39aea190-cb0e-44e0-a3c0-8a4b0be772ae
# 삽입 성공, UUID: 7fc3168b-9144-4616-9222-9a056752e6a2
# 삽입 성공, UUID: 4b3f30af-4406-434b-a4b2-0c7d77dd8d01
# 삽입 성공, UUID: d23c1678-6ce0-483e-adb1-fbf3f4813a69
# 삽입 성공, UUID: 3a723b39-a2d8-40c0-b5ec-3a94a930c45f
# 삽입 성공, UUID: 751230b0-00ad-436a-8653-fe3e097c9aaa

# %%
# BEFORE RAG, check dspy functions first.

print(dspy.settings.lm("Write a 3 line poem about neural networks."))
context_example = dspy.OpenAI(model="gpt-4-turbo-preview")

with dspy.context(llm=context_example):
    print(context_example("Write a 3 line poem about neural networks."))
# Out:
# ['Neural networks, a web of connections so vast,\nLearning and adapting, from present to past,\nMimicking the brain, a future so vast.']
# ['In webs of neurons, thoughts intertwine,\nLearning from chaos, patterns they find.\nMinds of silicon, endlessly refined.']

# %%
# Load FAQs
import re

f = open("blog/faq.md")
markdown_content = f.read()

def parse_questions(markdown_content):
    # Regular expression pattern for finding questions
    question_pattern = r'#### Q: (.+?)\n'

    # Finding all questions
    questions = re.findall(question_pattern, markdown_content, re.DOTALL)

    return questions

# Parsing the markdown content to get only questions
questions = parse_questions(markdown_content)

# Displaying the first few extracted questions
questions[:5]  # Displaying only the first few for brevity
# Out:
# C:\Users\rhcp1\AppData\Local\Temp\ipykernel_5588\1907521693.py:4: ResourceWarning: unclosed file <_io.TextIOWrapper name='blog/faq.md' mode='r' encoding='utf-8'>
#   f = open("blog/faq.md")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ['Why would I use Weaviate as my vector database?',
#  'What is the difference between Weaviate and for example Elasticsearch?',
#  'Do you offer Weaviate as a managed service?',
#  'How should I configure the size of my instance?',
#  'Do I need to know about Docker (Compose) to use Weaviate?']

# %%
# ToDo, add random splitting -- maybe wrap this entire thing in a cross-validation loop
trainset = questions[:20] # 20 examples for training
devset = questions[20:30] # 10 examples for development
testset = questions[30:] # 14 examples for testing

trainset = [dspy.Example(question=question).with_inputs("question") for question in trainset]
devset = [dspy.Example(question=question).with_inputs("question") for question in devset]
testset = [dspy.Example(question=question).with_inputs("question") for question in testset]

print(devset[0])
# Out:
# Example({'question': 'Is there support to multiple versions of the query/document embedding models to co-exist at a given time? (helps with live experiments of new model versions)'}) (input_keys={'question'})

# %%
metricLM = dspy.OpenAI(model='gpt-4-turbo-preview', max_tokens=2048, model_type='chat')

# Signature for LLM assessments.

class Assess(dspy.Signature):
    """Assess the quality of an answer to a question."""
    
    context = dspy.InputField(desc="The context for answering the question.")
    assessed_question = dspy.InputField(desc="The evaluation criterion.")
    assessed_answer = dspy.InputField(desc="The answer to the question.")
    assessment_answer = dspy.OutputField(desc="A rating between 1 and 5. Only output the rating and nothing else.")

def llm_metric(gold, pred, trace=None):
    predicted_answer = pred.answer
    question = gold.question
    
    print(f"Test Question: {question}")
    print(f"Predicted Answer: {predicted_answer}")
    
    detail = "Is the assessed answer detailed?"
    faithful = "Is the assessed text grounded in the context? Say no if it includes significant facts not in the context."
    overall = f"Please rate how well this answer answers the question, `{question}` based on the context.\n `{predicted_answer}`"
    
    with dspy.context(lm=metricLM):
        context = dspy.Retrieve(k=5)(question).passages
        detail = dspy.ChainOfThought(Assess)(context="N/A", assessed_question=detail, assessed_answer=predicted_answer)
        faithful = dspy.ChainOfThought(Assess)(context=context, assessed_question=faithful, assessed_answer=predicted_answer)
        overall = dspy.ChainOfThought(Assess)(context=context, assessed_question=overall, assessed_answer=predicted_answer)
    
    print(f"Faithful: {faithful.assessment_answer}")
    print(f"Detail: {detail.assessment_answer}")
    print(f"Overall: {overall.assessment_answer}")
    
    
    total = float(detail.assessment_answer) + float(faithful.assessment_answer)*2 + float(overall.assessment_answer)
    
    return total / 5.0

# %%
test_example = dspy.Example(question="What do cross encoders do?")
test_pred = dspy.Example(answer="They re-rank documents.")

type(llm_metric(test_example, test_pred))
# Out:
# Test Question: What do cross encoders do?
# Predicted Answer: They re-rank documents.
# Faithful: 5
# Detail: 1
# Overall: 5
# float

# %%
test_example = dspy.Example(question="What do cross encoders do?")
test_pred = dspy.Example(answer="They index data.")

type(llm_metric(test_example, test_pred))
# Out:
# Test Question: What do cross encoders do?
# Predicted Answer: They index data.
# Faithful: 1
# Detail: 1
# Overall: 1
# float

# %%
class GenerateAnswer(dspy.Signature):
    """Answer questions based on the context."""
    
    context = dspy.InputField(desc="may contain relevant facts")
    question = dspy.InputField()
    answer = dspy.OutputField()

# %%
import dspy

class RAG(dspy.Module):
    def __init__(self, num_passages=3):
        super().__init__()
        # Initialize the retrieve step to get the top `num_passages` passages
        self.retrieve = dspy.Retrieve(k=num_passages)
        # Initialize the generate step to answer the question
        self.generate_answer = dspy.ChainOfThought(GenerateAnswer)
    
    def forward(self, question):
        # Retrieve context based on the question
        context = self.retrieve(question).passages
        # Generate an answer based on the retrieved context and the question
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

my_question = "What are re-rankers in search engines?"
rag = RAG(num_passages=2)
pred = rag(my_question)

print(f"Question: {my_question}")
print(f"Predicted Answer: {pred.answer}")
print(f"Retrieved Contexts (truncated): {[c[:200] + '...' for c in pred.context]}")
# Out:
# Question: What are re-rankers in search engines?
# Predicted Answer: Re-rankers in search engines are tools or models, such as Cross Encoders and Metadata Rankers, that are used to further refine the relevance of search results without requiring specialized training.
# Retrieved Contexts (truncated): ['They offer the advantage of further reasoning about the relevance of results without needing specialized training. Cross Encoders can be interfaced with Weaviate to re-rank search results, trading off...', 'Taken directly from the paper, “Our findings indicate that cross-encoder re-rankers can efficiently be improved without additional computational burden and extra steps in the pipeline by explicitly ad...']

# %%
uncompiled_rag = RAG(num_passages=3)
print(uncompiled_rag("What are Cross Encoders?"))
# Out:
# Prediction(
#     context=['[Cross Encoders](#cross-encoders) (collapsing the use of Large Language Models for ranking into this category as well)\n1. [Metadata Rankers](#metadata-rankers)\n1. [Score Rankers](#score-rankers)\n\n## Cross Encoders\nCross Encoders are one of the most well known ranking models for content-based re-ranking. There is quite a collection of pre-trained cross encoders available on [sentence transformers](https://www.sbert.net/docs/pretrained_cross-encoders.html). We are currently envisioning interfacing cross encoders with Weaviate using the following syntax.', 'Bi-Encoders are fast, but are not as accurate as the expensive fisherman aka the Cross-Encoder. Cross-Encoders are time-consuming, like the fisherman who would need to limit the number of fishing rounds they could do. So we can chain those two methods behind each other (see Figure 5). First, you use a Bi-Encoder to retrieve a *list of result candidates*, then you use a Cross-Encoder on this list of candidates to pick out (or rerank) the most relevant results. This way, you benefit from the efficient retrieval method using Bi-Encoders and the high accuracy of the Cross-Encoder, so you can use this on large scale datasets!\n\n![Multistage search pipeline](./img/weaviate-pipeline-long.png)\n\n*Figure 5 - Multistage search pipeline using Weaviate*\n\n## Pre-trained Cross-Encoder models\n\nAs noted, Cross-Encoders can achieve high *in-domain* accuracy.', '![Cross-Encoder](./img/cross-encoder.png)\n\n*Figure 3 - Representation of a Cross-Encoder model*\n\n\nIf a Cross-Encoder model is trained on a representative training set, it [achieves higher accuracy than Bi-Encoders](https://arxiv.org/abs/1908.10084). However, since you need to use the Cross-Encoder model during a search for every single data item in combination with the query, this method is very inefficient. For a real-life semantic search application – with thousands or millions of objects – this would be impractical, as it would take "forever" to perform the search. ## Combining Bi-Encoders and Cross-Encoders\n\nWe can combine the two methods to benefit from the strong points of both models! I\'d like to illustrate this idea with an example. Imagine you are a fisherman who is looking for salmon in a sea full of fish of numerous species.'],
#     answer='Cross Encoders are ranking models used for content-based re-ranking that can achieve high accuracy when trained on a representative training set.'
# )
